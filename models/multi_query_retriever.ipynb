# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
try:
  from langchain_core.prompts import PromptTemplate
except ImportError:
  # !pip install langchain_core
  from langchain_core.prompts import PromptTemplate

try:
  from langchain_openai import ChatOpenAI
except ImportError:
  # !pip install langchain_openai
  from langchain_openai import ChatOpenAI

try:
  import chromadb
except ImportError:
  # !pip install chromadb
  import chromadb

try:
  from langchain_chroma import Chroma
except ImportError:
  # !pip install langchain_chroma
  from langchain_chroma import Chroma

try:
  from langchain_openai import OpenAIEmbeddings
except ImportError:
  # !pip install langchain_openai
  from langchain_openai import OpenAIEmbeddings

try:
  from langchain_core.documents import Document
except ImportError:
  # !pip install langchain_core
  from langchain_core.documents import Document

# %%
try:
  from langchain_core.prompts import PromptTemplate
except ImportError:
  # !pip install langchain_core
  from langchain_core.prompts import PromptTemplate

try:
  from langchain_openai import ChatOpenAI
except ImportError:
  # !pip install langchain_openai
  from langchain_openai import ChatOpenAI

try:
  import chromadb
except ImportError:
  # !pip install chromadb
  import chromadb

try:
  from langchain_chroma import Chroma
except ImportError:
  # !pip install langchain_chroma
  from langchain_chroma import Chroma

try:
  from langchain_openai import OpenAIEmbeddings
except ImportError:
  # !pip install langchain_openai
  from langchain_openai import OpenAIEmbeddings

try:
  from langchain_core.documents import Document
except ImportError:
  # !pip install langchain_core
  from langchain_core.documents import Document

# %%
try:
    from langchain_classic.retrievers.multi_query import MultiQueryRetriever
except ImportError:
    # !pip install langchain_classic
    from langchain_classic.retrievers.multi_query import MultiQueryRetriever
# Out:
# Collecting langchain_classic
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (1.2.8)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain_classic)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (0.6.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (2.32.4)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (2.0.46)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (26.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (0.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_classic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_classic) (3.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain_classic) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain_classic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain_classic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain_classic) (3.0.0)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Installing collected packages: langchain-text-splitters, langchain_classic
# Successfully installed langchain-text-splitters-1.1.0 langchain_classic-1.0.1

# %%
from google.colab import userdata

llm = ChatOpenAI(
    model = "gpt-4.1-nano",
    temperature = 0.01,
    max_tokens = 500,
    openai_api_key = userdata.get('OPENAI_API_KEY')
)

prompt_multi_query = """
질문을 세법 전문 용어를 사용해 3개의 서로 다른 query로 재작성해.
각 쿼리는 반드시 줄바꿈으로 구분해.

질문: {question}
"""

# %%
db_path = "/content/drive/MyDrive/rag/chromadb_backup"
client = chromadb.PersistentClient(path=db_path)
collection_name = "tax_law"

try:
  collection = client.get_collection(name=collection_name)
except Exception:
  raise RuntimeError(f"Collection {collection_name} not found")

# %%
embedding_model = "text-embedding-3-small"
embeddings = OpenAIEmbeddings(model=embedding_model, openai_api_key = userdata.get("OPENAI_API_KEY"))

vectorstore = Chroma(client = client, collection_name=collection_name, embedding_function=embeddings)

# %%
try:
  from langchain_core.output_parsers import StrOutputParser
except ImportError:
  # !pip install langchain_core
  from langchain_core.output_parsers import StrOutputParser

# %%
class LLMRerank:

  def __init__(self):
    self.llm = ChatOpenAI(model="gpt-4.1-nano", openai_api_key=userdata.get("OPENAI_API_KEY"), max_tokens = 200)

    self.prompt = """
    너는 세법 전문가야.
    질문에 대해 가장 정확한 '법률적 정의'와 '계산 근거', '법률적 조건'을 포함하고 있는 상위 {final_k}개의 문서를 나열해.
    질문과 단어가 겹치는 문서보다, 질문의 '의도'를 해결해주는 문서를 우선해.
    반드시 상위 {final_k}개의 문서 번호만 쉼표로 구분해서 답변해.

    질문: {query}
    문서: {docs}

    ex. 문서 번호 1,2,3,4,5 (final_k = 3)인 경우 3,1,4로 답변 (쉼표로 번호 구분해서 답변)
    답변:
    """

  def rerank(self, query, docs, final_k):
    docs_for_reranking = [f"[{i}] {doc.page_content}" for i, doc in enumerate(docs)]
    docs_for_reranking = "\n\n".join(docs_for_reranking)

    reranking_prompt = PromptTemplate.from_template(self.prompt)

    chain = reranking_prompt | self.llm | StrOutputParser()

    reranked_docs = chain.invoke({"final_k": final_k, "query": query, "docs": docs_for_reranking})

    reranked_docs = reranked_docs.split(",")

    reranked_docs = [int(x.strip()) for x in reranked_docs]

    final_docs = []
    seen = set()
    for x in reranked_docs:
      if x not in seen:
        seen.add(x)
        final_docs.append(docs[x])

      if len(final_docs) >= final_k:
        break

    return final_docs

# %%
import json
import re
from langchain_core.output_parsers import JsonOutputParser

class LLMRerank2:
  # LLM이 각 문서별로 질문과 관련된 정도에 대해 점수를 매김

  def __init__(self):
    self.llm = ChatOpenAI(model="gpt-4.1-nano", openai_api_key=userdata.get("OPENAI_API_KEY"), max_tokens = 1000)

    self.prompt = """
    너는 세법 전문 지식을 가진 reranking 모델이야.
    아래 질문에 대해 문서들 중 답변 근거로 가장 적절하고 관련성 있는 상위 {top_k}개의 문서를 골라줘.
    id는 반드시 제공된 [문서 번호] 숫자만 사용하고, 상위 {top_k}개의 문서에 대해 점수(0~100)을 매겨서 JSON 형식으로 답변해

    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수
    - 미세하게라도 점수에 차등을 둘 것
    - 문서 간 비교를 하여 상대적인 점수를 계산할 것

    [질문]
    {query}

    [문서들]
    {docs}

    [출력 형식-JSON]
    {{
      "scores": [
        {{"id": 0, "score": 95}},
        {{"id": 1, "score": 80}},
        ...
      ]
    }}
    """

  def rerank(self, query, docs, final_k):

    docs_matching = {} # docs 순서의 인덱싱
    for i, doc in enumerate(docs):
      docs_matching[str(i)] = doc

    docs_formatted = "\n".join([f"[문서 ID: {i}] {doc.page_content[:500]}..." for i, doc in docs_matching.items()])

    prompt = PromptTemplate.from_template(self.prompt)

    chain = prompt | self.llm | JsonOutputParser()

    try:
      result = chain.invoke({"query": query, "docs": docs_formatted, "top_k": final_k})
      scores = result.get("scores", [])

      scored_docs = []
      for x in scores:
        id = str(x.get("id"))
        score = int(x.get("score", 0))

        if id in docs_matching:
          scored_docs.append((docs_matching[id], score))

      scored_docs.sort(key=lambda x: x[1], reverse=True)

      reranked_docs = [doc for doc, _ in scored_docs[:final_k]]

      return reranked_docs

    except Exception as e:
      print(f"reranking 오류: {e}")
      return docs[:final_k]

# %%
import json
import re
from langchain_core.output_parsers import JsonOutputParser

class LLMRerank2:
  # LLM이 각 문서별로 질문과 관련된 정도에 대해 점수를 매김

  def __init__(self):
    self.llm = ChatOpenAI(model="gpt-4.1-nano", openai_api_key=userdata.get("OPENAI_API_KEY"), max_tokens = 1000)

    self.prompt = """
    너는 세법 전문 지식을 가진 reranking 모델이야.
    아래 질문에 대해 문서들 중 답변 근거로 가장 적절하고 관련성 있는 상위 {top_k}개의 문서를 골라줘.
    id는 반드시 제공된 [문서 번호] 숫자만 사용하고, 상위 {top_k}개의 문서에 대해 점수(0~100)을 매겨서 JSON 형식으로 답변해

    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수
    - 미세하게라도 점수에 차등을 둘 것
    - 문서 간 비교를 하여 상대적인 점수를 계산할 것

    [질문]
    {query}

    [문서들]
    {docs}

    [출력 형식-JSON]
    {{
      "scores": [
        {{"id": 0, "score": 95}},
        {{"id": 1, "score": 80}},
        ...
      ]
    }}
    """

  def rerank(self, query, docs, final_k):

    docs_matching = {} # docs 순서의 인덱싱
    for i, doc in enumerate(docs):
      docs_matching[str(i)] = doc

    docs_formatted = "\n".join([f"[문서 ID: {i}] {doc.page_content[:500]}..." for i, doc in docs_matching.items()])

    prompt = PromptTemplate.from_template(self.prompt)

    chain = prompt | self.llm | JsonOutputParser()

    try:
      result = chain.invoke({"query": query, "docs": docs_formatted, "top_k": final_k})
      scores = result.get("scores", [])

      scored_docs = []
      for x in scores:
        id = str(x.get("id"))
        score = int(x.get("score", 0))

        if id in docs_matching:
          scored_docs.append((docs_matching[id], score))

      scored_docs.sort(key=lambda x: x[1], reverse=True)

      reranked_docs = [doc for doc, _ in scored_docs[:final_k]]

      return reranked_docs

    except Exception as e:
      print(f"reranking 오류: {e}")
      return docs[:final_k]

# %%
from langchain_core.globals import set_debug

set_debug(False)

# %%
import re
from langchain_core.output_parsers import JsonOutputParser

class MultiQueryPipeline:
  def __init__(self, prompt_multi_query, llm, vectorstore,initial_k=25, final_k=10):
    self.prompt = PromptTemplate(
        input_variables=["question"],
        template=prompt_multi_query
    )

    self.llm = llm
    self.initial_k = initial_k
    self.final_k = final_k

    basic_retriever = vectorstore.as_retriever(search_type = "similarity", search_kwargs={"k": self.initial_k})

    self.multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever = basic_retriever,
        llm = self.llm,
        prompt = self.prompt,
        include_original = True
    )

  def llm_reranking(self, query):
    docs = self.multiquery_retriever.invoke(query)

    reranker = LLMRerank2()
    reranked_docs = reranker.rerank(query, docs, self.final_k)

    # id 매핑
    idx_to_id = {str(i): getattr(doc, "id", "None") for i, doc in enumerate(docs)}

    #context = "\n\n".join(f"[문서 ID: {getattr(doc, "id", None)}\n{doc.page_content}" for doc in reranked_docs)
    context = "\n\n".join(f"[[{i}]]\n{doc.page_content}" for i, doc in enumerate(reranked_docs)) # reranked docs 순서의 인덱싱 (점수 순)
    print(context)

    return context, reranked_docs



  def generate_answer(self, query):
    context, reranked_docs = self.llm_reranking(query)

    prompt_template = """
    너는 회계, 세법 전문가야. 아래의 context를 근거로 다음 규칙에 따라 질문에 답변해.

    [규칙]
    1. 결론: 질문에 대한 답은 한 문장으로 먼저 제시 (ex. "납부할 세액은 1,000,000원입니다." "해당 항목은 익금산입 대상입니다.")
    2. 출처는 context에등장하는 [문서 ID: ...]의 값만 그대로 복사해서 사용. (요약, 생략 불가)

    [문맥]
    {context}

    [질문]
    {question}

    <출력 형식>
    [답변]
    1. 결론: ...
    2. 결론 도출 과정: ...

    [출처]
    ["문서 ID1", "문서 ID2", ...]
    - 답변 생성에 사용한 문서의 ID만 작성
    - 1 ~ {final_k}개의 문서 ID 작성
    """

    prompt = PromptTemplate(input_variables = ["context", "question", "final_k"], template = prompt_template)

    chain = prompt | self.llm | StrOutputParser()

    answer = chain.invoke({"context": context, "question": query, "final_k": self.final_k})

    return answer, reranked_docs

  def generate_answer2(self, query):
    context, reranked_docs = self.llm_reranking(query)

    prompt_template = """
    너는 세법 전문가야. 아래의 문백을 바탕으로 질문에 답변해.
    반드시 아래의 JSON 형식을 지켜서 출력해

    [문맥]
    {context}

    [질문]
    {question}

    [출력 형식-JSON]
    {{
      "answer": "질문에 대한 답변 (결론 선제시, 논리적 근거 설명)",
      "used_ids": ["0", "2"]
    }}
    """

    prompt = PromptTemplate(input_variables = ["context", "question"], template = prompt_template)
    chain = prompt | self.llm | JsonOutputParser()
    answer = chain.invoke({"context": context, "question": query})

    return answer, reranked_docs

  def strip_dot(self, text):
    if not text:
      return ""
    return text.rstrip(".")

  def clean_content(self, text):
    if not text:
      return text

    text = text.strip()

    text = re.sub(r"^[①②③④⑤⑥⑦⑧⑨⑩]+\s*", "", text)
    text = re.sub(r"^\d+\.\s*", "", text)
    text = re.sub(r"^[가-힣]\.\s*", "", text)

    return text.strip()

  def make_reference(self, doc, max_law_chars):
    출처 = ""
    meta = doc.metadata
    law_name = meta.get("law_name")
    출처 += law_name
    조문번호 = meta.get("조문번호", "")
    출처 += f" {조문번호}조" if 조문번호 else ""
    항번호 = meta.get("항번호", "")
    출처 += f" {self.strip_dot(항번호)}항" if 항번호 else ""
    호번호 = meta.get("호번호", "")
    출처 += f" {self.strip_dot(호번호)}호" if 호번호 else ""
    목번호 = meta.get("목번호", "")
    출처 += f" {self.strip_dot(목번호)}목" if 목번호 else ""

    content = self.clean_content(doc.page_content)
    if len(content) > max_law_chars:
      content = content[:max_law_chars] + "..."

    return 출처, content


  def final_output(self,query, max_law_chars=400):
    answer, reranked_docs = self.generate_answer2(query)

    answer_text = answer.get("answer", "")
    used_ids = answer.get("used_ids", [])

    reference_list = []
    for i in used_ids:
      try:
        i = int(i)
        doc = reranked_docs[i]
        출처, content = self.make_reference(doc, max_law_chars)
        reference_list.append(f"{출처}: {content}")
      except (IndexError, ValueError):
        continue

    final_output = answer_text + "\n\n[근거 법령 및 본문]\n" + "\n\n".join(reference_list)

    return final_output

# %%
query = "예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?"

print(MultiQueryPipeline(prompt_multi_query, llm, vectorstore).final_output(query))
# Out:
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "question": "예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?"
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n질문을 세법 전문 용어를 사용해 3개의 서로 다른 query로 재작성해.\n각 쿼리는 반드시 줄바꿈으로 구분해.\n\n질문: 예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?"
#   ]
# }
# [llm/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] [1.31s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 예식장 등 사업자가 제3자(개인 미용실 등)와 일괄계약을 체결하고 그 대가를 수취한 경우, 해당 금액은 부가가치세 과세표준에 포함되는지 여부와 관련하여 세법상 과세 여부를 어떻게 판단하나요?\n\n2. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수령하는 경우, 이와 같은 수익금의 과세처리 및 세금계산서 발행 의무는 어떻게 규정되어 있나요?\n\n3. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수취하는 경우, 해당 거래에 대한 부가가치세 신고 시 세법상 적절한 과세처리 방법과 세액계산 기준은 무엇인가요?",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 예식장 등 사업자가 제3자(개인 미용실 등)와 일괄계약을 체결하고 그 대가를 수취한 경우, 해당 금액은 부가가치세 과세표준에 포함되는지 여부와 관련하여 세법상 과세 여부를 어떻게 판단하나요?\n\n2. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수령하는 경우, 이와 같은 수익금의 과세처리 및 세금계산서 발행 의무는 어떻게 규정되어 있나요?\n\n3. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수취하는 경우, 해당 거래에 대한 부가가치세 신고 시 세법상 적절한 과세처리 방법과 세액계산 기준은 무엇인가요?",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 215,
#                 "prompt_tokens": 93,
#                 "total_tokens": 308,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_70fc5e01a5",
#               "id": "chatcmpl-D6XmNoZ8zI05hWUeQuaaz7l7yaL2G",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c372c-7904-7e63-b775-2e5b4d316d9b-0",
#             "usage_metadata": {
#               "input_tokens": 93,
#               "output_tokens": 215,
#               "total_tokens": 308,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 215,
#       "prompt_tokens": 93,
#       "total_tokens": 308,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_70fc5e01a5",
#     "id": "chatcmpl-D6XmNoZ8zI05hWUeQuaaz7l7yaL2G",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] s] Exiting Parser run with output:
# {
#   "output": [
#     "1. 예식장 등 사업자가 제3자(개인 미용실 등)와 일괄계약을 체결하고 그 대가를 수취한 경우, 해당 금액은 부가가치세 과세표준에 포함되는지 여부와 관련하여 세법상 과세 여부를 어떻게 판단하나요?",
#     "2. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수령하는 경우, 이와 같은 수익금의 과세처리 및 세금계산서 발행 의무는 어떻게 규정되어 있나요?",
#     "3. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수취하는 경우, 해당 거래에 대한 부가가치세 신고 시 세법상 적절한 과세처리 방법과 세액계산 기준은 무엇인가요?"
#   ]
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence] [1.31s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 예식장 등 사업자가 제3자(개인 미용실 등)와 일괄계약을 체결하고 그 대가를 수취한 경우, 해당 금액은 부가가치세 과세표준에 포함되는지 여부와 관련하여 세법상 과세 여부를 어떻게 판단하나요?",
#     "2. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수령하는 경우, 이와 같은 수익금의 과세처리 및 세금계산서 발행 의무는 어떻게 규정되어 있나요?",
#     "3. 예식장 등 사업자가 제3자 용역 제공자(개인 미용실 등)와 일괄계약을 체결하고 그 대금을 수취하는 경우, 해당 거래에 대한 부가가치세 신고 시 세법상 적절한 과세처리 방법과 세액계산 기준은 무엇인가요?"
#   ]
# }
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?",
#   "docs": "[문서 ID: 0] 2. 개인의 양도소득금액을 과세표준으로 하여 과세된 세의 부가세액...\n[문서 ID: 1] 2. 법인의 소득 등을 과세표준으로 하여 과세된 세의 부가세액...\n[문서 ID: 2] 1. 사업수입금액에서 다음 각목의 금액을 공제한 금액을 과세표준으로 하여 그 세액을 결정 또는 경정하는 방법. 이 경우 공제할 금액이 사업수입금액을 초과하는 경우에는 그 초과금액은 없는 것으로 본다....\n[문서 ID: 3] ②각 사업연도의 소득에 대한 법인세의 과세표준을 계산할 때 법 제13조제1항제1호에 따라 공제할 결손금에는 법인세의 과세표준과 세액을 추계결정 또는 경정함에 따라 법 제68조에 따라 공제되지 아니한 이월결손금을 포함한다. <개정 2003.3.26, 2019.3.20>...\n[문서 ID: 4] 3. 사업의 양수에 따른 대가의 가액과 부가가치세액...\n[문서 ID: 5] 1. 개인의 소득금액을 과세표준으로 하여 과세된 세액과 그 부가세액...\n[문서 ID: 6] 3. 법인의 소득 등을 과세표준으로 하여 과세된 세와 동일한 세목에 해당하는 것으로서 소득외의 수익금액 기타 이에 준하는 것을 과세표준으로 하여 과세된 세액...\n[문서 ID: 7] ② 법 제42조제1항 표 외의 부분에서 \"대통령령으로 정하는 금액\"이란 해당 과세기간에 해당 사업자가 면세농산물등과 관련하여 공급한 과세표준(이하 이 항에서 \"과세표준\"이라 한다)에 100분의 30(개인사업자에 대해서는 과세표준이 2억원 이하인 경우에는 100분의 50, 과세표준이 2억원 초과인 경우에는 100분의 40)을 곱하여 계산한 금액을 말한다. 다만, 2027년 12월 31일까지는 사업자별로 매입세액으로서 공제할 수 있는 금액의 한도를 다음 각 호의 구분에 따라 계산한 금액으로 한다. <신설 2015.2.3, 2016.2.17, 2017.2.7, 2018.2.13, 2018.9.28, 2020.2.11, 2022.2.15, 2022.6.30, 2023.12.26, 2025.11.28>...\n[문서 ID: 8] ④ 제3항에 따라 매입세액에서 대손세액에 해당하는 금액을 뺀(관할 세무서장이 결정 또는 경정한 경우를 포함한다) 해당 사업자가 대손금액의 전부 또는 일부를 변제한 경우에는 대통령령으로 정하는 바에 따라 변제한 대손금액에 관련된 대손세액에 해당하는 금액을 변제한 날이 속하는 과세기간의 매입세액에 더한다....\n[문서 ID: 9] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 10] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 11] ① 사업자가 법 제39조제1항제7호에 따라 매입세액이 공제되지 아니한 감가상각자산을 과세사업에 사용하거나 소비하는 경우 법 제43조에 따라 공제되는 세액은 다음 각 호의 계산식에 따라 계산한 금액으로 한다. 이 경우 경과된 과세기간의 수에 관하여는 제66조제2항 후단을 준용한다....\n[문서 ID: 12] ② 세관장은 「관세법」에 따라 과세표준 또는 세액을 결정 또는 경정하기 전에 같은 법 제28조제2항, 제38조의2제1항ㆍ제2항, 제38조의3제1항부터 제3항까지, 제38조의4제1항, 제46조, 제47조, 제106조 및 제106조의2에 따라 부가가치세를 납부받거나 징수 또는 환급하는 경우에는 법 제35조제2항에 따라 수입자에게 수정한 수입세금계산서를 발급하여야 한다. <개정 2014.2.21, 2023.2.28>...\n[문서 ID: 13] 3. 법 제42조제3항제3호의 주식등의 경우에는 사업연도종료일 현재 시가(주식등의 발행법인별로 보유주식총액을 시가로 평가한 가액이 1천원 이하인 경우에는 1천원으로 한다)로 평가한 가액...\n[문서 ID: 14] ② 사업자가 법 제43조에 따라 매입세액이 공제되지 아니한 감가상각자산을 과세사업과 면세사업등에 공통으로 사용하거나 소비하는 경우에 공제되는 세액은 다음 각 호의 계산식에 따라 계산한 금액으로 하되, 그 과세사업에 의한 과세공급가액이 총공급가액 중 5퍼센트 미만일 때에는 공제세액이 없는 것으로 본다. 이 경우 경과된 과세기간의 수에 관하여는 제66조제2항 후단을 준용한다....\n[문서 ID: 15] ③「부가가치세법」 제36조제1항제2호를 적용받는 사업자가 부가가치세가 과세되는 재화 또는 용역을 공급하는 때에는 제1항 및 제2항 단서의 규정에 불구하고 계산서를 발급할 수 없으며, 영수증을 발급하여야 한다. <신설 1999.12.31, 2005.2.19, 2013.2.15, 2013.6.28, 2023.2.28>...\n[문서 ID: 16] 2. 기준경비율 또는 단순경비율이 결정되지 아니하였거나 천재ㆍ지변 기타 불가항력으로 장부 기타 증빙서류가 멸실된 때에는 기장이 가장 정확하다고 인정되는 동일업종의 다른 사업자의 소득금액을 참작하여 그 소득금액을 결정 또는 경정하는 방법. 다만, 동일업종의 다른 사업자가 없는 경우로서 과세표준확정신고후에 장부등이 멸실된 때에는 법 제70조의 규정에 의한 신고서 및 그 첨부서류에 의하고 과세표준확정신고전에 장부등이 멸실된 때에는 직전과세기간의 소득률에 의하여 소득금액을 결정 또는 경정한다....\n[문서 ID: 17] ① 법 제53조의3제1항제1호의 과세표준계산방법을 적용하는 경우 손금으로 계상한 경우에만 각 사업연도의 소득금액을 계산할 때 손금에 산입하는 항목은 원화재무제표의 금액을 기준으로 손금 계상액을 산정한다....\n[문서 ID: 18] ③ 일반과세자가 간이과세자로 변경되는 경우에 해당 사업자는 다음 각 호의 방법에 따라 계산한 금액(이하 \"재고납부세액\"이라 한다)을 납부세액에 더하여 납부해야 한다. 이 경우 제3호와 제4호에 따른 경과된 과세기간의 수에 관하여는 제66조제2항 후단 및 같은 조 제5항을 준용한다. <개정 2021.2.17>...\n[문서 ID: 19] ① 각 연결사업연도의 소득에 대한 법인세는 제76조의13에 따른 과세표준에 제55조제1항의 세율을 적용하여 계산한 금액(이하 이 장에서 \"연결산출세액\"이라 한다)으로 한다....\n[문서 ID: 20] 3. 제2호 외의 사업을 경영하는 개인사업자는 다음 각 목의 구분에 따라 계산한 금액에 공제율을 곱한 금액...\n[문서 ID: 21] 1. 법인사업자: 과세표준에 100분의 50을 곱하여 계산한 금액에 공제율을 곱한 금액...\n[문서 ID: 22] 3. 제1호 및 제2호의 자산으로서 그 취득가액이 불분명한 자산과 제1호 및 제2호의 자산 외의 자산은 해당 자산의 취득 당시의 재정경제부령이 정하는 시가에 취득세ㆍ등록면허세 기타 부대비용을 가산한 금액...\n[문서 ID: 23] ⑫법 제120조에 따른 법인이 합병ㆍ분할 또는 해산함으로써 법 제84조ㆍ제85조 또는 제87조에 따라 과세표준을 신고ㆍ결정 또는 경정한 경우 법 제75조의7에 따른 지급금액은 합병등기일ㆍ분할등기일 또는 해산등기일까지 제출하여야 하는 금액으로 한다. <개정 2013.2.15, 2019.2.12, 2021.5.4>...\n[문서 ID: 24] ①사업자는 부가가치세가 과세되는 재화 또는 용역을 공급하고 외상매출금이나 그 밖의 매출채권(부가가치세를 포함한 것을 말한다)의 전부 또는 일부가 공급을 받은 자의 파산ㆍ강제집행이나 그 밖에 대통령령으로 정하는 사유로 대손되어 회수할 수 없는 경우에는 다음의 계산식에 따라 계산한 금액(이하 \"대손세액\"이라 한다)을 그 대손이 확정된 날이 속하는 과세기간의 매출세액에서 뺄 수 있다. 다만, 그 사업자가 대손되어 회수할 수 없는 금액(이하 \"대손금액\"이라 한다)의 전부 또는 일부를 회수한 경우에는 회수한 대손금액에 관련된 대손세액을 회수한 날이 속하는 과세기간의 매출세액에 더한다.\n \n 대손세액 = 대손금액 × 110분의 10...\n[문서 ID: 25] ⑤ 전자세금계산서를 발급하여야 하는 사업자가 아닌 사업자도 제2항 및 제3항에 따라 전자세금계산서를 발급하고 전자세금계산서 발급명세를 전송할 수 있다....\n[문서 ID: 26] ④ 제1항 및 제2항에도 불구하고 영수증을 발급하는 사업자는 금전등록기를 설치하여 영수증을 대신하여 공급대가를 적은 계산서를 발급할 수 있다. 이 ...
#   "top_k": 10
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "query": "예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?",
#   "docs": "[문서 ID: 0] 2. 개인의 양도소득금액을 과세표준으로 하여 과세된 세의 부가세액...\n[문서 ID: 1] 2. 법인의 소득 등을 과세표준으로 하여 과세된 세의 부가세액...\n[문서 ID: 2] 1. 사업수입금액에서 다음 각목의 금액을 공제한 금액을 과세표준으로 하여 그 세액을 결정 또는 경정하는 방법. 이 경우 공제할 금액이 사업수입금액을 초과하는 경우에는 그 초과금액은 없는 것으로 본다....\n[문서 ID: 3] ②각 사업연도의 소득에 대한 법인세의 과세표준을 계산할 때 법 제13조제1항제1호에 따라 공제할 결손금에는 법인세의 과세표준과 세액을 추계결정 또는 경정함에 따라 법 제68조에 따라 공제되지 아니한 이월결손금을 포함한다. <개정 2003.3.26, 2019.3.20>...\n[문서 ID: 4] 3. 사업의 양수에 따른 대가의 가액과 부가가치세액...\n[문서 ID: 5] 1. 개인의 소득금액을 과세표준으로 하여 과세된 세액과 그 부가세액...\n[문서 ID: 6] 3. 법인의 소득 등을 과세표준으로 하여 과세된 세와 동일한 세목에 해당하는 것으로서 소득외의 수익금액 기타 이에 준하는 것을 과세표준으로 하여 과세된 세액...\n[문서 ID: 7] ② 법 제42조제1항 표 외의 부분에서 \"대통령령으로 정하는 금액\"이란 해당 과세기간에 해당 사업자가 면세농산물등과 관련하여 공급한 과세표준(이하 이 항에서 \"과세표준\"이라 한다)에 100분의 30(개인사업자에 대해서는 과세표준이 2억원 이하인 경우에는 100분의 50, 과세표준이 2억원 초과인 경우에는 100분의 40)을 곱하여 계산한 금액을 말한다. 다만, 2027년 12월 31일까지는 사업자별로 매입세액으로서 공제할 수 있는 금액의 한도를 다음 각 호의 구분에 따라 계산한 금액으로 한다. <신설 2015.2.3, 2016.2.17, 2017.2.7, 2018.2.13, 2018.9.28, 2020.2.11, 2022.2.15, 2022.6.30, 2023.12.26, 2025.11.28>...\n[문서 ID: 8] ④ 제3항에 따라 매입세액에서 대손세액에 해당하는 금액을 뺀(관할 세무서장이 결정 또는 경정한 경우를 포함한다) 해당 사업자가 대손금액의 전부 또는 일부를 변제한 경우에는 대통령령으로 정하는 바에 따라 변제한 대손금액에 관련된 대손세액에 해당하는 금액을 변제한 날이 속하는 과세기간의 매입세액에 더한다....\n[문서 ID: 9] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 10] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 11] ① 사업자가 법 제39조제1항제7호에 따라 매입세액이 공제되지 아니한 감가상각자산을 과세사업에 사용하거나 소비하는 경우 법 제43조에 따라 공제되는 세액은 다음 각 호의 계산식에 따라 계산한 금액으로 한다. 이 경우 경과된 과세기간의 수에 관하여는 제66조제2항 후단을 준용한다....\n[문서 ID: 12] ② 세관장은 「관세법」에 따라 과세표준 또는 세액을 결정 또는 경정하기 전에 같은 법 제28조제2항, 제38조의2제1항ㆍ제2항, 제38조의3제1항부터 제3항까지, 제38조의4제1항, 제46조, 제47조, 제106조 및 제106조의2에 따라 부가가치세를 납부받거나 징수 또는 환급하는 경우에는 법 제35조제2항에 따라 수입자에게 수정한 수입세금계산서를 발급하여야 한다. <개정 2014.2.21, 2023.2.28>...\n[문서 ID: 13] 3. 법 제42조제3항제3호의 주식등의 경우에는 사업연도종료일 현재 시가(주식등의 발행법인별로 보유주식총액을 시가로 평가한 가액이 1천원 이하인 경우에는 1천원으로 한다)로 평가한 가액...\n[문서 ID: 14] ② 사업자가 법 제43조에 따라 매입세액이 공제되지 아니한 감가상각자산을 과세사업과 면세사업등에 공통으로 사용하거나 소비하는 경우에 공제되는 세액은 다음 각 호의 계산식에 따라 계산한 금액으로 하되, 그 과세사업에 의한 과세공급가액이 총공급가액 중 5퍼센트 미만일 때에는 공제세액이 없는 것으로 본다. 이 경우 경과된 과세기간의 수에 관하여는 제66조제2항 후단을 준용한다....\n[문서 ID: 15] ③「부가가치세법」 제36조제1항제2호를 적용받는 사업자가 부가가치세가 과세되는 재화 또는 용역을 공급하는 때에는 제1항 및 제2항 단서의 규정에 불구하고 계산서를 발급할 수 없으며, 영수증을 발급하여야 한다. <신설 1999.12.31, 2005.2.19, 2013.2.15, 2013.6.28, 2023.2.28>...\n[문서 ID: 16] 2. 기준경비율 또는 단순경비율이 결정되지 아니하였거나 천재ㆍ지변 기타 불가항력으로 장부 기타 증빙서류가 멸실된 때에는 기장이 가장 정확하다고 인정되는 동일업종의 다른 사업자의 소득금액을 참작하여 그 소득금액을 결정 또는 경정하는 방법. 다만, 동일업종의 다른 사업자가 없는 경우로서 과세표준확정신고후에 장부등이 멸실된 때에는 법 제70조의 규정에 의한 신고서 및 그 첨부서류에 의하고 과세표준확정신고전에 장부등이 멸실된 때에는 직전과세기간의 소득률에 의하여 소득금액을 결정 또는 경정한다....\n[문서 ID: 17] ① 법 제53조의3제1항제1호의 과세표준계산방법을 적용하는 경우 손금으로 계상한 경우에만 각 사업연도의 소득금액을 계산할 때 손금에 산입하는 항목은 원화재무제표의 금액을 기준으로 손금 계상액을 산정한다....\n[문서 ID: 18] ③ 일반과세자가 간이과세자로 변경되는 경우에 해당 사업자는 다음 각 호의 방법에 따라 계산한 금액(이하 \"재고납부세액\"이라 한다)을 납부세액에 더하여 납부해야 한다. 이 경우 제3호와 제4호에 따른 경과된 과세기간의 수에 관하여는 제66조제2항 후단 및 같은 조 제5항을 준용한다. <개정 2021.2.17>...\n[문서 ID: 19] ① 각 연결사업연도의 소득에 대한 법인세는 제76조의13에 따른 과세표준에 제55조제1항의 세율을 적용하여 계산한 금액(이하 이 장에서 \"연결산출세액\"이라 한다)으로 한다....\n[문서 ID: 20] 3. 제2호 외의 사업을 경영하는 개인사업자는 다음 각 목의 구분에 따라 계산한 금액에 공제율을 곱한 금액...\n[문서 ID: 21] 1. 법인사업자: 과세표준에 100분의 50을 곱하여 계산한 금액에 공제율을 곱한 금액...\n[문서 ID: 22] 3. 제1호 및 제2호의 자산으로서 그 취득가액이 불분명한 자산과 제1호 및 제2호의 자산 외의 자산은 해당 자산의 취득 당시의 재정경제부령이 정하는 시가에 취득세ㆍ등록면허세 기타 부대비용을 가산한 금액...\n[문서 ID: 23] ⑫법 제120조에 따른 법인이 합병ㆍ분할 또는 해산함으로써 법 제84조ㆍ제85조 또는 제87조에 따라 과세표준을 신고ㆍ결정 또는 경정한 경우 법 제75조의7에 따른 지급금액은 합병등기일ㆍ분할등기일 또는 해산등기일까지 제출하여야 하는 금액으로 한다. <개정 2013.2.15, 2019.2.12, 2021.5.4>...\n[문서 ID: 24] ①사업자는 부가가치세가 과세되는 재화 또는 용역을 공급하고 외상매출금이나 그 밖의 매출채권(부가가치세를 포함한 것을 말한다)의 전부 또는 일부가 공급을 받은 자의 파산ㆍ강제집행이나 그 밖에 대통령령으로 정하는 사유로 대손되어 회수할 수 없는 경우에는 다음의 계산식에 따라 계산한 금액(이하 \"대손세액\"이라 한다)을 그 대손이 확정된 날이 속하는 과세기간의 매출세액에서 뺄 수 있다. 다만, 그 사업자가 대손되어 회수할 수 없는 금액(이하 \"대손금액\"이라 한다)의 전부 또는 일부를 회수한 경우에는 회수한 대손금액에 관련된 대손세액을 회수한 날이 속하는 과세기간의 매출세액에 더한다.\n \n 대손세액 = 대손금액 × 110분의 10...\n[문서 ID: 25] ⑤ 전자세금계산서를 발급하여야 하는 사업자가 아닌 사업자도 제2항 및 제3항에 따라 전자세금계산서를 발급하고 전자세금계산서 발급명세를 전송할 수 있다....\n[문서 ID: 26] ④ 제1항 및 제2항에도 불구하고 영수증을 발급하는 사업자는 금전등록기를 설치하여 영수증을 대신하여 공급대가를 적은 계산서를 발급할 수 있다. 이 ...
#   "top_k": 10
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문 지식을 가진 reranking 모델이야.\n    아래 질문에 대해 문서들 중 답변 근거로 가장 적절하고 관련성 있는 상위 10개의 문서를 골라줘.\n    id는 반드시 제공된 [문서 번호] 숫자만 사용하고, 상위 10개의 문서에 대해 점수(0~100)을 매겨서 JSON 형식으로 답변해\n\n    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수\n    - 미세하게라도 점수에 차등을 둘 것\n    - 문서 간 비교를 하여 상대적인 점수를 계산할 것\n    \n    [질문]\n    예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?\n\n    [문서들]\n    [문서 ID: 0] 2. 개인의 양도소득금액을 과세표준으로 하여 과세된 세의 부가세액...\n[문서 ID: 1] 2. 법인의 소득 등을 과세표준으로 하여 과세된 세의 부가세액...\n[문서 ID: 2] 1. 사업수입금액에서 다음 각목의 금액을 공제한 금액을 과세표준으로 하여 그 세액을 결정 또는 경정하는 방법. 이 경우 공제할 금액이 사업수입금액을 초과하는 경우에는 그 초과금액은 없는 것으로 본다....\n[문서 ID: 3] ②각 사업연도의 소득에 대한 법인세의 과세표준을 계산할 때 법 제13조제1항제1호에 따라 공제할 결손금에는 법인세의 과세표준과 세액을 추계결정 또는 경정함에 따라 법 제68조에 따라 공제되지 아니한 이월결손금을 포함한다. <개정 2003.3.26, 2019.3.20>...\n[문서 ID: 4] 3. 사업의 양수에 따른 대가의 가액과 부가가치세액...\n[문서 ID: 5] 1. 개인의 소득금액을 과세표준으로 하여 과세된 세액과 그 부가세액...\n[문서 ID: 6] 3. 법인의 소득 등을 과세표준으로 하여 과세된 세와 동일한 세목에 해당하는 것으로서 소득외의 수익금액 기타 이에 준하는 것을 과세표준으로 하여 과세된 세액...\n[문서 ID: 7] ② 법 제42조제1항 표 외의 부분에서 \"대통령령으로 정하는 금액\"이란 해당 과세기간에 해당 사업자가 면세농산물등과 관련하여 공급한 과세표준(이하 이 항에서 \"과세표준\"이라 한다)에 100분의 30(개인사업자에 대해서는 과세표준이 2억원 이하인 경우에는 100분의 50, 과세표준이 2억원 초과인 경우에는 100분의 40)을 곱하여 계산한 금액을 말한다. 다만, 2027년 12월 31일까지는 사업자별로 매입세액으로서 공제할 수 있는 금액의 한도를 다음 각 호의 구분에 따라 계산한 금액으로 한다. <신설 2015.2.3, 2016.2.17, 2017.2.7, 2018.2.13, 2018.9.28, 2020.2.11, 2022.2.15, 2022.6.30, 2023.12.26, 2025.11.28>...\n[문서 ID: 8] ④ 제3항에 따라 매입세액에서 대손세액에 해당하는 금액을 뺀(관할 세무서장이 결정 또는 경정한 경우를 포함한다) 해당 사업자가 대손금액의 전부 또는 일부를 변제한 경우에는 대통령령으로 정하는 바에 따라 변제한 대손금액에 관련된 대손세액에 해당하는 금액을 변제한 날이 속하는 과세기간의 매입세액에 더한다....\n[문서 ID: 9] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 10] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 11] ① 사업자가 법 제39조제1항제7호에 따라 매입세액이 공제되지 아니한 감가상각자산을 과세사업에 사용하거나 소비하는 경우 법 제43조에 따라 공제되는 세액은 다음 각 호의 계산식에 따라 계산한 금액으로 한다. 이 경우 경과된 과세기간의 수에 관하여는 제66조제2항 후단을 준용한다....\n[문서 ID: 12] ② 세관장은 「관세법」에 따라 과세표준 또는 세액을 결정 또는 경정하기 전에 같은 법 제28조제2항, 제38조의2제1항ㆍ제2항, 제38조의3제1항부터 제3항까지, 제38조의4제1항, 제46조, 제47조, 제106조 및 제106조의2에 따라 부가가치세를 납부받거나 징수 또는 환급하는 경우에는 법 제35조제2항에 따라 수입자에게 수정한 수입세금계산서를 발급하여야 한다. <개정 2014.2.21, 2023.2.28>...\n[문서 ID: 13] 3. 법 제42조제3항제3호의 주식등의 경우에는 사업연도종료일 현재 시가(주식등의 발행법인별로 보유주식총액을 시가로 평가한 가액이 1천원 이하인 경우에는 1천원으로 한다)로 평가한 가액...\n[문서 ID: 14] ② 사업자가 법 제43조에 따라 매입세액이 공제되지 아니한 감가상각자산을 과세사업과 면세사업등에 공통으로 사용하거나 소비하는 경우에 공제되는 세액은 다음 각 호의 계산식에 따라 계산한 금액으로 하되, 그 과세사업에 의한 과세공급가액이 총공급가액 중 5퍼센트 미만일 때에는 공제세액이 없는 것으로 본다. 이 경우 경과된 과세기간의 수에 관하여는 제66조제2항 후단을 준용한다....\n[문서 ID: 15] ③「부가가치세법」 제36조제1항제2호를 적용받는 사업자가 부가가치세가 과세되는 재화 또는 용역을 공급하는 때에는 제1항 및 제2항 단서의 규정에 불구하고 계산서를 발급할 수 없으며, 영수증을 발급하여야 한다. <신설 1999.12.31, 2005.2.19, 2013.2.15, 2013.6.28, 2023.2.28>...\n[문서 ID: 16] 2. 기준경비율 또는 단순경비율이 결정되지 아니하였거나 천재ㆍ지변 기타 불가항력으로 장부 기타 증빙서류가 멸실된 때에는 기장이 가장 정확하다고 인정되는 동일업종의 다른 사업자의 소득금액을 참작하여 그 소득금액을 결정 또는 경정하는 방법. 다만, 동일업종의 다른 사업자가 없는 경우로서 과세표준확정신고후에 장부등이 멸실된 때에는 법 제70조의 규정에 의한 신고서 및 그 첨부서류에 의하고 과세표준확정신고전에 장부등이 멸실된 때에는 직전과세기간의 소득률에 의하여 소득금액을 결정 또는 경정한다....\n[문서 ID: 17] ① 법 제53조의3제1항제1호의 과세표준계산방법을 적용하는 경우 손금으로 계상한 경우에만 각 사업연도의 소득금액을 계산할 때 손금에 산입하는 항목은 원화재무제표의 금액을 기준으로 손금 계상액을 산정한다....\n[문서 ID: 18] ③ 일반과세자가 간이과세자로 변경되는 경우에 해당 사업자는 다음 각 호의 방법에 따라 계산한 금액(이하 \"재고납부세액\"이라 한다)을 납부세액에 더하여 납부해야 한다. 이 경우 제3호와 제4호에 따른 경과된 과세기간의 수에 관하여는 제66조제2항 후단 및 같은 조 제5항을 준용한다. <개정 2021.2.17>...\n[문서 ID: 19] ① 각 연결사업연도의 소득에 대한 법인세는 제76조의13에 따른 과세표준에 제55조제1항의 세율을 적용하여 계산한 금액(이하 이 장에서 \"연결산출세액\"이라 한다)으로 한다....\n[문서 ID: 20] 3. 제2호 외의 사업을 경영하는 개인사업자는 다음 각 목의 구분에 따라 계산한 금액에 공제율을 곱한 금액...\n[문서 ID: 21] 1. 법인사업자: 과세표준에 100분의 50을 곱하여 계산한 금액에 공제율을 곱한 금액...\n[문서 ID: 22] 3. 제1호 및 제2호의 자산으로서 그 취득가액이 불분명한 자산과 제1호 및 제2호의 자산 외의 자산은 해당 자산의 취득 당시의 재정경제부령이 정하는 시가에 취득세ㆍ등록면허세 기타 부대비용을 가산한 금액...\n[문서 ID: 23] ⑫법 제120조에 따른 법인이 합병ㆍ분할 또는 해산함으로써 법 제84조ㆍ제85조 또는 제87조에 따라 과세표준을 신고ㆍ결정 또는 경정한 경우 법 제75조의7에 따른 지급금액은 합병등기일ㆍ분할등기일 또는 해산등기일까지 제출하여야 하는 금액으로 한다. <개정 2013.2.15, 2019.2.12, 2021.5.4>...\n[문서 ID: 24] ①사업자는 부가가치세가 과세되는 재화 또는 용역을 공급하고 외상매출금이나 그 밖의 매출채권(부가가치세를 포함한 것을 말한다)의 전부 또는 일부가 공급을 받은 자의 파산ㆍ강제집행이나 그 밖에 대통령령으로 정하는 사유로 대손되어 회수할 수 없는 경우에는 다음의 계산식에 따라 계산한 금액( ...
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [1.88s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"scores\": [\n    {\"id\": 4, \"score\": 92},\n    {\"id\": 48, \"score\": 88},\n    {\"id\": 73, \"score\": 85},\n    {\"id\": 75, \"score\": 83},\n    {\"id\": 70, \"score\": 81},\n    {\"id\": 74, \"score\": 80},\n    {\"id\": 44, \"score\": 78},\n    {\"id\": 45, \"score\": 76},\n    {\"id\": 66, \"score\": 74},\n    {\"id\": 68, \"score\": 72}\n  ]\n}",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"scores\": [\n    {\"id\": 4, \"score\": 92},\n    {\"id\": 48, \"score\": 88},\n    {\"id\": 73, \"score\": 85},\n    {\"id\": 75, \"score\": 83},\n    {\"id\": 70, \"score\": 81},\n    {\"id\": 74, \"score\": 80},\n    {\"id\": 44, \"score\": 78},\n    {\"id\": 45, \"score\": 76},\n    {\"id\": 66, \"score\": 74},\n    {\"id\": 68, \"score\": 72}\n  ]\n}",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 139,
#                 "prompt_tokens": 8696,
#                 "total_tokens": 8835,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_44848d1550",
#               "id": "chatcmpl-D6XmRa9WtntrEeXdMhcgWLcZ0c71Y",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c372c-85a5-7d50-b04d-8ea273f3b4a6-0",
#             "usage_metadata": {
#               "input_tokens": 8696,
#               "output_tokens": 139,
#               "total_tokens": 8835,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 139,
#       "prompt_tokens": 8696,
#       "total_tokens": 8835,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_44848d1550",
#     "id": "chatcmpl-D6XmRa9WtntrEeXdMhcgWLcZ0c71Y",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "scores": [
#     {
#       "id": 4,
#       "score": 92
#     },
#     {
#       "id": 48,
#       "score": 88
#     },
#     {
#       "id": 73,
#       "score": 85
#     },
#     {
#       "id": 75,
#       "score": 83
#     },
#     {
#       "id": 70,
#       "score": 81
#     },
#     {
#       "id": 74,
#       "score": 80
#     },
#     {
#       "id": 44,
#       "score": 78
#     },
#     {
#       "id": 45,
#       "score": 76
#     },
#     {
#       "id": 66,
#       "score": 74
#     },
#     {
#       "id": 68,
#       "score": 72
#     }
#   ]
# }
# [chain/end] [chain:RunnableSequence] [1.88s] Exiting Chain run with output:
# {
#   "scores": [
#     {
#       "id": 4,
#       "score": 92
#     },
#     {
#       "id": 48,
#       "score": 88
#     },
#     {
#       "id": 73,
#       "score": 85
#     },
#     {
#       "id": 75,
#       "score": 83
#     },
#     {
#       "id": 70,
#       "score": 81
#     },
#     {
#       "id": 74,
#       "score": 80
#     },
#     {
#       "id": 44,
#       "score": 78
#     },
#     {
#       "id": 45,
#       "score": 76
#     },
#     {
#       "id": 66,
#       "score": 74
#     },
#     {
#       "id": 68,
#       "score": 72
#     }
#   ]
# }
# [[0]]
# 3. 사업의 양수에 따른 대가의 가액과 부가가치세액
#
# [[1]]
# 3. 손익분배비율을 공동사업자 간에 약정된 내용과 다르게 신고하는 경우
#
# [[2]]
# ①사업자가 재화 또는 용역을 공급하는 때에는 다음 각 호의 사항이 적힌 계산서 2매를 작성하여 그 중 1매를 공급받는 자에게 발급하여야 한다. <개정 1996.12.31, 2013.2.15, 2015.2.3>
#
# [[3]]
# 2. 해당 비과세외국연예등법인에게 보수 또는 대가를 지급하는 자와 해당 비과세외국연예등법인 사이에 체결된 용역제공 관련 계약서
#
# [[4]]
# ① 사업자가 재화 또는 용역을 공급(부가가치세가 면제되는 재화 또는 용역의 공급은 제외한다)하는 경우에는 다음 각 호의 사항을 적은 계산서(이하 "세금계산서"라 한다)를 그 공급을 받는 자에게 발급하여야 한다.
#
# [[5]]
# 2. 소매업 또는 미용, 욕탕 및 유사 서비스업을 경영하는 자가 공급하는 재화 또는 용역. 다만, 소매업의 경우에는 공급받는 자가 세금계산서 발급을 요구하지 아니하는 경우로 한정한다.
#
# [[6]]
# ⑩ 법 제32조제5항에 따라 법인사업자 및 전자세금계산서 의무발급 개인사업자 외의 사업자도 제5항부터 제8항까지의 규정에 따라 전자세금계산서를 발급하고 전송할 수 있다. <개정 2018.2.13>
#
# [[7]]
# 마. 다른 사업자로부터 사업(용역을 공급하는 사업으로 한정한다. 이하 이 호에서 같다)을 위탁받아 수행하는 사업자가 위탁받은 사업의 수행에 필요한 비용을 사업을 위탁한 사업자로부터 지급받아 지출한 경우로서 해당 비용을 공급가액에 포함해야 함에도 불구하고 거래 당사자 간 계약에 따라 이를 공급가액에서 제외하여 세금계산서를 발급받은 경우
#
# [[8]]
# ③ 현금영수증가맹점으로 가입한 사업자는 사업과 관련하여 재화 또는 용역을 공급하고 그 상대방이 대금을 현금으로 지급한 후 현금영수증의 발급을 요청하는 경우에는 그 발급을 거부하거나 사실과 다르게 발급해서는 아니 된다.
#
# [[9]]
# 2. 통신판매업자가 판매를 대행 또는 중개하는 부가통신사업자를 통해 재화 또는 용역을 공급하고 부가통신사업자로부터 전자적으로 대금을 결제받는 경우(부가통신사업자가 법 제75조제1항 및 이 영 제121조제1항에 따라 제출하는 월별 거래 명세를 통해 그 결제 내역이 확인되는 경우만 해당한다)
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "context": "[[0]]\n3. 사업의 양수에 따른 대가의 가액과 부가가치세액\n\n[[1]]\n3. 손익분배비율을 공동사업자 간에 약정된 내용과 다르게 신고하는 경우\n\n[[2]]\n①사업자가 재화 또는 용역을 공급하는 때에는 다음 각 호의 사항이 적힌 계산서 2매를 작성하여 그 중 1매를 공급받는 자에게 발급하여야 한다. <개정 1996.12.31, 2013.2.15, 2015.2.3>\n\n[[3]]\n2. 해당 비과세외국연예등법인에게 보수 또는 대가를 지급하는 자와 해당 비과세외국연예등법인 사이에 체결된 용역제공 관련 계약서\n\n[[4]]\n① 사업자가 재화 또는 용역을 공급(부가가치세가 면제되는 재화 또는 용역의 공급은 제외한다)하는 경우에는 다음 각 호의 사항을 적은 계산서(이하 \"세금계산서\"라 한다)를 그 공급을 받는 자에게 발급하여야 한다.\n\n[[5]]\n2. 소매업 또는 미용, 욕탕 및 유사 서비스업을 경영하는 자가 공급하는 재화 또는 용역. 다만, 소매업의 경우에는 공급받는 자가 세금계산서 발급을 요구하지 아니하는 경우로 한정한다.\n\n[[6]]\n⑩ 법 제32조제5항에 따라 법인사업자 및 전자세금계산서 의무발급 개인사업자 외의 사업자도 제5항부터 제8항까지의 규정에 따라 전자세금계산서를 발급하고 전송할 수 있다. <개정 2018.2.13>\n\n[[7]]\n마. 다른 사업자로부터 사업(용역을 공급하는 사업으로 한정한다. 이하 이 호에서 같다)을 위탁받아 수행하는 사업자가 위탁받은 사업의 수행에 필요한 비용을 사업을 위탁한 사업자로부터 지급받아 지출한 경우로서 해당 비용을 공급가액에 포함해야 함에도 불구하고 거래 당사자 간 계약에 따라 이를 공급가액에서 제외하여 세금계산서를 발급받은 경우\n\n[[8]]\n③ 현금영수증가맹점으로 가입한 사업자는 사업과 관련하여 재화 또는 용역을 공급하고 그 상대방이 대금을 현금으로 지급한 후 현금영수증의 발급을 요청하는 경우에는 그 발급을 거부하거나 사실과 다르게 발급해서는 아니 된다.\n\n[[9]]\n2. 통신판매업자가 판매를 대행 또는 중개하는 부가통신사업자를 통해 재화 또는 용역을 공급하고 부가통신사업자로부터 전자적으로 대금을 결제받는 경우(부가통신사업자가 법 제75조제1항 및 이 영 제121조제1항에 따라 제출하는 월별 거래 명세를 통해 그 결제 내역이 확인되는 경우만 해당한다)",
#   "question": "예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?"
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "context": "[[0]]\n3. 사업의 양수에 따른 대가의 가액과 부가가치세액\n\n[[1]]\n3. 손익분배비율을 공동사업자 간에 약정된 내용과 다르게 신고하는 경우\n\n[[2]]\n①사업자가 재화 또는 용역을 공급하는 때에는 다음 각 호의 사항이 적힌 계산서 2매를 작성하여 그 중 1매를 공급받는 자에게 발급하여야 한다. <개정 1996.12.31, 2013.2.15, 2015.2.3>\n\n[[3]]\n2. 해당 비과세외국연예등법인에게 보수 또는 대가를 지급하는 자와 해당 비과세외국연예등법인 사이에 체결된 용역제공 관련 계약서\n\n[[4]]\n① 사업자가 재화 또는 용역을 공급(부가가치세가 면제되는 재화 또는 용역의 공급은 제외한다)하는 경우에는 다음 각 호의 사항을 적은 계산서(이하 \"세금계산서\"라 한다)를 그 공급을 받는 자에게 발급하여야 한다.\n\n[[5]]\n2. 소매업 또는 미용, 욕탕 및 유사 서비스업을 경영하는 자가 공급하는 재화 또는 용역. 다만, 소매업의 경우에는 공급받는 자가 세금계산서 발급을 요구하지 아니하는 경우로 한정한다.\n\n[[6]]\n⑩ 법 제32조제5항에 따라 법인사업자 및 전자세금계산서 의무발급 개인사업자 외의 사업자도 제5항부터 제8항까지의 규정에 따라 전자세금계산서를 발급하고 전송할 수 있다. <개정 2018.2.13>\n\n[[7]]\n마. 다른 사업자로부터 사업(용역을 공급하는 사업으로 한정한다. 이하 이 호에서 같다)을 위탁받아 수행하는 사업자가 위탁받은 사업의 수행에 필요한 비용을 사업을 위탁한 사업자로부터 지급받아 지출한 경우로서 해당 비용을 공급가액에 포함해야 함에도 불구하고 거래 당사자 간 계약에 따라 이를 공급가액에서 제외하여 세금계산서를 발급받은 경우\n\n[[8]]\n③ 현금영수증가맹점으로 가입한 사업자는 사업과 관련하여 재화 또는 용역을 공급하고 그 상대방이 대금을 현금으로 지급한 후 현금영수증의 발급을 요청하는 경우에는 그 발급을 거부하거나 사실과 다르게 발급해서는 아니 된다.\n\n[[9]]\n2. 통신판매업자가 판매를 대행 또는 중개하는 부가통신사업자를 통해 재화 또는 용역을 공급하고 부가통신사업자로부터 전자적으로 대금을 결제받는 경우(부가통신사업자가 법 제75조제1항 및 이 영 제121조제1항에 따라 제출하는 월별 거래 명세를 통해 그 결제 내역이 확인되는 경우만 해당한다)",
#   "question": "예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?"
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문가야. 아래의 문백을 바탕으로 질문에 답변해.\n    반드시 아래의 JSON 형식을 지켜서 출력해\n\n    [문맥]\n    [[0]]\n3. 사업의 양수에 따른 대가의 가액과 부가가치세액\n\n[[1]]\n3. 손익분배비율을 공동사업자 간에 약정된 내용과 다르게 신고하는 경우\n\n[[2]]\n①사업자가 재화 또는 용역을 공급하는 때에는 다음 각 호의 사항이 적힌 계산서 2매를 작성하여 그 중 1매를 공급받는 자에게 발급하여야 한다. <개정 1996.12.31, 2013.2.15, 2015.2.3>\n\n[[3]]\n2. 해당 비과세외국연예등법인에게 보수 또는 대가를 지급하는 자와 해당 비과세외국연예등법인 사이에 체결된 용역제공 관련 계약서\n\n[[4]]\n① 사업자가 재화 또는 용역을 공급(부가가치세가 면제되는 재화 또는 용역의 공급은 제외한다)하는 경우에는 다음 각 호의 사항을 적은 계산서(이하 \"세금계산서\"라 한다)를 그 공급을 받는 자에게 발급하여야 한다.\n\n[[5]]\n2. 소매업 또는 미용, 욕탕 및 유사 서비스업을 경영하는 자가 공급하는 재화 또는 용역. 다만, 소매업의 경우에는 공급받는 자가 세금계산서 발급을 요구하지 아니하는 경우로 한정한다.\n\n[[6]]\n⑩ 법 제32조제5항에 따라 법인사업자 및 전자세금계산서 의무발급 개인사업자 외의 사업자도 제5항부터 제8항까지의 규정에 따라 전자세금계산서를 발급하고 전송할 수 있다. <개정 2018.2.13>\n\n[[7]]\n마. 다른 사업자로부터 사업(용역을 공급하는 사업으로 한정한다. 이하 이 호에서 같다)을 위탁받아 수행하는 사업자가 위탁받은 사업의 수행에 필요한 비용을 사업을 위탁한 사업자로부터 지급받아 지출한 경우로서 해당 비용을 공급가액에 포함해야 함에도 불구하고 거래 당사자 간 계약에 따라 이를 공급가액에서 제외하여 세금계산서를 발급받은 경우\n\n[[8]]\n③ 현금영수증가맹점으로 가입한 사업자는 사업과 관련하여 재화 또는 용역을 공급하고 그 상대방이 대금을 현금으로 지급한 후 현금영수증의 발급을 요청하는 경우에는 그 발급을 거부하거나 사실과 다르게 발급해서는 아니 된다.\n\n[[9]]\n2. 통신판매업자가 판매를 대행 또는 중개하는 부가통신사업자를 통해 재화 또는 용역을 공급하고 부가통신사업자로부터 전자적으로 대금을 결제받는 경우(부가통신사업자가 법 제75조제1항 및 이 영 제121조제1항에 따라 제출하는 월별 거래 명세를 통해 그 결제 내역이 확인되는 경우만 해당한다)\n\n    [질문]\n    예식장 등에서 다른 사업자가 제공하는 용역(예: 개인 미용실)에 대하여 소비자와 일괄계약을 체결하고 그 대금을 지급받은 경우는 어떻게 하나요?\n\n    [출력 형식-JSON]\n    {\n      \"answer\": \"질문에 대한 답변 (결론 선제시, 논리적 근거 설명)\",\n      \"used_ids\": [\"0\", \"2\"]\n    }"
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [1.45s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"answer\": \"이 경우, 예식장 등에서 일괄계약을 체결하고 대금을 지급받았을 때, 해당 용역이 별도로 공급된 것으로 간주되어 별도의 세금계산서 발급이 필요할 수 있으며, 공급가액 산정 시 용역별로 구분하여 신고하는 것이 바람직하다. 이는 사업자가 공급하는 용역에 대해 별도로 세금계산서를 발급해야 하는 규정(예: [[2]]), 그리고 용역 제공 계약서에 따른 거래 내용이 명확히 구분되어야 하는 점에 근거한다.\",\n  \"used_ids\": [\"0\", \"2\"]\n}",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"answer\": \"이 경우, 예식장 등에서 일괄계약을 체결하고 대금을 지급받았을 때, 해당 용역이 별도로 공급된 것으로 간주되어 별도의 세금계산서 발급이 필요할 수 있으며, 공급가액 산정 시 용역별로 구분하여 신고하는 것이 바람직하다. 이는 사업자가 공급하는 용역에 대해 별도로 세금계산서를 발급해야 하는 규정(예: [[2]]), 그리고 용역 제공 계약서에 따른 거래 내용이 명확히 구분되어야 하는 점에 근거한다.\",\n  \"used_ids\": [\"0\", \"2\"]\n}",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 145,
#                 "prompt_tokens": 820,
#                 "total_tokens": 965,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_70fc5e01a5",
#               "id": "chatcmpl-D6XmSRjSBrlp1CFLJO2IsVMmTt99Y",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c372c-8cfc-7da2-9748-c09c3d0ba474-0",
#             "usage_metadata": {
#               "input_tokens": 820,
#               "output_tokens": 145,
#               "total_tokens": 965,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 145,
#       "prompt_tokens": 820,
#       "total_tokens": 965,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_70fc5e01a5",
#     "id": "chatcmpl-D6XmSRjSBrlp1CFLJO2IsVMmTt99Y",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "answer": "이 경우, 예식장 등에서 일괄계약을 체결하고 대금을 지급받았을 때, 해당 용역이 별도로 공급된 것으로 간주되어 별도의 세금계산서 발급이 필요할 수 있으며, 공급가액 산정 시 용역별로 구분하여 신고하는 것이 바람직하다. 이는 사업자가 공급하는 용역에 대해 별도로 세금계산서를 발급해야 하는 규정(예: [[2]]), 그리고 용역 제공 계약서에 따른 거래 내용이 명확히 구분되어야 하는 점에 근거한다.",
#   "used_ids": [
#     "0",
#     "2"
#   ]
# }
# [chain/end] [chain:RunnableSequence] [1.45s] Exiting Chain run with output:
# {
#   "answer": "이 경우, 예식장 등에서 일괄계약을 체결하고 대금을 지급받았을 때, 해당 용역이 별도로 공급된 것으로 간주되어 별도의 세금계산서 발급이 필요할 수 있으며, 공급가액 산정 시 용역별로 구분하여 신고하는 것이 바람직하다. 이는 사업자가 공급하는 용역에 대해 별도로 세금계산서를 발급해야 하는 규정(예: [[2]]), 그리고 용역 제공 계약서에 따른 거래 내용이 명확히 구분되어야 하는 점에 근거한다.",
#   "used_ids": [
#     "0",
#     "2"
#   ]
# }
# 이 경우, 예식장 등에서 일괄계약을 체결하고 대금을 지급받았을 때, 해당 용역이 별도로 공급된 것으로 간주되어 별도의 세금계산서 발급이 필요할 수 있으며, 공급가액 산정 시 용역별로 구분하여 신고하는 것이 바람직하다. 이는 사업자가 공급하는 용역에 대해 별도로 세금계산서를 발급해야 하는 규정(예: [[2]]), 그리고 용역 제공 계약서에 따른 거래 내용이 명확히 구분되어야 하는 점에 근거한다.
#
# [근거 법령 및 본문]
# 부가가치세법 시행령 95조 ⑤항 3호: 사업의 양수에 따른 대가의 가액과 부가가치세액
#
# 소득세법 시행령 211조 ①항: 사업자가 재화 또는 용역을 공급하는 때에는 다음 각 호의 사항이 적힌 계산서 2매를 작성하여 그 중 1매를 공급받는 자에게 발급하여야 한다. <개정 1996.12.31, 2013.2.15, 2015.2.3>

# %%
query = "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
print(MultiQueryPipeline(prompt_multi_query, llm, vectorstore).final_output(query))
# Out:
# [[0]]
# ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>
#
# [[1]]
# 2. 거주자의 배우자로서 해당 과세기간의 소득금액이 없거나 해당 과세기간의 소득금액 합계액이 100만원 이하인 사람(총급여액 500만원 이하의 근로소득만 있는 배우자를 포함한다)
#
# [[2]]
# ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>
#
# [[3]]
# 1의2. 법 제21조제1항제7호ㆍ제8호의2ㆍ제9호ㆍ제15호 및 제19호의 기타소득에 대해서는 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다.
#
# [[4]]
# 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.
#
# [[5]]
# 3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액
#
# [[6]]
# ① 공적연금소득에 대한 원천징수의무자가 해당 과세기간의 다음 연도 1월분의 공적연금소득을 지급할 때에는 연금소득자의 해당 과세기간 연금소득금액에 그 연금소득자가 제143조의6에 따라 신고한 내용에 따라 인적공제를 적용한 금액을 종합소득과세표준으로 하고, 그 금액에 기본세율을 적용하여 종합소득산출세액을 계산한 후 그 세액에서 자녀세액공제와 표준세액공제를 적용한 세액에서 그 과세기간에 이미 원천징수하여 납부한 소득세를 공제하고 남은 금액을 원천징수한다. <개정 2013.1.1, 2014.1.1>
#
# [[7]]
# ① 거주자는 해당 과세기간의 과세표준에 대한 종합소득 산출세액 또는 퇴직소득 산출세액에서 감면세액과 세액공제액을 공제한 금액을 제70조, 제70조의2, 제71조 및 제74조에 따른 과세표준확정신고기한까지 대통령령으로 정하는 바에 따라 납세지 관할 세무서, 한국은행 또는 체신관서에 납부하여야 한다. <개정 2013.1.1>
#
# [[8]]
# 가. 제21조제1항제1호부터 제8호까지, 제8호의2, 제9호부터 제20호까지, 제22호, 제22호의2 및 제26호에 따른 기타소득(라목 및 마목의 소득은 제외한다)으로서 같은 조 제3항에 따른 기타소득금액이 300만원 이하이면서 제127조에 따라 원천징수(제127조제1항제6호나목에 해당하여 원천징수되지 아니하는 경우를 포함한다)된 소득. 다만, 해당 소득이 있는 거주자가 종합소득과세표준을 계산할 때 그 소득을 합산하려는 경우 그 소득은 분리과세기타소득에서 제외한다.
#
# [[9]]
# 25. 광고ㆍ선전을 목적으로 견본품ㆍ달력ㆍ수첩ㆍ컵ㆍ부채 기타 이와 유사한 물품을 불특정다수인에게 기증하기 위하여 지출한 비용[특정인에게 기증한 물품(개당 3만원 이하의 물품은 제외한다)의 경우에는 연간 5만원 이내의 금액으로 한정한다]
# 연간 소득금액 100만원 이하란, 부양가족이 한 해 동안 벌어들인 모든 소득(근로소득, 기타소득 등)을 합산했을 때 그 금액이 100만원을 넘지 않는 것을 의미한다. 이는 부양가족 공제 요건 중 하나로, 소득이 일정 수준 이하인 가족을 부양가족으로 인정받기 위한 조건이다. 구체적으로는, 부양가족이 벌어들인 소득이 100만원 이하일 경우, 해당 가족을 부양가족으로 공제받을 수 있다.
#
# [근거 법령 및 본문]
# 소득세법 59조 ②항: 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>
#
# 소득세법 103조 ①항: 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>

# %%
class Reference2:

  def strip_dot(self, text):
    if not text:
      return ""
    return text.rstrip(".")

  def clean_content(self, text):
    if not text:
      return text

    text = text.strip()

    text = re.sub(r"^[①②③④⑤⑥⑦⑧⑨⑩]+\s*", "", text)
    text = re.sub(r"^\d+\.\s*", "", text)
    text = re.sub(r"^[가-힣]\.\s*", "", text)

    return text.strip()

  def make_reference(self, doc, max_law_chars):
    출처 = ""
    meta = doc.metadata
    law_name = meta.get("law_name")
    출처 += law_name
    조문번호 = meta.get("조문번호", "")
    출처 += f" {조문번호}조" if 조문번호 else ""
    항번호 = meta.get("항번호", "")
    출처 += f" {self.strip_dot(항번호)}항" if 항번호 else ""
    호번호 = meta.get("호번호", "")
    출처 += f" {self.strip_dot(호번호)}호" if 호번호 else ""
    목번호 = meta.get("목번호", "")
    출처 += f" {self.strip_dot(목번호)}목" if 목번호 else ""

    content = self.clean_content(doc.page_content)
    if len(content) > max_law_chars:
      content = content[:max_law_chars] + "..."

    return 출처, content

  def final_output(self,query, pipeline, max_law_chars=400):
    answer, reranked_docs = pipeline.generate_answer2(query)

    answer_text = answer.get("answer", "")
    used_ids = answer.get("used_ids", [])

    docs_dict = {getattr(doc, "id", str(i)): doc for i, doc in enumerate(reranked_docs)}

    reference_list = []
    for id in used_ids:
      doc = docs_dict.get(id)
      if not doc:
        matched_key = next((k for k in docs_dict.keys() if id in k or k in id), None)
        doc = docs_dict.get(matched_key)

      if doc:
        출처, content = self.make_reference(doc, max_law_chars)
        reference_list.append(f"{출처}: {content}")

    final_output = answer_text + "\n\n[근거 법령 및 본문]\n" + "\n\n".join(reference_list)

    return final_output

# %%
ㅈquery = "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"

pipeline = MultiQueryPipeline(prompt_multi_query, llm, 25, vectorstore)
print(Reference2().final_output(query, pipeline))
# Out:
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n질문을 세법 전문 용어를 사용해 3개의 서로 다른 query로 재작성해.\n각 쿼리는 반드시 줄바꿈으로 구분해.\n\n질문: 소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
#   ]
# }
# [llm/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] [3.33s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 소득세법상 부양가족 공제의 연간 소득금액 기준이 100만원 이하인 경우, 구체적으로 어떤 소득 항목을 포함하며 산정 방법은 어떻게 되는지 설명해 주시기 바랍니다.\n\n2. 소득세법 제XX조에 규정된 부양가족 공제 대상의 연간 소득금액 산정 시, '100만원 이하'라는 기준에 해당하는 소득 범위와 그 산정 기준에 대해 상세히 설명해 주십시오.\n\n3. 소득세 신고 시 부양가족 공제 요건 중 연간 소득금액이 100만원 이하인 경우, 해당 소득금액의 산정 방법과 포함되는 소득 항목에 대해 구체적으로 명시해 주시기 바랍니다.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 소득세법상 부양가족 공제의 연간 소득금액 기준이 100만원 이하인 경우, 구체적으로 어떤 소득 항목을 포함하며 산정 방법은 어떻게 되는지 설명해 주시기 바랍니다.\n\n2. 소득세법 제XX조에 규정된 부양가족 공제 대상의 연간 소득금액 산정 시, '100만원 이하'라는 기준에 해당하는 소득 범위와 그 산정 기준에 대해 상세히 설명해 주십시오.\n\n3. 소득세 신고 시 부양가족 공제 요건 중 연간 소득금액이 100만원 이하인 경우, 해당 소득금액의 산정 방법과 포함되는 소득 항목에 대해 구체적으로 명시해 주시기 바랍니다.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 172,
#                 "prompt_tokens": 81,
#                 "total_tokens": 253,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_70fc5e01a5",
#               "id": "chatcmpl-D6K0U10AUEvlUpBQD0GojbEyjEgTk",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c3404-a4b1-7861-9885-70cceae7e7d6-0",
#             "usage_metadata": {
#               "input_tokens": 81,
#               "output_tokens": 172,
#               "total_tokens": 253,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 172,
#       "prompt_tokens": 81,
#       "total_tokens": 253,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_70fc5e01a5",
#     "id": "chatcmpl-D6K0U10AUEvlUpBQD0GojbEyjEgTk",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] s] Exiting Parser run with output:
# {
#   "output": [
#     "1. 소득세법상 부양가족 공제의 연간 소득금액 기준이 100만원 이하인 경우, 구체적으로 어떤 소득 항목을 포함하며 산정 방법은 어떻게 되는지 설명해 주시기 바랍니다.",
#     "2. 소득세법 제XX조에 규정된 부양가족 공제 대상의 연간 소득금액 산정 시, '100만원 이하'라는 기준에 해당하는 소득 범위와 그 산정 기준에 대해 상세히 설명해 주십시오.",
#     "3. 소득세 신고 시 부양가족 공제 요건 중 연간 소득금액이 100만원 이하인 경우, 해당 소득금액의 산정 방법과 포함되는 소득 항목에 대해 구체적으로 명시해 주시기 바랍니다."
#   ]
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence] [3.34s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 소득세법상 부양가족 공제의 연간 소득금액 기준이 100만원 이하인 경우, 구체적으로 어떤 소득 항목을 포함하며 산정 방법은 어떻게 되는지 설명해 주시기 바랍니다.",
#     "2. 소득세법 제XX조에 규정된 부양가족 공제 대상의 연간 소득금액 산정 시, '100만원 이하'라는 기준에 해당하는 소득 범위와 그 산정 기준에 대해 상세히 설명해 주십시오.",
#     "3. 소득세 신고 시 부양가족 공제 요건 중 연간 소득금액이 100만원 이하인 경우, 해당 소득금액의 산정 방법과 포함되는 소득 항목에 대해 구체적으로 명시해 주시기 바랍니다."
#   ]
# }
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?",
#   "docs": "[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712] 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원...\n[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242] ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>...\n[문서 ID: 007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367] 2. 소득ㆍ세액 공제 대상금액의 표기에 관한 사항...\n[문서 ID: 001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283] 나. 「소득세법」 제17조제1항 각 호에 따른 배당소득의 금액. 다만, 「상속세 및 증여세법」 제16조 또는 제48조에 따라 상속세 과세가액 또는 증여세 과세가액에 산입되거나 증여세가 부과되는 주식등으로부터 발생한 배당소득의 금액은 제외한다....\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532] ① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148] 1의2. 법 제21조제1항제7호ㆍ제8호의2ㆍ제9호ㆍ제15호 및 제19호의 기타소득에 대해서는 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다....\n[문서 ID: 001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153] 가. 제21조제1항제1호부터 제8호까지, 제8호의2, 제9호부터 제20호까지, 제22호, 제22호의2 및 제26호에 따른 기타소득(라목 및 마목의 소득은 제외한다)으로서 같은 조 제3항에 따른 기타소득금액이 300만원 이하이면서 제127조에 따라 원천징수(제127조제1항제6호나목에 해당하여 원천징수되지 아니하는 경우를 포함한다)된 소득. 다만, 해당 소득이 있는 거주자가 종합소득과세표준을 계산할 때 그 소득을 합산하려는 경우 그 소득은 분리과세기타소득에서 제외한다....\n[문서 ID: 003608:138_5_②_8._NO_목번호:j23:p1:l2629] 8. 소득수취법인이 당해 소득에 대하여 부담할 세액이 법 제98조의 규정에 따른 세율을 적용하여 계산한 세액과 해당국과의 조세조약에 따라 과세될 세액과의 차익의 100분의 50 이상이 되는 경우...\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677] ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>...\n[문서 ID: 003956:143_NO_조문가지번호_③_1._NO_목번호:j8:p1:l1770] 1. 수입금액에서 다음 각 목의 금액의 합계액(수입금액을 초과하는 경우에는 그 초과하는 금액은 제외한다)을 공제한 금액을 그 소득금액(이하 이 조에서 \"기준소득금액\"이라 한다)으로 결정 또는 경정하는 방법. 다만, 기준소득금액이 제1호의2에 따른 소득금액에 재정경제부령으로 정하는 배율을 곱하여 계산한 금액 이상인 경우 2027년 12월 31일이 속하는 과세기간의 소득금액을 결정 또는 경정할 때까지는 그 배율을 곱하여 계산한 금액을 소득금액으로 결정할 수 있다....\n[문서 ID: 001565:33_NO_조문가지번호_①_1._NO_목번호:j3:p1:l388] 1. 소득세(제57조 및 제57조의2에 따라 세액공제를 적용하는 경우의 외국소득세액을 포함한다)와 개인지방소득세...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 001565:44_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l479] ①피상속인의 소득금액에 대한 소득세로서 상속인에게 과세할 것과 상속인의 소득금액에 대한 소득세는 구분하여 계산하여야 한다. <개정 2013.1.1>...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_3._NO_목번호:j11:p1:l1152] 3. 법 제21조제1항제26호에 따른 종교인소득(이하 \"종교인소득\"이라 한다)에 대해서는 종교관련종사자가 해당 과세기간에 받은 금액(법 제12조제5호아목에 따른 비과세소득을 제외한다. 이하 이 호에서 같다) 중 다음 표에 따른 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 다음 표에 따른 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=23764609\" alt=\"img23764609\" >\n \n ┌─────────┬────────────────────┐\n \n │종교관련종사자가 │필요경비 │\n \n │받은 금액 │ │\n \n ├─────────┼────────────────────┤\n \n │2천만원 이하 │종교관련종사자가 받은 금액의 100분의 80 │\n \n ├─────────┼────────────────────┤\n \n │2천만원 초과 │1,600만원+(2천만원을 초과하는 금...\n[문서 ID: 001563:75_7_③_2._NO_목번호:j14:p1:l873] 2. 2024년 1월 1일부터 2024년 12월 31일까지 「소득세법」 제164조의3제1항제3호의 소득을 지급하는 경우로서 해당 소득에 대한 지급명세서를 그 소득 지급일이 속하는 과세연도의 다음 연도 2월 말일(휴업, 폐업 또는 해산한 경우에는 휴업일, 폐업일 또는 해산일이 속하는 달의 다음다음 달 말일)까지 제출하는 경우...\n[문서 ID: 001563:62_2_⑤_NO_호번호_NO_목번호:j9:p1:l697] ⑤ 자산양도소득에 대한 과세표준의 계산에 관하여는 「소득세법」 제101조 및 제102조를 준용하고, 자산양도소득에 대한 세액계산에 관하여는 같은 법 제92조를 준용한다. <개정 2023.12.31>...\n[문서 ID: 001565:22_NO_조문가지번호_④_2._NO_목번호:j10:p1:l335] 2. 총급여: 봉급ㆍ상여 등 제20조제1항제1호 및 제2호에 따른 근로소득(제12조에 따른 비과세소득은 제외한다)을 합산한다....\n[문서 ID: 001565:47_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l500] ①근로소득이 있는 거주자에 대해서는 해당 과세기간에 받는 총급여액에서 다음의 금액을 공제 ...
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "query": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?",
#   "docs": "[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712] 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원...\n[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242] ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>...\n[문서 ID: 007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367] 2. 소득ㆍ세액 공제 대상금액의 표기에 관한 사항...\n[문서 ID: 001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283] 나. 「소득세법」 제17조제1항 각 호에 따른 배당소득의 금액. 다만, 「상속세 및 증여세법」 제16조 또는 제48조에 따라 상속세 과세가액 또는 증여세 과세가액에 산입되거나 증여세가 부과되는 주식등으로부터 발생한 배당소득의 금액은 제외한다....\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532] ① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148] 1의2. 법 제21조제1항제7호ㆍ제8호의2ㆍ제9호ㆍ제15호 및 제19호의 기타소득에 대해서는 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다....\n[문서 ID: 001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153] 가. 제21조제1항제1호부터 제8호까지, 제8호의2, 제9호부터 제20호까지, 제22호, 제22호의2 및 제26호에 따른 기타소득(라목 및 마목의 소득은 제외한다)으로서 같은 조 제3항에 따른 기타소득금액이 300만원 이하이면서 제127조에 따라 원천징수(제127조제1항제6호나목에 해당하여 원천징수되지 아니하는 경우를 포함한다)된 소득. 다만, 해당 소득이 있는 거주자가 종합소득과세표준을 계산할 때 그 소득을 합산하려는 경우 그 소득은 분리과세기타소득에서 제외한다....\n[문서 ID: 003608:138_5_②_8._NO_목번호:j23:p1:l2629] 8. 소득수취법인이 당해 소득에 대하여 부담할 세액이 법 제98조의 규정에 따른 세율을 적용하여 계산한 세액과 해당국과의 조세조약에 따라 과세될 세액과의 차익의 100분의 50 이상이 되는 경우...\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677] ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>...\n[문서 ID: 003956:143_NO_조문가지번호_③_1._NO_목번호:j8:p1:l1770] 1. 수입금액에서 다음 각 목의 금액의 합계액(수입금액을 초과하는 경우에는 그 초과하는 금액은 제외한다)을 공제한 금액을 그 소득금액(이하 이 조에서 \"기준소득금액\"이라 한다)으로 결정 또는 경정하는 방법. 다만, 기준소득금액이 제1호의2에 따른 소득금액에 재정경제부령으로 정하는 배율을 곱하여 계산한 금액 이상인 경우 2027년 12월 31일이 속하는 과세기간의 소득금액을 결정 또는 경정할 때까지는 그 배율을 곱하여 계산한 금액을 소득금액으로 결정할 수 있다....\n[문서 ID: 001565:33_NO_조문가지번호_①_1._NO_목번호:j3:p1:l388] 1. 소득세(제57조 및 제57조의2에 따라 세액공제를 적용하는 경우의 외국소득세액을 포함한다)와 개인지방소득세...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 001565:44_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l479] ①피상속인의 소득금액에 대한 소득세로서 상속인에게 과세할 것과 상속인의 소득금액에 대한 소득세는 구분하여 계산하여야 한다. <개정 2013.1.1>...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_3._NO_목번호:j11:p1:l1152] 3. 법 제21조제1항제26호에 따른 종교인소득(이하 \"종교인소득\"이라 한다)에 대해서는 종교관련종사자가 해당 과세기간에 받은 금액(법 제12조제5호아목에 따른 비과세소득을 제외한다. 이하 이 호에서 같다) 중 다음 표에 따른 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 다음 표에 따른 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=23764609\" alt=\"img23764609\" >\n \n ┌─────────┬────────────────────┐\n \n │종교관련종사자가 │필요경비 │\n \n │받은 금액 │ │\n \n ├─────────┼────────────────────┤\n \n │2천만원 이하 │종교관련종사자가 받은 금액의 100분의 80 │\n \n ├─────────┼────────────────────┤\n \n │2천만원 초과 │1,600만원+(2천만원을 초과하는 금...\n[문서 ID: 001563:75_7_③_2._NO_목번호:j14:p1:l873] 2. 2024년 1월 1일부터 2024년 12월 31일까지 「소득세법」 제164조의3제1항제3호의 소득을 지급하는 경우로서 해당 소득에 대한 지급명세서를 그 소득 지급일이 속하는 과세연도의 다음 연도 2월 말일(휴업, 폐업 또는 해산한 경우에는 휴업일, 폐업일 또는 해산일이 속하는 달의 다음다음 달 말일)까지 제출하는 경우...\n[문서 ID: 001563:62_2_⑤_NO_호번호_NO_목번호:j9:p1:l697] ⑤ 자산양도소득에 대한 과세표준의 계산에 관하여는 「소득세법」 제101조 및 제102조를 준용하고, 자산양도소득에 대한 세액계산에 관하여는 같은 법 제92조를 준용한다. <개정 2023.12.31>...\n[문서 ID: 001565:22_NO_조문가지번호_④_2._NO_목번호:j10:p1:l335] 2. 총급여: 봉급ㆍ상여 등 제20조제1항제1호 및 제2호에 따른 근로소득(제12조에 따른 비과세소득은 제외한다)을 합산한다....\n[문서 ID: 001565:47_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l500] ①근로소득이 있는 거주자에 대해서는 해당 과세기간에 받는 총급여액에서 다음의 금액을 공제 ...
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문 지식을 가진 reranking 모델이야.\n    아래 질문에 대해 각 문서들이 답변 근거로 얼마나 관련성 있고 적합한지 점수로 평가해.\n    점수 범위: 0 ~ 100\n\n    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수\n    - 미세하게라도 점수에 차등을 둘 것\n    - 문서 간 비교를 하여 상대적인 점수를 계산할 것\n    - 반드시 아래의 JSON 형식으로만 답변할 것\n    - id는 문서ID를 그대로 복사해서 사용\n    \n    [질문]\n    소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?\n\n    [문서들]\n    [문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712] 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원...\n[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242] ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>...\n[문서 ID: 007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367] 2. 소득ㆍ세액 공제 대상금액의 표기에 관한 사항...\n[문서 ID: 001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283] 나. 「소득세법」 제17조제1항 각 호에 따른 배당소득의 금액. 다만, 「상속세 및 증여세법」 제16조 또는 제48조에 따라 상속세 과세가액 또는 증여세 과세가액에 산입되거나 증여세가 부과되는 주식등으로부터 발생한 배당소득의 금액은 제외한다....\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532] ① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148] 1의2. 법 제21조제1항제7호ㆍ제8호의2ㆍ제9호ㆍ제15호 및 제19호의 기타소득에 대해서는 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다....\n[문서 ID: 001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153] 가. 제21조제1항제1호부터 제8호까지, 제8호의2, 제9호부터 제20호까지, 제22호, 제22호의2 및 제26호에 따른 기타소득(라목 및 마목의 소득은 제외한다)으로서 같은 조 제3항에 따른 기타소득금액이 300만원 이하이면서 제127조에 따라 원천징수(제127조제1항제6호나목에 해당하여 원천징수되지 아니하는 경우를 포함한다)된 소득. 다만, 해당 소득이 있는 거주자가 종합소득과세표준을 계산할 때 그 소득을 합산하려는 경우 그 소득은 분리과세기타소득에서 제외한다....\n[문서 ID: 003608:138_5_②_8._NO_목번호:j23:p1:l2629] 8. 소득수취법인이 당해 소득에 대하여 부담할 세액이 법 제98조의 규정에 따른 세율을 적용하여 계산한 세액과 해당국과의 조세조약에 따라 과세될 세액과의 차익의 100분의 50 이상이 되는 경우...\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677] ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>...\n[문서 ID: 003956:143_NO_조문가지번호_③_1._NO_목번호:j8:p1:l1770] 1. 수입금액에서 다음 각 목의 금액의 합계액(수입금액을 초과하는 경우에는 그 초과하는 금액은 제외한다)을 공제한 금액을 그 소득금액(이하 이 조에서 \"기준소득금액\"이라 한다)으로 결정 또는 경정하는 방법. 다만, 기준소득금액이 제1호의2에 따른 소득금액에 재정경제부령으로 정하는 배율을 곱하여 계산한 금액 이상인 경우 2027년 12월 31일이 속하는 과세기간의 소득금액을 결정 또는 경정할 때까지는 그 배율을 곱하여 계산한 금액을 소득금액으로 결정할 수 있다....\n[문서 ID: 001565:33_NO_조문가지번호_①_1._NO_목번호:j3:p1:l388] 1. 소득세(제57조 및 제57조의2에 따라 세액공제를 적용하는 경우의 외국소득세액을 포함한다)와 개인지방소득세...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 001565:44_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l479] ①피상속인의 소득금액에 대한 소득세로서 상속인에게 과세할 것과 상속인의 소득금액에 대한 소득세는 구분하여 계산하여야 한다. <개정 2013.1.1>...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_3._NO_목번호:j11:p1:l1152] 3. 법 제21조제1항제26호에 따른 종교인소득(이하 \"종교인소득\"이라 한다)에 대해서는 종교관련종사자가 해당 과세기간에 받은 금액(법 제12조제5호아목에 따른 비과세소득을 제외한다. 이하 이 호에서 같다) 중 다음 표에 따른 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 다음 표에 따른 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=23764609\" alt=\"img23764609\" >\n \n ┌─────────┬────────────────────┐\n \n │종교관련종사자가 │필요경비 │\n \n │받은 금액 │ │\n \n ├─────────┼────────────────────┤\n \n │2천만원 이하 │종교관련종사자가 받은 금액의 100분의 80 │\n \n ├─────────┼────────────────────┤\n \n │2천만원 초과 │1,600만원+(2천만원을 초과하는 금...\n[문서 ID: 001563:75_7_③_2._NO_목번호:j14:p1:l873] 2. 2024년 1월 1일부터 2024년 12월 31일까지 「소득세법」 제164조의3제1항제3호의 소득을 지급하는 경우로서 해당 소득에 대한 지급명세서를 그 소득 지급일이 속하는 과세연도의 다음 연도 2월 말일(휴업, 폐업 또는 해산한 경우에는 휴업일, 폐업일 또는 해산일이 속하는 달의 다음다음 달 말일)까지 제출하는 경우...\n[문서 ID: 001563:62_2_⑤_NO_호번호 ...
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [6.61s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"scores\": [\n    {\"id\": \"001565:59_4_⑨_1._NO_목번호:j40:p1:l712\", \"score\": 10},\n    {\"id\": \"001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242\", \"score\": 15},\n    {\"id\": \"007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367\", \"score\": 0},\n    {\"id\": \"001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283\", \"score\": 0},\n    {\"id\": \"003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532\", \"score\": 0},\n    {\"id\": \"003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148\", \"score\": 0},\n    {\"id\": \"001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153\", \"score\": 0},\n    {\"id\": \"003608:138_5_②_8._NO_목번호:j23:p1:l2629\", \"score\": 0},\n    {\"id\": \"001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677\", \"score\": 10},\n    {\"id\": \"003956:143_NO_조문가지번호_③_1._NO_목번호:j8:p1:l1770\", \"score\": 0},\n    {\"id\": \"001565:33_NO_조문가지번호_①_1._NO_목번호:j3:p1:l388\", \"score\": 5},\n    {\"id\": \"003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\", \"score\": 0},\n    {\"id\": \"001565:44_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l479\", \"score\": 0},\n    {\"id\": \"003956:87_NO_조문가지번호_NO_항",
#         "generation_info": {
#           "finish_reason": "length",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"scores\": [\n    {\"id\": \"001565:59_4_⑨_1._NO_목번호:j40:p1:l712\", \"score\": 10},\n    {\"id\": \"001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242\", \"score\": 15},\n    {\"id\": \"007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367\", \"score\": 0},\n    {\"id\": \"001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283\", \"score\": 0},\n    {\"id\": \"003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532\", \"score\": 0},\n    {\"id\": \"003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148\", \"score\": 0},\n    {\"id\": \"001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153\", \"score\": 0},\n    {\"id\": \"003608:138_5_②_8._NO_목번호:j23:p1:l2629\", \"score\": 0},\n    {\"id\": \"001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677\", \"score\": 10},\n    {\"id\": \"003956:143_NO_조문가지번호_③_1._NO_목번호:j8:p1:l1770\", \"score\": 0},\n    {\"id\": \"001565:33_NO_조문가지번호_①_1._NO_목번호:j3:p1:l388\", \"score\": 5},\n    {\"id\": \"003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\", \"score\": 0},\n    {\"id\": \"001565:44_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l479\", \"score\": 0},\n    {\"id\": \"003956:87_NO_조문가지번호_NO_항",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 500,
#                 "prompt_tokens": 10070,
#                 "total_tokens": 10570,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_de604bd877",
#               "id": "chatcmpl-D6K0bwfV8IZ9enFjM7CNR8evTDQon",
#               "service_tier": "default",
#               "finish_reason": "length",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c3404-be99-72d1-8daa-9b6bd9d5cc51-0",
#             "usage_metadata": {
#               "input_tokens": 10070,
#               "output_tokens": 500,
#               "total_tokens": 10570,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 500,
#       "prompt_tokens": 10070,
#       "total_tokens": 10570,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_de604bd877",
#     "id": "chatcmpl-D6K0bwfV8IZ9enFjM7CNR8evTDQon",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "scores": [
#     {
#       "id": "001565:59_4_⑨_1._NO_목번호:j40:p1:l712",
#       "score": 10
#     },
#     {
#       "id": "001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242",
#       "score": 15
#     },
#     {
#       "id": "007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367",
#       "score": 0
#     },
#     {
#       "id": "001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283",
#       "score": 0
#     },
#     {
#       "id": "003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532",
#       "score": 0
#     },
#     {
#       "id": "003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148",
#       "score": 0
#     },
#     {
#       "id": "001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153",
#       "score": 0
#     },
#     {
#       "id": "003608:138_5_②_8._NO_목번호:j23:p1:l2629",
#       "score": 0
#     },
#     {
#       "id": "001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677",
#       "score": 10
#     },
#     {
#       "id": "003956:143_NO_조문가지번호_③_1._NO_목번호:j8:p1:l1770",
#       "score": 0
#     },
#     {
#       "id": "001565:33_NO_조문가지번호_①_1._NO_목번호:j3:p1:l388",
#       "score": 5
#     },
#     {
#       "id": "003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960",
#       "score": 0
#     },
#     {
#       "id": "001565:44_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l479",
#       "score": 0
#     },
#     {
#       "id": "003956:87_NO_조문가지번호_NO_항"
#     }
#   ]
# }
# [chain/end] [chain:RunnableSequence] [6.62s] Exiting Chain run with output:
# {
#   "scores": [
#     {
#       "id": "001565:59_4_⑨_1._NO_목번호:j40:p1:l712",
#       "score": 10
#     },
#     {
#       "id": "001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242",
#       "score": 15
#     },
#     {
#       "id": "007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367",
#       "score": 0
#     },
#     {
#       "id": "001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283",
#       "score": 0
#     },
#     {
#       "id": "003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532",
#       "score": 0
#     },
#     {
#       "id": "003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148",
#       "score": 0
#     },
#     {
#       "id": "001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153",
#       "score": 0
#     },
#     {
#       "id": "003608:138_5_②_8._NO_목번호:j23:p1:l2629",
#       "score": 0
#     },
#     {
#       "id": "001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677",
#       "score": 10
#     },
#     {
#       "id": "003956:143_NO_조문가지번호_③_1._NO_목번호:j8:p1:l1770",
#       "score": 0
#     },
#     {
#       "id": "001565:33_NO_조문가지번호_①_1._NO_목번호:j3:p1:l388",
#       "score": 5
#     },
#     {
#       "id": "003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960",
#       "score": 0
#     },
#     {
#       "id": "001565:44_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l479",
#       "score": 0
#     },
#     {
#       "id": "003956:87_NO_조문가지번호_NO_항"
#     }
#   ]
# }
# [문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242
# ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>
#
# [문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712
# 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "context": "[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242\n① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>\n\n[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712\n1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원",
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "context": "[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242\n① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>\n\n[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712\n1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원",
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문가야. 아래의 문백을 바탕으로 질문에 답변해.\n    반드시 아래의 JSON 형식을 지켜서 출력해\n\n    [문맥]\n    [문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242\n① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>\n\n[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712\n1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원\n\n    [질문]\n    소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?\n\n    [출력 형식-JSON]\n    {\n      \"answer\": \"질문에 대한 답변 (결론 선제시, 논리적 근거 설명)\",\n      \"used_ids\": [\"문서 ID1\", \"문서 ID2\"]\n    }"
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [2.66s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"answer\": \"연간 소득금액 100만원 이하란, 부양가족이 한 해 동안 벌어들인 소득이 100만원을 넘지 않는 경우를 의미합니다. 이는 부양가족 공제 요건 중 하나로, 해당 가족의 소득이 일정 기준 이하일 때 공제 혜택을 받을 수 있음을 의미하며, 근로소득, 사업소득, 기타 소득 등을 모두 포함하여 계산됩니다.\",\n  \"used_ids\": [\"001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242\", \"001565:59_4_⑨_1._NO_목번호:j40:p1:l712\"]\n}",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"answer\": \"연간 소득금액 100만원 이하란, 부양가족이 한 해 동안 벌어들인 소득이 100만원을 넘지 않는 경우를 의미합니다. 이는 부양가족 공제 요건 중 하나로, 해당 가족의 소득이 일정 기준 이하일 때 공제 혜택을 받을 수 있음을 의미하며, 근로소득, 사업소득, 기타 소득 등을 모두 포함하여 계산됩니다.\",\n  \"used_ids\": [\"001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242\", \"001565:59_4_⑨_1._NO_목번호:j40:p1:l712\"]\n}",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 160,
#                 "prompt_tokens": 341,
#                 "total_tokens": 501,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_44848d1550",
#               "id": "chatcmpl-D6K0hmRJFH5dZir9lwKwCqEy5W0pq",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c3404-d873-7542-b6ea-9d670b8a8ba5-0",
#             "usage_metadata": {
#               "input_tokens": 341,
#               "output_tokens": 160,
#               "total_tokens": 501,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 160,
#       "prompt_tokens": 341,
#       "total_tokens": 501,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_44848d1550",
#     "id": "chatcmpl-D6K0hmRJFH5dZir9lwKwCqEy5W0pq",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "answer": "연간 소득금액 100만원 이하란, 부양가족이 한 해 동안 벌어들인 소득이 100만원을 넘지 않는 경우를 의미합니다. 이는 부양가족 공제 요건 중 하나로, 해당 가족의 소득이 일정 기준 이하일 때 공제 혜택을 받을 수 있음을 의미하며, 근로소득, 사업소득, 기타 소득 등을 모두 포함하여 계산됩니다.",
#   "used_ids": [
#     "001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242",
#     "001565:59_4_⑨_1._NO_목번호:j40:p1:l712"
#   ]
# }
# [chain/end] [chain:RunnableSequence] [2.66s] Exiting Chain run with output:
# {
#   "answer": "연간 소득금액 100만원 이하란, 부양가족이 한 해 동안 벌어들인 소득이 100만원을 넘지 않는 경우를 의미합니다. 이는 부양가족 공제 요건 중 하나로, 해당 가족의 소득이 일정 기준 이하일 때 공제 혜택을 받을 수 있음을 의미하며, 근로소득, 사업소득, 기타 소득 등을 모두 포함하여 계산됩니다.",
#   "used_ids": [
#     "001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242",
#     "001565:59_4_⑨_1._NO_목번호:j40:p1:l712"
#   ]
# }
# 연간 소득금액 100만원 이하란, 부양가족이 한 해 동안 벌어들인 소득이 100만원을 넘지 않는 경우를 의미합니다. 이는 부양가족 공제 요건 중 하나로, 해당 가족의 소득이 일정 기준 이하일 때 공제 혜택을 받을 수 있음을 의미하며, 근로소득, 사업소득, 기타 소득 등을 모두 포함하여 계산됩니다.
#
# [근거 법령 및 본문]
# 소득세법 103조 ①항: 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>
#
# 소득세법 59조 ⑨항 1호: 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원

# %%
query = "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"

pipeline = MultiQueryPipeline(prompt_multi_query, llm, 25, vectorstore)
print(Reference2().final_output(query, pipeline))
# Out:
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n질문을 세법 전문 용어를 사용해 3개의 서로 다른 query로 재작성해.\n각 쿼리는 반드시 줄바꿈으로 구분해.\n\n질문: 미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
#   ]
# }
# [llm/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] [2.00s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 미혼자가 본인 명의로 임대한 주택에 대해 발생하는 임대소득이 소득세법상 과세대상인지 여부를 판단하는 기준은 무엇인가?\n\n2. 본인 명의 임대주택에서 발생하는 임대소득이 종합소득세 과세 대상에 포함되는지, 또는 별도 과세 대상인지에 대한 세법상 규정은 어떻게 되는가?\n\n3. 부모님 소유 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 임대소득세 과세 여부와 관련된 세법상 해석은 무엇인가?",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 미혼자가 본인 명의로 임대한 주택에 대해 발생하는 임대소득이 소득세법상 과세대상인지 여부를 판단하는 기준은 무엇인가?\n\n2. 본인 명의 임대주택에서 발생하는 임대소득이 종합소득세 과세 대상에 포함되는지, 또는 별도 과세 대상인지에 대한 세법상 규정은 어떻게 되는가?\n\n3. 부모님 소유 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 임대소득세 과세 여부와 관련된 세법상 해석은 무엇인가?",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 149,
#                 "prompt_tokens": 87,
#                 "total_tokens": 236,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_70fc5e01a5",
#               "id": "chatcmpl-D6K1heRVJVKa56ZYzPJOYsptxM5QQ",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c3405-cb28-7b62-9e44-b762b84f956c-0",
#             "usage_metadata": {
#               "input_tokens": 87,
#               "output_tokens": 149,
#               "total_tokens": 236,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 149,
#       "prompt_tokens": 87,
#       "total_tokens": 236,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_70fc5e01a5",
#     "id": "chatcmpl-D6K1heRVJVKa56ZYzPJOYsptxM5QQ",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] s] Exiting Parser run with output:
# {
#   "output": [
#     "1. 미혼자가 본인 명의로 임대한 주택에 대해 발생하는 임대소득이 소득세법상 과세대상인지 여부를 판단하는 기준은 무엇인가?",
#     "2. 본인 명의 임대주택에서 발생하는 임대소득이 종합소득세 과세 대상에 포함되는지, 또는 별도 과세 대상인지에 대한 세법상 규정은 어떻게 되는가?",
#     "3. 부모님 소유 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 임대소득세 과세 여부와 관련된 세법상 해석은 무엇인가?"
#   ]
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence] [2.00s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 미혼자가 본인 명의로 임대한 주택에 대해 발생하는 임대소득이 소득세법상 과세대상인지 여부를 판단하는 기준은 무엇인가?",
#     "2. 본인 명의 임대주택에서 발생하는 임대소득이 종합소득세 과세 대상에 포함되는지, 또는 별도 과세 대상인지에 대한 세법상 규정은 어떻게 되는가?",
#     "3. 부모님 소유 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 임대소득세 과세 여부와 관련된 세법상 해석은 무엇인가?"
#   ]
# }
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?",
#   "docs": "[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93] 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다....\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620] 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>...\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567] ⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 003956:167_3_①_3._NO_목번호:j14:p1:l2500] 3. 「조세특례제한법」 제97조ㆍ제97조의2 및 제98조에 따라 양도소득세가 감면되는 임대주택으로서 5년 이상 임대한 국민주택(이하 이 조에서 \"감면대상장기임대주택\"이라 한다)...\n[문서 ID: 001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32] ⑤ 공동으로 소유한 자산에 대한 양도소득금액을 계산하는 경우에는 해당 자산을 공동으로 소유하는 각 거주자가 납세의무를 진다. <신설 2017.12.19, 2020.12.29>...\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673] 5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득...\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985] ① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다....\n[문서 ID: 007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111] 다. 법 제70조제2항에 따른 분리과세 주택임대소득 및 법 제127조제1항제6호나목의 소득만 있는 경우: 별지 제40호서식(6)...\n[문서 ID: 001565:64_2_①_2._가.:j5:p1:l757] 가. 분리과세 주택임대소득에 대한 사업소득금액에 100분의 14를 곱하여 산출한 금액. 다만, 「조세특례제한법」 제96조제1항에 해당하는 거주자가 같은 항에 따른 임대주택을 임대하는 경우에는 해당 임대사업에서 발생한 분리과세 주택임대소득에 대한 사업소득금액에 100분의 14를 곱하여 산출한 금액에서 같은 항에 따라 감면받는 세액을 차감한 금액으로 한다....\n[문서 ID: 003956:167_10_①_15._NO_목번호:j18:p1:l2596] 15. 제155조 또는 「조세특례제한법」에 따라 1세대가 국내에 1개의 주택을 소유하고 있는 것으로 보거나 1세대 1주택으로 보아 제154조제1항이 적용되는 주택으로서 같은 항의 요건을 모두 충족하는 주택...\n[문서 ID: 003956:167_3_①_13._NO_목번호:j30:p1:l2516] 13. 제155조 또는 「조세특례제한법」에 따라 1세대가 국내에 1개의 주택을 소유하고 있는 것으로 보거나 1세대 1주택으로 보아 제154조제1항이 적용되는 주택으로서 같은 항의 요건을 모두 충족하는 주택...\n[문서 ID: 003956:122_2_③_2._NO_목번호:j12:p1:l1609] 2. 「도시 및 주거환경정비법」에 따른 재개발사업ㆍ재건축사업, 「빈집 및 소규모주택 정비에 관한 특례법」에 따른 소규모주택정비사업으로 임대 중이던 당초의 임대주택이 멸실되어 새로 취득하거나 「주택법」에 따른 리모델링으로 새로 취득한 주택이 아파트(당초의 임대주택이 단기민간임대주택인 경우에는 모든 주택을 말한다)인 경우. 다만, 새로 취득한 주택의 준공일부터 6개월이 되는 날이 2020년 7월 10일 이전인 경우는 제외한다....\n[문서 ID: 003956:167_3_①_5._NO_목번호:j16:p1:l2502] 5. 「조세특례제한법」 제77조, 제98조의2, 제98조의3, 제98조의5부터 제98조의8까지, 제99조, 제99조의2 및 제99조의3에 따라 양도소득세가 감면되는 주택...\n[문서 ID: 003956:155_NO_조문가지번호_⑧_NO_호번호_NO_목번호:j25:p1:l2045] ⑧ 재정경제부령으로 정하는 취학, 근무상의 형편, 질병의 요양, 그 밖에 부득이한 사유(이하 이 항에서 \"부득이한 사유\"라 한다)로 취득한 수도권 밖에 소재하는 주택과 그 밖의 주택(이하 이 항에서 \"일반주택\"이라 한다)을 국내에 각각 1개씩 소유하고 있는 1세대가 부득이한 사유가 해소된 날부터 3년 이내에 일반주택을 양도하는 경우에는 국내에 1개의 주택을 소유하고 있는 것으로 보아 제154조제1항을 적용한다. <신설 2008.11.28, 2012.2.2, 2025.12.30>...\n[문서 ID: 003956:155_3_①_NO_호번호_NO_목번호:j2:p1:l2111] ① 국내에 1주택(제155조, 제155조의2, 제156조의2, 제156조의3 및 그 밖의 법령에 따라 1세대1주택으로 보는 경우를 포함한다)을 소유한 1세대가 다음 각 호의 요건을 모두 갖춘 주택(이하 \"상생임대주택\"이라 한다)을 양도하는 경우에는 제154조제1항, 제155조제20항제1호 및 제159조의4를 적용할 때 해당 규정에 따른 거주기간의 제한을 받지 않는다. <개정 2022.8.2, 2023.2.28, 2024.11.12>...\n[문서 ID ...
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "query": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?",
#   "docs": "[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93] 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다....\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620] 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>...\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567] ⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 003956:167_3_①_3._NO_목번호:j14:p1:l2500] 3. 「조세특례제한법」 제97조ㆍ제97조의2 및 제98조에 따라 양도소득세가 감면되는 임대주택으로서 5년 이상 임대한 국민주택(이하 이 조에서 \"감면대상장기임대주택\"이라 한다)...\n[문서 ID: 001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32] ⑤ 공동으로 소유한 자산에 대한 양도소득금액을 계산하는 경우에는 해당 자산을 공동으로 소유하는 각 거주자가 납세의무를 진다. <신설 2017.12.19, 2020.12.29>...\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673] 5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득...\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985] ① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다....\n[문서 ID: 007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111] 다. 법 제70조제2항에 따른 분리과세 주택임대소득 및 법 제127조제1항제6호나목의 소득만 있는 경우: 별지 제40호서식(6)...\n[문서 ID: 001565:64_2_①_2._가.:j5:p1:l757] 가. 분리과세 주택임대소득에 대한 사업소득금액에 100분의 14를 곱하여 산출한 금액. 다만, 「조세특례제한법」 제96조제1항에 해당하는 거주자가 같은 항에 따른 임대주택을 임대하는 경우에는 해당 임대사업에서 발생한 분리과세 주택임대소득에 대한 사업소득금액에 100분의 14를 곱하여 산출한 금액에서 같은 항에 따라 감면받는 세액을 차감한 금액으로 한다....\n[문서 ID: 003956:167_10_①_15._NO_목번호:j18:p1:l2596] 15. 제155조 또는 「조세특례제한법」에 따라 1세대가 국내에 1개의 주택을 소유하고 있는 것으로 보거나 1세대 1주택으로 보아 제154조제1항이 적용되는 주택으로서 같은 항의 요건을 모두 충족하는 주택...\n[문서 ID: 003956:167_3_①_13._NO_목번호:j30:p1:l2516] 13. 제155조 또는 「조세특례제한법」에 따라 1세대가 국내에 1개의 주택을 소유하고 있는 것으로 보거나 1세대 1주택으로 보아 제154조제1항이 적용되는 주택으로서 같은 항의 요건을 모두 충족하는 주택...\n[문서 ID: 003956:122_2_③_2._NO_목번호:j12:p1:l1609] 2. 「도시 및 주거환경정비법」에 따른 재개발사업ㆍ재건축사업, 「빈집 및 소규모주택 정비에 관한 특례법」에 따른 소규모주택정비사업으로 임대 중이던 당초의 임대주택이 멸실되어 새로 취득하거나 「주택법」에 따른 리모델링으로 새로 취득한 주택이 아파트(당초의 임대주택이 단기민간임대주택인 경우에는 모든 주택을 말한다)인 경우. 다만, 새로 취득한 주택의 준공일부터 6개월이 되는 날이 2020년 7월 10일 이전인 경우는 제외한다....\n[문서 ID: 003956:167_3_①_5._NO_목번호:j16:p1:l2502] 5. 「조세특례제한법」 제77조, 제98조의2, 제98조의3, 제98조의5부터 제98조의8까지, 제99조, 제99조의2 및 제99조의3에 따라 양도소득세가 감면되는 주택...\n[문서 ID: 003956:155_NO_조문가지번호_⑧_NO_호번호_NO_목번호:j25:p1:l2045] ⑧ 재정경제부령으로 정하는 취학, 근무상의 형편, 질병의 요양, 그 밖에 부득이한 사유(이하 이 항에서 \"부득이한 사유\"라 한다)로 취득한 수도권 밖에 소재하는 주택과 그 밖의 주택(이하 이 항에서 \"일반주택\"이라 한다)을 국내에 각각 1개씩 소유하고 있는 1세대가 부득이한 사유가 해소된 날부터 3년 이내에 일반주택을 양도하는 경우에는 국내에 1개의 주택을 소유하고 있는 것으로 보아 제154조제1항을 적용한다. <신설 2008.11.28, 2012.2.2, 2025.12.30>...\n[문서 ID: 003956:155_3_①_NO_호번호_NO_목번호:j2:p1:l2111] ① 국내에 1주택(제155조, 제155조의2, 제156조의2, 제156조의3 및 그 밖의 법령에 따라 1세대1주택으로 보는 경우를 포함한다)을 소유한 1세대가 다음 각 호의 요건을 모두 갖춘 주택(이하 \"상생임대주택\"이라 한다)을 양도하는 경우에는 제154조제1항, 제155조제20항제1호 및 제159조의4를 적용할 때 해당 규정에 따른 거주기간의 제한을 받지 않는다. <개정 2022.8.2, 2023.2.28, 2024.11.12>...\n[문서 ID ...
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문 지식을 가진 reranking 모델이야.\n    아래 질문에 대해 각 문서들이 답변 근거로 얼마나 관련성 있고 적합한지 점수로 평가해.\n    점수 범위: 0 ~ 100\n\n    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수\n    - 미세하게라도 점수에 차등을 둘 것\n    - 문서 간 비교를 하여 상대적인 점수를 계산할 것\n    - 반드시 아래의 JSON 형식으로만 답변할 것\n    - id는 문서ID를 그대로 복사해서 사용\n    \n    [질문]\n    미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?\n\n    [문서들]\n    [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93] 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다....\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620] 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>...\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567] ⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 003956:167_3_①_3._NO_목번호:j14:p1:l2500] 3. 「조세특례제한법」 제97조ㆍ제97조의2 및 제98조에 따라 양도소득세가 감면되는 임대주택으로서 5년 이상 임대한 국민주택(이하 이 조에서 \"감면대상장기임대주택\"이라 한다)...\n[문서 ID: 001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32] ⑤ 공동으로 소유한 자산에 대한 양도소득금액을 계산하는 경우에는 해당 자산을 공동으로 소유하는 각 거주자가 납세의무를 진다. <신설 2017.12.19, 2020.12.29>...\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673] 5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득...\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985] ① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다....\n[문서 ID: 007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111] 다. 법 제70조제2항에 따른 분리과세 주택임대소득 및 법 제127조제1항제6호나목의 소득만 있는 경우: 별지 제40호서식(6)...\n[문서 ID: 001565:64_2_①_2._가.:j5:p1:l757] 가. 분리과세 주택임대소득에 대한 사업소득금액에 100분의 14를 곱하여 산출한 금액. 다만, 「조세특례제한법」 제96조제1항에 해당하는 거주자가 같은 항에 따른 임대주택을 임대하는 경우에는 해당 임대사업에서 발생한 분리과세 주택임대소득에 대한 사업소득금액에 100분의 14를 곱하여 산출한 금액에서 같은 항에 따라 감면받는 세액을 차감한 금액으로 한다....\n[문서 ID: 003956:167_10_①_15._NO_목번호:j18:p1:l2596] 15. 제155조 또는 「조세특례제한법」에 따라 1세대가 국내에 1개의 주택을 소유하고 있는 것으로 보거나 1세대 1주택으로 보아 제154조제1항이 적용되는 주택으로서 같은 항의 요건을 모두 충족하는 주택...\n[문서 ID: 003956:167_3_①_13._NO_목번호:j30:p1:l2516] 13. 제155조 또는 「조세특례제한법」에 따라 1세대가 국내에 1개의 주택을 소유하고 있는 것으로 보거나 1세대 1주택으로 보아 제154조제1항이 적용되는 주택으로서 같은 항의 요건을 모두 충족하는 주택...\n[문서 ID: 003956:122_2_③_2._NO_목번호:j12:p1:l1609] 2. 「도시 및 주거환경정비법」에 따른 재개발사업ㆍ재건축사업, 「빈집 및 소규모주택 정비에 관한 특례법」에 따른 소규모주택정비사업으로 임대 중이던 당초의 임대주택이 멸실되어 새로 취득하거나 「주택법」에 따른 리모델링으로 새로 취득한 주택이 아파트(당초의 임대주택이 단기민간임대주택인 경우에는 모든 주택을 말한다)인 경우. 다만, 새로 취득한 주택의 준공일부터 6개월이 되는 날이 2020년 7월 10일 이전인 경우는 제외한다....\n[문서 ID: 003956:167_3_①_5._NO_목번호:j16:p1:l2502] 5. 「조세특례제한법」 제77조, 제98조의2, 제98조의3, 제98조의5부터 제98조의8까지, 제99조, 제99조의2 및 제99조의3에 따라 양도소득세가 감면되는 주택...\n[문서 ID: 003956:155_NO_조문가지번호_⑧_NO_호번호_NO_목번호:j25:p1:l2045] ⑧ 재정경제부령으로 정하는 취학, 근무상의 형편, 질병의 요양, 그 밖에 부득이한 사유(이하 이 항에서 \"부득이한 사유\"라 한다)로 취득한 수도권 밖에 소재하는 주택과 그 밖의 주택(이하 이 항에서 \"일반주택\"이라 한다)을 국내에 각각 1개씩 소유하고 있는 1세대가 부득이한 사유가 해소된 날부터 3년 이내에 일반주택을 양도하는 경우에는 국내에 1개의 주택을 소유하고 있는  ...
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [10.55s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"scores\": [\n    {\"id\": \"001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\", \"score\": 60},\n    {\"id\": \"003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\", \"score\": 85},\n    {\"id\": \"001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567\", \"score\": 35},\n    {\"id\": \"003956:167_3_①_3._NO_목번호:j14:p1:l2500\", \"score\": 40},\n    {\"id\": \"001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32\", \"score\": 25},\n    {\"id\": \"003608:92_2_④_5._NO_목번호:j72:p1:l1673\", \"score\": 30},\n    {\"id\": \"001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985\", \"score\": 20},\n    {\"id\": \"007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111\", \"score\": 15},\n    {\"id\": \"001565:64_2_①_2._가.:j5:p1:l757\", \"score\": 65},\n    {\"id\": \"003956:167_10_①_15._NO_목번호:j18:p1:l2596\", \"score\": 50},\n    {\"id\": \"003956:167_3_①_13._NO_목번호:j30:p1:l2516\", \"score\": 55},\n    {\"id\": \"003956:122_2_③_2._NO_목번호:j12:p1:l1609\", \"score\": 45},\n    {\"id\": \"003956:167_3_⑤_2._가.:j40:p1:l2526\", \"score\": 20},\n    {\"id\": \"001565:89_NO_조문가지번호_①_3._나.:j7:p1:l1091\", \"score\": 10},\n    {\"id\": \"003956:155",
#         "generation_info": {
#           "finish_reason": "length",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"scores\": [\n    {\"id\": \"001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\", \"score\": 60},\n    {\"id\": \"003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\", \"score\": 85},\n    {\"id\": \"001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567\", \"score\": 35},\n    {\"id\": \"003956:167_3_①_3._NO_목번호:j14:p1:l2500\", \"score\": 40},\n    {\"id\": \"001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32\", \"score\": 25},\n    {\"id\": \"003608:92_2_④_5._NO_목번호:j72:p1:l1673\", \"score\": 30},\n    {\"id\": \"001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985\", \"score\": 20},\n    {\"id\": \"007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111\", \"score\": 15},\n    {\"id\": \"001565:64_2_①_2._가.:j5:p1:l757\", \"score\": 65},\n    {\"id\": \"003956:167_10_①_15._NO_목번호:j18:p1:l2596\", \"score\": 50},\n    {\"id\": \"003956:167_3_①_13._NO_목번호:j30:p1:l2516\", \"score\": 55},\n    {\"id\": \"003956:122_2_③_2._NO_목번호:j12:p1:l1609\", \"score\": 45},\n    {\"id\": \"003956:167_3_⑤_2._가.:j40:p1:l2526\", \"score\": 20},\n    {\"id\": \"001565:89_NO_조문가지번호_①_3._나.:j7:p1:l1091\", \"score\": 10},\n    {\"id\": \"003956:155",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 500,
#                 "prompt_tokens": 10960,
#                 "total_tokens": 11460,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_44848d1550",
#               "id": "chatcmpl-D6K1lx8DZFlS1AW6MwlFPKGIVPzZ2",
#               "service_tier": "default",
#               "finish_reason": "length",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c3405-da76-7c20-bdc6-2547d275a282-0",
#             "usage_metadata": {
#               "input_tokens": 10960,
#               "output_tokens": 500,
#               "total_tokens": 11460,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 500,
#       "prompt_tokens": 10960,
#       "total_tokens": 11460,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_44848d1550",
#     "id": "chatcmpl-D6K1lx8DZFlS1AW6MwlFPKGIVPzZ2",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "scores": [
#     {
#       "id": "001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93",
#       "score": 60
#     },
#     {
#       "id": "003956:122_2_⑦_2._NO_목번호:j23:p1:l1620",
#       "score": 85
#     },
#     {
#       "id": "001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567",
#       "score": 35
#     },
#     {
#       "id": "003956:167_3_①_3._NO_목번호:j14:p1:l2500",
#       "score": 40
#     },
#     {
#       "id": "001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32",
#       "score": 25
#     },
#     {
#       "id": "003608:92_2_④_5._NO_목번호:j72:p1:l1673",
#       "score": 30
#     },
#     {
#       "id": "001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985",
#       "score": 20
#     },
#     {
#       "id": "007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111",
#       "score": 15
#     },
#     {
#       "id": "001565:64_2_①_2._가.:j5:p1:l757",
#       "score": 65
#     },
#     {
#       "id": "003956:167_10_①_15._NO_목번호:j18:p1:l2596",
#       "score": 50
#     },
#     {
#       "id": "003956:167_3_①_13._NO_목번호:j30:p1:l2516",
#       "score": 55
#     },
#     {
#       "id": "003956:122_2_③_2._NO_목번호:j12:p1:l1609",
#       "score": 45
#     },
#     {
#       "id": "003956:167_3_⑤_2._가.:j40:p1:l2526",
#       "score": 20
#     },
#     {
#       "id": "001565:89_NO_조문가지번호_①_3._나.:j7:p1:l1091",
#       "score": 10
#     },
#     {
#       "id": "003956:155"
#     }
#   ]
# }
# [chain/end] [chain:RunnableSequence] [10.56s] Exiting Chain run with output:
# {
#   "scores": [
#     {
#       "id": "001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93",
#       "score": 60
#     },
#     {
#       "id": "003956:122_2_⑦_2._NO_목번호:j23:p1:l1620",
#       "score": 85
#     },
#     {
#       "id": "001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567",
#       "score": 35
#     },
#     {
#       "id": "003956:167_3_①_3._NO_목번호:j14:p1:l2500",
#       "score": 40
#     },
#     {
#       "id": "001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32",
#       "score": 25
#     },
#     {
#       "id": "003608:92_2_④_5._NO_목번호:j72:p1:l1673",
#       "score": 30
#     },
#     {
#       "id": "001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985",
#       "score": 20
#     },
#     {
#       "id": "007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111",
#       "score": 15
#     },
#     {
#       "id": "001565:64_2_①_2._가.:j5:p1:l757",
#       "score": 65
#     },
#     {
#       "id": "003956:167_10_①_15._NO_목번호:j18:p1:l2596",
#       "score": 50
#     },
#     {
#       "id": "003956:167_3_①_13._NO_목번호:j30:p1:l2516",
#       "score": 55
#     },
#     {
#       "id": "003956:122_2_③_2._NO_목번호:j12:p1:l1609",
#       "score": 45
#     },
#     {
#       "id": "003956:167_3_⑤_2._가.:j40:p1:l2526",
#       "score": 20
#     },
#     {
#       "id": "001565:89_NO_조문가지번호_①_3._나.:j7:p1:l1091",
#       "score": 10
#     },
#     {
#       "id": "003956:155"
#     }
#   ]
# }
# reranking 오류: slice indices must be integers or None or have an __index__ method
# [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93
# 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.
#
# [문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620
# 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.
#
#  <img src="http://www.law.go.kr/flDownload.do?flSeq=40489693" alt="img40489693" >
#
#  ┌──────────────────────────────────┐
#
#  │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│
#
#  │[ 발생한 수입금액 [ 기간에 발생한 │
#
#  │ 수입금액 │
#
#  └──────────────────────────────────┘
#
#  </img>
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "context": "[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\n나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.\n\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\n2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>",
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "context": "[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\n나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.\n\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\n2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>",
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문가야. 아래의 문백을 바탕으로 질문에 답변해.\n    반드시 아래의 JSON 형식을 지켜서 출력해\n\n    [문맥]\n    [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\n나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.\n\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\n2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>\n\n    [질문]\n    미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?\n\n    [출력 형식-JSON]\n    {\n      \"answer\": \"질문에 대한 답변 (결론 선제시, 논리적 근거 설명)\",\n      \"used_ids\": [\"문서 ID1\", \"문서 ID2\"]\n    }"
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [2.10s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"answer\": \"네, 임대소득세 과세대상입니다. 본인이 보유한 주택에서 발생하는 임대소득은 과세 대상이며, 부모님이 소유한 주택에서 거주하는 경우에는 해당 주택의 임대소득이 본인에게 귀속되지 않으므로 과세 대상이 아닙니다. 즉, 본인 소유의 주택에서 발생하는 임대소득만 과세 대상이며, 부모님 소유의 주택에서 거주하는 경우에는 임대소득이 아니기 때문에 과세 대상이 아닙니다.\",\n  \"used_ids\": [\"001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\"]\n}",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"answer\": \"네, 임대소득세 과세대상입니다. 본인이 보유한 주택에서 발생하는 임대소득은 과세 대상이며, 부모님이 소유한 주택에서 거주하는 경우에는 해당 주택의 임대소득이 본인에게 귀속되지 않으므로 과세 대상이 아닙니다. 즉, 본인 소유의 주택에서 발생하는 임대소득만 과세 대상이며, 부모님 소유의 주택에서 거주하는 경우에는 임대소득이 아니기 때문에 과세 대상이 아닙니다.\",\n  \"used_ids\": [\"001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\"]\n}",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 163,
#                 "prompt_tokens": 496,
#                 "total_tokens": 659,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_de604bd877",
#               "id": "chatcmpl-D6K1vt6CWx46vw8As1W4B7mLOzBxk",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c3406-03b4-75d0-8558-82e572e07a75-0",
#             "usage_metadata": {
#               "input_tokens": 496,
#               "output_tokens": 163,
#               "total_tokens": 659,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 163,
#       "prompt_tokens": 496,
#       "total_tokens": 659,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_de604bd877",
#     "id": "chatcmpl-D6K1vt6CWx46vw8As1W4B7mLOzBxk",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "answer": "네, 임대소득세 과세대상입니다. 본인이 보유한 주택에서 발생하는 임대소득은 과세 대상이며, 부모님이 소유한 주택에서 거주하는 경우에는 해당 주택의 임대소득이 본인에게 귀속되지 않으므로 과세 대상이 아닙니다. 즉, 본인 소유의 주택에서 발생하는 임대소득만 과세 대상이며, 부모님 소유의 주택에서 거주하는 경우에는 임대소득이 아니기 때문에 과세 대상이 아닙니다.",
#   "used_ids": [
#     "001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93"
#   ]
# }
# [chain/end] [chain:RunnableSequence] [2.10s] Exiting Chain run with output:
# {
#   "answer": "네, 임대소득세 과세대상입니다. 본인이 보유한 주택에서 발생하는 임대소득은 과세 대상이며, 부모님이 소유한 주택에서 거주하는 경우에는 해당 주택의 임대소득이 본인에게 귀속되지 않으므로 과세 대상이 아닙니다. 즉, 본인 소유의 주택에서 발생하는 임대소득만 과세 대상이며, 부모님 소유의 주택에서 거주하는 경우에는 임대소득이 아니기 때문에 과세 대상이 아닙니다.",
#   "used_ids": [
#     "001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93"
#   ]
# }
# 네, 임대소득세 과세대상입니다. 본인이 보유한 주택에서 발생하는 임대소득은 과세 대상이며, 부모님이 소유한 주택에서 거주하는 경우에는 해당 주택의 임대소득이 본인에게 귀속되지 않으므로 과세 대상이 아닙니다. 즉, 본인 소유의 주택에서 발생하는 임대소득만 과세 대상이며, 부모님 소유의 주택에서 거주하는 경우에는 임대소득이 아니기 때문에 과세 대상이 아닙니다.
#
# [근거 법령 및 본문]
# 소득세법 12조 2호 나목: 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.

# %%
import re

class Reference:

  def strip_dot(self, text):
    if not text:
      return ""
    return text.rstrip(".")

  def clean_content(self, text):
    if not text:
      return text

    text = text.strip()

    text = re.sub(r"^[①②③④⑤⑥⑦⑧⑨⑩]+\s*", "", text)
    text = re.sub(r"^\d+\.\s*", "", text)
    text = re.sub(r"^[가-힣]\.\s*", "", text)

    return text.strip()

  def make_reference(self, doc, max_law_chars):
    출처 = ""
    meta = doc.metadata
    law_name = meta.get("law_name")
    출처 += law_name
    조문번호 = meta.get("조문번호", "")
    출처 += f" {조문번호}조" if 조문번호 else ""
    항번호 = meta.get("항번호", "")
    출처 += f" {self.strip_dot(항번호)}항" if 항번호 else ""
    호번호 = meta.get("호번호", "")
    출처 += f" {self.strip_dot(호번호)}호" if 호번호 else ""
    목번호 = meta.get("목번호", "")
    출처 += f" {self.strip_dot(목번호)}목" if 목번호 else ""

    content = self.clean_content(doc.page_content)
    if len(content) > max_law_chars:
      content = content[:max_law_chars] + "..."

    return 출처, content

  def match_id(self, cited_id, docs_id):
    if cited_id in docs_id:
      return cited_id

    # cited_id = str(cited_id)

    for k in docs_id:
      # k = str(k)
      if k.startswith(cited_id) or cited_id.startswith(k):
        return k

  def final_output(self, query, pipeline, max_law_chars=400, k_preliminary=2):
    answer, reranked_docs = pipeline.generate_answer(query)

    docs_list = {}
    for i, doc in enumerate(reranked_docs, 1):
      doc_id = getattr(doc, "id", None)
      if doc_id is None:
        doc_id = f"NO_ID_doc{i}"

      docs_list[doc_id] = doc

    ids = re.findall(r"ID:([^\s,]+)", answer)
    print("ids: ", ids)

    answer = re.sub(r"\n?\[출처\][\s\S]*$", "", answer.strip()).strip()

    if not ids:
      ids = list(docs_list.keys())[:k_preliminary]

    used_docs = []
    seen = set()
    docs_id = list(docs_list.keys())

    for id in ids:
      matched = self.match_id(id, docs_id)
      if matched is not None:
        used_docs.append(docs_list[matched])
        seen.add(matched)

    print("docs_id", docs_id)
    print("used_docs", used_docs)

    reference = []
    for doc in used_docs:
      출처, content = self.make_reference(doc, max_law_chars)
      reference.append(f"{출처}: {content}")

    final_output = answer + "\n\n[근거 법령 및 본문]\n" + "\n\n".join(reference)

    return final_output

# %%
query = "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"

print(MultiQueryPipeline(prompt_multi_query, llm, 25, 10, vectorstore).generate_answer(query))
# Out:
# ①피상속인의 소득금액에 대한 소득세로서 상속인에게 과세할 것과 상속인의 소득금액에 대한 소득세는 구분하여 계산하여야 한다. <개정 2013.1.1>
#
# 나. 「소득세법」 제17조제1항 각 호에 따른 배당소득의 금액. 다만, 「상속세 및 증여세법」 제16조 또는 제48조에 따라 상속세 과세가액 또는 증여세 과세가액에 산입되거나 증여세가 부과되는 주식등으로부터 발생한 배당소득의 금액은 제외한다.
#
# ⑤ 자산양도소득에 대한 과세표준의 계산에 관하여는 「소득세법」 제101조 및 제102조를 준용하고, 자산양도소득에 대한 세액계산에 관하여는 같은 법 제92조를 준용한다. <개정 2023.12.31>
#
# 2. 소득ㆍ세액 공제 대상금액의 표기에 관한 사항
#
# 1. 수입금액에서 다음 각 목의 금액의 합계액(수입금액을 초과하는 경우에는 그 초과하는 금액은 제외한다)을 공제한 금액을 그 소득금액(이하 이 조에서 "기준소득금액"이라 한다)으로 결정 또는 경정하는 방법. 다만, 기준소득금액이 제1호의2에 따른 소득금액에 재정경제부령으로 정하는 배율을 곱하여 계산한 금액 이상인 경우 2027년 12월 31일이 속하는 과세기간의 소득금액을 결정 또는 경정할 때까지는 그 배율을 곱하여 계산한 금액을 소득금액으로 결정할 수 있다.
# [답변] 연간 소득금액 100만원 이하란 부양가족이 1년 동안 벌어들인 소득금액이 1백만원 이하임을 의미합니다.
#
# [근거] 소득세법 제54조의2 제1항 및 제1항 각 호에 따른 부양가족 공제 요건에 관한 규정.
#
# [결론 도출 과정] 부양가족 공제 요건 중 "연간 소득금액 100만원 이하"란, 해당 부양가족이 1년 동안 벌어들인 모든 소득(이자, 배당, 근로소득, 기타 소득 등)을 합산했을 때 그 금액이 1백만원 이하임을 의미하며, 이는 소득세법 제54조의2 제1항에서 규정하는 부양가족의 소득 기준에 해당합니다.
#
# [출처]
# ID:ids1

# %%
query = "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"

pipeline = MultiQueryPipeline(prompt_multi_query, llm, 25, 10, vectorstore)
print(Reference().final_output(query, pipeline))
# Out:
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n질문을 세법 전문 용어를 사용해 3개의 서로 다른 query로 재작성해.\n각 쿼리는 반드시 줄바꿈으로 구분해.\n\n질문: 소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?"
#   ]
# }
# [llm/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] [3.36s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 소득세법상 부양가족 공제 대상의 연간 소득금액 산정 기준에서 '100만원 이하'라는 요건의 구체적 의미와 산정 방법은 무엇인가요?\n\n2. 소득세법 제XX조에 규정된 부양가족 공제의 연간 소득금액 기준 '100만원 이하'의 의미와 해당 소득금액 산정 시 포함되는 소득 항목은 무엇인지 설명해 주시기 바랍니다.\n\n3. 소득세 신고 시 부양가족 공제 요건 중 '연간 소득금액 100만원 이하'의 구체적 의미와, 이를 판단하는 소득 산정 기준 및 적용 방법에 대해 상세히 설명해 주세요.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 소득세법상 부양가족 공제 대상의 연간 소득금액 산정 기준에서 '100만원 이하'라는 요건의 구체적 의미와 산정 방법은 무엇인가요?\n\n2. 소득세법 제XX조에 규정된 부양가족 공제의 연간 소득금액 기준 '100만원 이하'의 의미와 해당 소득금액 산정 시 포함되는 소득 항목은 무엇인지 설명해 주시기 바랍니다.\n\n3. 소득세 신고 시 부양가족 공제 요건 중 '연간 소득금액 100만원 이하'의 구체적 의미와, 이를 판단하는 소득 산정 기준 및 적용 방법에 대해 상세히 설명해 주세요.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 160,
#                 "prompt_tokens": 81,
#                 "total_tokens": 241,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_70fc5e01a5",
#               "id": "chatcmpl-D5uV974tW26Zv8nwE5I4crkgqP944",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e2c-9e82-7a52-93b2-d40d4f0e4a41-0",
#             "usage_metadata": {
#               "input_tokens": 81,
#               "output_tokens": 160,
#               "total_tokens": 241,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 160,
#       "prompt_tokens": 81,
#       "total_tokens": 241,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_70fc5e01a5",
#     "id": "chatcmpl-D5uV974tW26Zv8nwE5I4crkgqP944",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] s] Exiting Parser run with output:
# {
#   "output": [
#     "1. 소득세법상 부양가족 공제 대상의 연간 소득금액 산정 기준에서 '100만원 이하'라는 요건의 구체적 의미와 산정 방법은 무엇인가요?",
#     "2. 소득세법 제XX조에 규정된 부양가족 공제의 연간 소득금액 기준 '100만원 이하'의 의미와 해당 소득금액 산정 시 포함되는 소득 항목은 무엇인지 설명해 주시기 바랍니다.",
#     "3. 소득세 신고 시 부양가족 공제 요건 중 '연간 소득금액 100만원 이하'의 구체적 의미와, 이를 판단하는 소득 산정 기준 및 적용 방법에 대해 상세히 설명해 주세요."
#   ]
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence] [3.37s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 소득세법상 부양가족 공제 대상의 연간 소득금액 산정 기준에서 '100만원 이하'라는 요건의 구체적 의미와 산정 방법은 무엇인가요?",
#     "2. 소득세법 제XX조에 규정된 부양가족 공제의 연간 소득금액 기준 '100만원 이하'의 의미와 해당 소득금액 산정 시 포함되는 소득 항목은 무엇인지 설명해 주시기 바랍니다.",
#     "3. 소득세 신고 시 부양가족 공제 요건 중 '연간 소득금액 100만원 이하'의 구체적 의미와, 이를 판단하는 소득 산정 기준 및 적용 방법에 대해 상세히 설명해 주세요."
#   ]
# }
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?",
#   "docs": "[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712] 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원...\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532] ① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118] 3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148] 1의2. 법 제21조제1항제7호ㆍ제8호의2ㆍ제9호ㆍ제15호 및 제19호의 기타소득에 대해서는 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다....\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677] ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>...\n[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242] ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>...\n[문서 ID: 007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367] 2. 소득ㆍ세액 공제 대상금액의 표기에 관한 사항...\n[문서 ID: 001563:62_2_⑤_NO_호번호_NO_목번호:j9:p1:l697] ⑤ 자산양도소득에 대한 과세표준의 계산에 관하여는 「소득세법」 제101조 및 제102조를 준용하고, 자산양도소득에 대한 세액계산에 관하여는 같은 법 제92조를 준용한다. <개정 2023.12.31>...\n[문서 ID: 001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283] 나. 「소득세법」 제17조제1항 각 호에 따른 배당소득의 금액. 다만, 「상속세 및 증여세법」 제16조 또는 제48조에 따라 상속세 과세가액 또는 증여세 과세가액에 산입되거나 증여세가 부과되는 주식등으로부터 발생한 배당소득의 금액은 제외한다....\n[문서 ID: 003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306] 2. 거주자의 공제대상부양가족이 다른 거주자의 공제대상부양가족에 해당하는 때에는 직전 과세기간에 부양가족으로 인적공제를 받은 거주자의 공제대상부양가족으로 한다. 다만, 직전 과세기간에 부양가족으로 인적공제를 받은 사실이 없는 때에는 해당 과세기간의 종합소득금액이 가장 많은 거주자의 공제대상부양가족으로 한다....\n[문서 ID: 003608:138_5_②_8._NO_목번호:j23:p1:l2629] 8. 소득수취법인이 당해 소득에 대하여 부담할 세액이 법 제98조의 규정에 따른 세율을 적용하여 계산한 세액과 해당국과의 조세조약에 따라 과세될 세액과의 차익의 100분의 50 이상이 되는 경우...\n[문서 ID: 001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153] 가. 제21조제1항제1호부터 제8호까지, 제8호의2, 제9호부터 제20호까지, 제22호, 제22호의2 및 제26호에 따른 기타소득(라목 및 마목의 소득은 제외한다)으로서 같은 조 제3항에 따른 기타소득금액이 300만원 이하이면서 제127조에 따라 원천징수(제127조제1항제6호나목에 해당하여 원천징수되지 아니하는 경우를 포함한다)된 소득. 다만, 해당 소득이 있는 거주자가 종합소득과세표준을 계산할 때 그 소득을 합산하려는 경우 그 소득은 분리과세기타소득에서 제외한다....\n[문서 ID: 001565:47_2_①_NO_호번호_NO_목번호:j2:p1:l507] ①연금소득이 있는 거주자에 대해서는 해당 과세기간에 받은 총연금액(분리과세연금소득은 제외하며, 이하 이 항에서 같다)에서 다음 표에 규정된 금액을 공제한다. 다만, 공제액이 900만원을 초과하는 경우에는 900만원을 공제한다. <개정 2013.1.1> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=22185101\" alt=\"img22185101\" >\n \n ┌─────────────┬────────────────────────┐\n \n │총연금액 │공제액 │\n \n ├─────────────┼────────────────────────┤\n \n │350만원 이하 │총연금액 │\n \n ├─────────────┼────────────────────────┤\n \n │350만원 초과 700만원 이하 │350만원＋(350만원을 초과하는 금액의 100분의 40) │\n \n ├─────────────┼────────────────────────┤\n \n ...\n[문서 ID: 003956:216_2_①_7._NO_목번호:j12:p1:l3725] 7. 원천징수세액이 1천원 미만인 소득(법 제119조제9호 및 제11호에 따른 소득을 제외한다)...\n[문서 ID: 003956:80_NO_조문가지번호_②_1._NO_목번호:j25:p1:l1077] 1. 공익단체가 「상속세 및 증여세법」 제48조제2항, 제3항, 제8항부터 제11항까지, 제78조제5항제3호, 같은 조 제10항 및 제11항에 따라 1천만원 이상의 상속세(그 가산세를 포함한다) 또는 증여세(그 가산세를 포함한다)를 추징당한 경우...\n[문서 ID: 001563:75_7_③_2._NO_목번호:j14:p1:l873] 2. 2024년 1월 1일부터 2024년 12월 31일까지 「소득세법」 제164조의3제1항제3호의 소득을 지급하는 경우로서 해당 소득에 대한 지급명세서를 그 소득 지급일이 속하는 과세연도의 다음 연도 2월 말일(휴업, 폐업 또는 해산한 경우에는 휴업일, 폐업일 또는 해산일이 속하는 달의 다음다음 달 말일)까지 제출하는 경우...\n[문서 ID: 007507:64_NO_조문가지번호_NO_항번호_NO_호번호_NO_목번호:j1:p1:l434] 제64조(중간예납에서 제외되는 소득) 영 제123조제4호에서 \"재정경제부령이 정하는 소득\"이란 다음 각 호의 어느 하나에 규정하는 사업에서 발생한 소득을 말한다. 다만, 제3호의 경우에는 법 제144조의2에 따라 원천징수의무자가 직전 과세기간에 ...
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "query": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?",
#   "docs": "[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712] 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원...\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532] ① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118] 3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148] 1의2. 법 제21조제1항제7호ㆍ제8호의2ㆍ제9호ㆍ제15호 및 제19호의 기타소득에 대해서는 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다....\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677] ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>...\n[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242] ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>...\n[문서 ID: 007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367] 2. 소득ㆍ세액 공제 대상금액의 표기에 관한 사항...\n[문서 ID: 001563:62_2_⑤_NO_호번호_NO_목번호:j9:p1:l697] ⑤ 자산양도소득에 대한 과세표준의 계산에 관하여는 「소득세법」 제101조 및 제102조를 준용하고, 자산양도소득에 대한 세액계산에 관하여는 같은 법 제92조를 준용한다. <개정 2023.12.31>...\n[문서 ID: 001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283] 나. 「소득세법」 제17조제1항 각 호에 따른 배당소득의 금액. 다만, 「상속세 및 증여세법」 제16조 또는 제48조에 따라 상속세 과세가액 또는 증여세 과세가액에 산입되거나 증여세가 부과되는 주식등으로부터 발생한 배당소득의 금액은 제외한다....\n[문서 ID: 003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306] 2. 거주자의 공제대상부양가족이 다른 거주자의 공제대상부양가족에 해당하는 때에는 직전 과세기간에 부양가족으로 인적공제를 받은 거주자의 공제대상부양가족으로 한다. 다만, 직전 과세기간에 부양가족으로 인적공제를 받은 사실이 없는 때에는 해당 과세기간의 종합소득금액이 가장 많은 거주자의 공제대상부양가족으로 한다....\n[문서 ID: 003608:138_5_②_8._NO_목번호:j23:p1:l2629] 8. 소득수취법인이 당해 소득에 대하여 부담할 세액이 법 제98조의 규정에 따른 세율을 적용하여 계산한 세액과 해당국과의 조세조약에 따라 과세될 세액과의 차익의 100분의 50 이상이 되는 경우...\n[문서 ID: 001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153] 가. 제21조제1항제1호부터 제8호까지, 제8호의2, 제9호부터 제20호까지, 제22호, 제22호의2 및 제26호에 따른 기타소득(라목 및 마목의 소득은 제외한다)으로서 같은 조 제3항에 따른 기타소득금액이 300만원 이하이면서 제127조에 따라 원천징수(제127조제1항제6호나목에 해당하여 원천징수되지 아니하는 경우를 포함한다)된 소득. 다만, 해당 소득이 있는 거주자가 종합소득과세표준을 계산할 때 그 소득을 합산하려는 경우 그 소득은 분리과세기타소득에서 제외한다....\n[문서 ID: 001565:47_2_①_NO_호번호_NO_목번호:j2:p1:l507] ①연금소득이 있는 거주자에 대해서는 해당 과세기간에 받은 총연금액(분리과세연금소득은 제외하며, 이하 이 항에서 같다)에서 다음 표에 규정된 금액을 공제한다. 다만, 공제액이 900만원을 초과하는 경우에는 900만원을 공제한다. <개정 2013.1.1> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=22185101\" alt=\"img22185101\" >\n \n ┌─────────────┬────────────────────────┐\n \n │총연금액 │공제액 │\n \n ├─────────────┼────────────────────────┤\n \n │350만원 이하 │총연금액 │\n \n ├─────────────┼────────────────────────┤\n \n │350만원 초과 700만원 이하 │350만원＋(350만원을 초과하는 금액의 100분의 40) │\n \n ├─────────────┼────────────────────────┤\n \n ...\n[문서 ID: 003956:216_2_①_7._NO_목번호:j12:p1:l3725] 7. 원천징수세액이 1천원 미만인 소득(법 제119조제9호 및 제11호에 따른 소득을 제외한다)...\n[문서 ID: 003956:80_NO_조문가지번호_②_1._NO_목번호:j25:p1:l1077] 1. 공익단체가 「상속세 및 증여세법」 제48조제2항, 제3항, 제8항부터 제11항까지, 제78조제5항제3호, 같은 조 제10항 및 제11항에 따라 1천만원 이상의 상속세(그 가산세를 포함한다) 또는 증여세(그 가산세를 포함한다)를 추징당한 경우...\n[문서 ID: 001563:75_7_③_2._NO_목번호:j14:p1:l873] 2. 2024년 1월 1일부터 2024년 12월 31일까지 「소득세법」 제164조의3제1항제3호의 소득을 지급하는 경우로서 해당 소득에 대한 지급명세서를 그 소득 지급일이 속하는 과세연도의 다음 연도 2월 말일(휴업, 폐업 또는 해산한 경우에는 휴업일, 폐업일 또는 해산일이 속하는 달의 다음다음 달 말일)까지 제출하는 경우...\n[문서 ID: 007507:64_NO_조문가지번호_NO_항번호_NO_호번호_NO_목번호:j1:p1:l434] 제64조(중간예납에서 제외되는 소득) 영 제123조제4호에서 \"재정경제부령이 정하는 소득\"이란 다음 각 호의 어느 하나에 규정하는 사업에서 발생한 소득을 말한다. 다만, 제3호의 경우에는 법 제144조의2에 따라 원천징수의무자가 직전 과세기간에 ...
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문 지식을 가진 reranking 모델이야.\n    아래 질문에 대해 각 문서들이 답변 근거로 얼마나 관련성 있고 적합한지 점수로 평가해.\n    점수 범위: 0 ~ 100\n\n    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수\n    - 미세하게라도 점수에 차등을 둘 것\n    - 문서 간 비교를 하여 상대적인 점수를 계산할 것\n    - 반드시 아래의 JSON 형식으로만 답변할 것\n    - id는 문서ID를 그대로 복사해서 사용\n    \n    [질문]\n    소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?\n\n    [문서들]\n    [문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712] 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원...\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532] ① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>...\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118] 3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액...\n[문서 ID: 003956:87_NO_조문가지번호_NO_항번호_1._NO_목번호:j7:p1:l1148] 1의2. 법 제21조제1항제7호ㆍ제8호의2ㆍ제9호ㆍ제15호 및 제19호의 기타소득에 대해서는 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 필요경비로 한다. 다만, 실제 소요된 필요경비가 거주자가 받은 금액의 100분의 70(2019년 1월 1일이 속하는 과세기간에 발생한 소득분부터는 100분의 60)에 상당하는 금액을 초과하면 그 초과하는 금액도 필요경비에 산입한다....\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677] ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>...\n[문서 ID: 001565:103_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l1242] ① 양도소득이 있는 거주자에 대해서는 다음 각 호의 소득별로 해당 과세기간의 양도소득금액에서 각각 연 250만원을 공제한다. <개정 2014.12.23, 2020.12.29, 2024.12.31>...\n[문서 ID: 007507:58_NO_조문가지번호_④_2._NO_목번호:j33:p1:l367] 2. 소득ㆍ세액 공제 대상금액의 표기에 관한 사항...\n[문서 ID: 001563:62_2_⑤_NO_호번호_NO_목번호:j9:p1:l697] ⑤ 자산양도소득에 대한 과세표준의 계산에 관하여는 「소득세법」 제101조 및 제102조를 준용하고, 자산양도소득에 대한 세액계산에 관하여는 같은 법 제92조를 준용한다. <개정 2023.12.31>...\n[문서 ID: 001563:29_NO_조문가지번호_①_1._나.:j5:p1:l283] 나. 「소득세법」 제17조제1항 각 호에 따른 배당소득의 금액. 다만, 「상속세 및 증여세법」 제16조 또는 제48조에 따라 상속세 과세가액 또는 증여세 과세가액에 산입되거나 증여세가 부과되는 주식등으로부터 발생한 배당소득의 금액은 제외한다....\n[문서 ID: 003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306] 2. 거주자의 공제대상부양가족이 다른 거주자의 공제대상부양가족에 해당하는 때에는 직전 과세기간에 부양가족으로 인적공제를 받은 거주자의 공제대상부양가족으로 한다. 다만, 직전 과세기간에 부양가족으로 인적공제를 받은 사실이 없는 때에는 해당 과세기간의 종합소득금액이 가장 많은 거주자의 공제대상부양가족으로 한다....\n[문서 ID: 003608:138_5_②_8._NO_목번호:j23:p1:l2629] 8. 소득수취법인이 당해 소득에 대하여 부담할 세액이 법 제98조의 규정에 따른 세율을 적용하여 계산한 세액과 해당국과의 조세조약에 따라 과세될 세액과의 차익의 100분의 50 이상이 되는 경우...\n[문서 ID: 001565:14_NO_조문가지번호_③_8._가.:j13:p1:l153] 가. 제21조제1항제1호부터 제8호까지, 제8호의2, 제9호부터 제20호까지, 제22호, 제22호의2 및 제26호에 따른 기타소득(라목 및 마목의 소득은 제외한다)으로서 같은 조 제3항에 따른 기타소득금액이 300만원 이하이면서 제127조에 따라 원천징수(제127조제1항제6호나목에 해당하여 원천징수되지 아니하는 경우를 포함한다)된 소득. 다만, 해당 소득이 있는 거주자가 종합소득과세표준을 계산할 때 그 소득을 합산하려는 경우 그 소득은 분리과세기타소득에서 제외한다....\n[문서 ID: 001565:47_2_①_NO_호번호_NO_목번호:j2:p1:l507] ①연금소득이 있는 거주자에 대해서는 해당 과세기간에 받은 총연금액(분리과세연금소득은 제외하며, 이하 이 항에서 같다)에서 다음 표에 규정된 금액을 공제한다. 다만, 공제액이 900만원을 초과하는 경우에는 900만원을 공제한다. <개정 2013.1.1> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=22185101\" alt=\"img22185101\" >\n \n ┌─────────────┬────────────────────────┐\n \n │총연금액 │공제액 │\n \n ├─────────────┼────────────────────────┤\n \n │350만원 이하 │총연금액 │\n \n ├─────────────┼────────────────────────┤\n \n │350만원 초과 700만원 이하 │350만원＋(350만원을 초과하는 금액의 100분의 40) │\n \n ├─────────────┼────────────────────────┤\n \n ...\n[문서 ID: 003956:216_2_①_7._NO_목번호:j12:p1:l3725] 7. 원천징수세액이 1천원 미만인 소득(법 제119조제9호 및 제11호에 따른 소득을 제외한다)...\n[문서 ID: 003956:80_NO_조문가지번호_②_1._NO_목번호:j25:p1:l1077] 1. 공익단체가 「상속세 및 증여세법」 제48조제2항, 제3항, 제8항부터 제11항까지, 제78조제5항제3호, 같은 조 제10항 및 제11항에 따라 1천만원 이상의 상속세(그 가산세를 포함한다) 또는 증여세(그 가산세를 포함한다)를 추징당한 경우...\n[문서 ID: 001563:75_7_③_2._NO_목번호:j14:p1:l873] 2. 2024년 1월 1일부터  ...
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [5.06s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"scores\": [\n    {\"id\": \"001565:59_4_⑨_1._NO_목번호:j40:p1:l712\", \"score\": 10},\n    {\"id\": \"003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532\", \"score\": 5},\n    {\"id\": \"003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\", \"score\": 25},\n    {\"id\": \"001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118\", \"score\": 20},\n    {\"id\": \"001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677\", \"score\": 33},\n    {\"id\": \"001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328\", \"score\": 35},\n    {\"id\": \"003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306\", \"score\": 28},\n    {\"id\": \"001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647\", \"score\": 50},\n    {\"id\": \"001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766\", \"score\": 45},\n    {\"id\": \"001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519\", \"score\": 55}\n  ]\n}",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"scores\": [\n    {\"id\": \"001565:59_4_⑨_1._NO_목번호:j40:p1:l712\", \"score\": 10},\n    {\"id\": \"003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532\", \"score\": 5},\n    {\"id\": \"003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\", \"score\": 25},\n    {\"id\": \"001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118\", \"score\": 20},\n    {\"id\": \"001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677\", \"score\": 33},\n    {\"id\": \"001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328\", \"score\": 35},\n    {\"id\": \"003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306\", \"score\": 28},\n    {\"id\": \"001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647\", \"score\": 50},\n    {\"id\": \"001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766\", \"score\": 45},\n    {\"id\": \"001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519\", \"score\": 55}\n  ]\n}",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 376,
#                 "prompt_tokens": 10156,
#                 "total_tokens": 10532,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_b6501e8a2c",
#               "id": "chatcmpl-D5uVOaiuF4kqenUbCbmTIDLHgVYFR",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e2c-ddfe-7be1-9337-9745826facb0-0",
#             "usage_metadata": {
#               "input_tokens": 10156,
#               "output_tokens": 376,
#               "total_tokens": 10532,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 376,
#       "prompt_tokens": 10156,
#       "total_tokens": 10532,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_b6501e8a2c",
#     "id": "chatcmpl-D5uVOaiuF4kqenUbCbmTIDLHgVYFR",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "scores": [
#     {
#       "id": "001565:59_4_⑨_1._NO_목번호:j40:p1:l712",
#       "score": 10
#     },
#     {
#       "id": "003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532",
#       "score": 5
#     },
#     {
#       "id": "003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960",
#       "score": 25
#     },
#     {
#       "id": "001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118",
#       "score": 20
#     },
#     {
#       "id": "001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677",
#       "score": 33
#     },
#     {
#       "id": "001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328",
#       "score": 35
#     },
#     {
#       "id": "003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306",
#       "score": 28
#     },
#     {
#       "id": "001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647",
#       "score": 50
#     },
#     {
#       "id": "001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766",
#       "score": 45
#     },
#     {
#       "id": "001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519",
#       "score": 55
#     }
#   ]
# }
# [chain/end] [chain:RunnableSequence] [5.06s] Exiting Chain run with output:
# {
#   "scores": [
#     {
#       "id": "001565:59_4_⑨_1._NO_목번호:j40:p1:l712",
#       "score": 10
#     },
#     {
#       "id": "003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532",
#       "score": 5
#     },
#     {
#       "id": "003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960",
#       "score": 25
#     },
#     {
#       "id": "001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118",
#       "score": 20
#     },
#     {
#       "id": "001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677",
#       "score": 33
#     },
#     {
#       "id": "001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328",
#       "score": 35
#     },
#     {
#       "id": "003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306",
#       "score": 28
#     },
#     {
#       "id": "001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647",
#       "score": 50
#     },
#     {
#       "id": "001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766",
#       "score": 45
#     },
#     {
#       "id": "001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519",
#       "score": 55
#     }
#   ]
# }
# [문서 ID: 001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519
# ① 종합소득이 있는 거주자(자연인만 해당한다)에 대해서는 다음 각 호의 어느 하나에 해당하는 사람의 수에 1명당 연 150만원을 곱하여 계산한 금액을 그 거주자의 해당 과세기간의 종합소득금액에서 공제한다. <개정 2015.12.15, 2024.12.31>
#
# [문서 ID: 001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647
# ①근로소득이 있는 거주자에 대해서는 그 근로소득에 대한 종합소득산출세액에서 다음의 금액을 공제한다. <개정 2014.1.1, 2015.5.13>
#
#  <img src="http://www.law.go.kr/flDownload.do?flSeq=22185317" alt="img22185317" >
#
#  ┌─────────────────┬───────────────────────┐
#
#  │근로소득에 대한 종합소득 산출세액 │공제액 │
#
#  ├─────────────────┼───────────────────────┤
#
#  │130만원 이하 │산출세액의 100분의 55 │
#
#  ├─────────────────┼───────────────────────┤
#
#  │130만원 초과 │71만5천원＋(130만원을 초과하는 금액의 100분의 │
#
#  │ │30) │
#
#  └─────────────────┴───────────────────────┘
#
#  </img>
#
# [문서 ID: 001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766
# ① 제14조에 따라 종합소득과세표준을 계산할 때 제127조제1항제6호나목의 소득을 합산하지 아니하는 경우 그 합산하지 아니하는 기타소득에 대한 결정세액은 해당 기타소득금액에 제129조제1항제6호라목의 세율을 적용하여 계산한 금액으로 한다. <개정 2020.12.29>
#
# [문서 ID: 001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328
# ② 해당 과세기간에 누진세율 적용대상 자산에 대한 예정신고를 2회 이상 하는 경우로서 거주자가 이미 신고한 양도소득금액과 합산하여 신고하려는 경우에는 다음 각 호의 구분에 따른 금액을 제2회 이후 신고하는 예정신고 산출세액으로 한다. <개정 2017.12.19, 2020.12.29, 2024.12.31>
#
# [문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677
# ② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>
#
# [문서 ID: 003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306
# 2. 거주자의 공제대상부양가족이 다른 거주자의 공제대상부양가족에 해당하는 때에는 직전 과세기간에 부양가족으로 인적공제를 받은 거주자의 공제대상부양가족으로 한다. 다만, 직전 과세기간에 부양가족으로 인적공제를 받은 사실이 없는 때에는 해당 과세기간의 종합소득금액이 가장 많은 거주자의 공제대상부양가족으로 한다.
#
# [문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960
# 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.
#
# [문서 ID: 001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118
# 3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액
#
# [문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712
# 1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원
#
# [문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532
# ① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "context": "[문서 ID: 001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519\n① 종합소득이 있는 거주자(자연인만 해당한다)에 대해서는 다음 각 호의 어느 하나에 해당하는 사람의 수에 1명당 연 150만원을 곱하여 계산한 금액을 그 거주자의 해당 과세기간의 종합소득금액에서 공제한다. <개정 2015.12.15, 2024.12.31>\n\n[문서 ID: 001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647\n①근로소득이 있는 거주자에 대해서는 그 근로소득에 대한 종합소득산출세액에서 다음의 금액을 공제한다. <개정 2014.1.1, 2015.5.13> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=22185317\" alt=\"img22185317\" >\n \n ┌─────────────────┬───────────────────────┐\n \n │근로소득에 대한 종합소득 산출세액 │공제액 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 이하 │산출세액의 100분의 55 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 초과 │71만5천원＋(130만원을 초과하는 금액의 100분의 │\n \n │ │30) │\n \n └─────────────────┴───────────────────────┘\n \n </img>\n\n[문서 ID: 001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766\n① 제14조에 따라 종합소득과세표준을 계산할 때 제127조제1항제6호나목의 소득을 합산하지 아니하는 경우 그 합산하지 아니하는 기타소득에 대한 결정세액은 해당 기타소득금액에 제129조제1항제6호라목의 세율을 적용하여 계산한 금액으로 한다. <개정 2020.12.29>\n\n[문서 ID: 001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328\n② 해당 과세기간에 누진세율 적용대상 자산에 대한 예정신고를 2회 이상 하는 경우로서 거주자가 이미 신고한 양도소득금액과 합산하여 신고하려는 경우에는 다음 각 호의 구분에 따른 금액을 제2회 이후 신고하는 예정신고 산출세액으로 한다. <개정 2017.12.19, 2020.12.29, 2024.12.31>\n\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677\n② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>\n\n[문서 ID: 003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306\n2. 거주자의 공제대상부양가족이 다른 거주자의 공제대상부양가족에 해당하는 때에는 직전 과세기간에 부양가족으로 인적공제를 받은 거주자의 공제대상부양가족으로 한다. 다만, 직전 과세기간에 부양가족으로 인적공제를 받은 사실이 없는 때에는 해당 과세기간의 종합소득금액이 가장 많은 거주자의 공제대상부양가족으로 한다.\n\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\n3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.\n\n[문서 ID: 001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118\n3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액\n\n[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712\n1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원\n\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532\n① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>",
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?",
#   "final_k": 10
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "context": "[문서 ID: 001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519\n① 종합소득이 있는 거주자(자연인만 해당한다)에 대해서는 다음 각 호의 어느 하나에 해당하는 사람의 수에 1명당 연 150만원을 곱하여 계산한 금액을 그 거주자의 해당 과세기간의 종합소득금액에서 공제한다. <개정 2015.12.15, 2024.12.31>\n\n[문서 ID: 001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647\n①근로소득이 있는 거주자에 대해서는 그 근로소득에 대한 종합소득산출세액에서 다음의 금액을 공제한다. <개정 2014.1.1, 2015.5.13> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=22185317\" alt=\"img22185317\" >\n \n ┌─────────────────┬───────────────────────┐\n \n │근로소득에 대한 종합소득 산출세액 │공제액 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 이하 │산출세액의 100분의 55 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 초과 │71만5천원＋(130만원을 초과하는 금액의 100분의 │\n \n │ │30) │\n \n └─────────────────┴───────────────────────┘\n \n </img>\n\n[문서 ID: 001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766\n① 제14조에 따라 종합소득과세표준을 계산할 때 제127조제1항제6호나목의 소득을 합산하지 아니하는 경우 그 합산하지 아니하는 기타소득에 대한 결정세액은 해당 기타소득금액에 제129조제1항제6호라목의 세율을 적용하여 계산한 금액으로 한다. <개정 2020.12.29>\n\n[문서 ID: 001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328\n② 해당 과세기간에 누진세율 적용대상 자산에 대한 예정신고를 2회 이상 하는 경우로서 거주자가 이미 신고한 양도소득금액과 합산하여 신고하려는 경우에는 다음 각 호의 구분에 따른 금액을 제2회 이후 신고하는 예정신고 산출세액으로 한다. <개정 2017.12.19, 2020.12.29, 2024.12.31>\n\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677\n② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>\n\n[문서 ID: 003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306\n2. 거주자의 공제대상부양가족이 다른 거주자의 공제대상부양가족에 해당하는 때에는 직전 과세기간에 부양가족으로 인적공제를 받은 거주자의 공제대상부양가족으로 한다. 다만, 직전 과세기간에 부양가족으로 인적공제를 받은 사실이 없는 때에는 해당 과세기간의 종합소득금액이 가장 많은 거주자의 공제대상부양가족으로 한다.\n\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\n3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.\n\n[문서 ID: 001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118\n3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액\n\n[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712\n1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원\n\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532\n① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>",
#   "question": "소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?",
#   "final_k": 10
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 회계, 세법 전문가야. 아래의 context를 근거로 다음 규칙에 따라 질문에 답변해.\n\n    [규칙]\n    1. 결론: 질문에 대한 답은 한 문장으로 먼저 제시 (ex. \"납부할 세액은 1,000,000원입니다.\" \"해당 항목은 익금산입 대상입니다.\")\n    2. 출처는 context에등장하는 [문서 ID: ...]의 값만 그대로 복사해서 사용. (요약, 생략 불가)\n\n    [문맥]\n    [문서 ID: 001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519\n① 종합소득이 있는 거주자(자연인만 해당한다)에 대해서는 다음 각 호의 어느 하나에 해당하는 사람의 수에 1명당 연 150만원을 곱하여 계산한 금액을 그 거주자의 해당 과세기간의 종합소득금액에서 공제한다. <개정 2015.12.15, 2024.12.31>\n\n[문서 ID: 001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647\n①근로소득이 있는 거주자에 대해서는 그 근로소득에 대한 종합소득산출세액에서 다음의 금액을 공제한다. <개정 2014.1.1, 2015.5.13> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=22185317\" alt=\"img22185317\" >\n \n ┌─────────────────┬───────────────────────┐\n \n │근로소득에 대한 종합소득 산출세액 │공제액 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 이하 │산출세액의 100분의 55 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 초과 │71만5천원＋(130만원을 초과하는 금액의 100분의 │\n \n │ │30) │\n \n └─────────────────┴───────────────────────┘\n \n </img>\n\n[문서 ID: 001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766\n① 제14조에 따라 종합소득과세표준을 계산할 때 제127조제1항제6호나목의 소득을 합산하지 아니하는 경우 그 합산하지 아니하는 기타소득에 대한 결정세액은 해당 기타소득금액에 제129조제1항제6호라목의 세율을 적용하여 계산한 금액으로 한다. <개정 2020.12.29>\n\n[문서 ID: 001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328\n② 해당 과세기간에 누진세율 적용대상 자산에 대한 예정신고를 2회 이상 하는 경우로서 거주자가 이미 신고한 양도소득금액과 합산하여 신고하려는 경우에는 다음 각 호의 구분에 따른 금액을 제2회 이후 신고하는 예정신고 산출세액으로 한다. <개정 2017.12.19, 2020.12.29, 2024.12.31>\n\n[문서 ID: 001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677\n② 근로소득이 있는 거주자가 기본공제대상자(나이 및 소득의 제한을 받지 아니한다)를 위하여 해당 과세기간에 대통령령으로 정하는 의료비를 지급한 경우 다음 각 호의 금액의 100분의 15(제3호의 경우에는 100분의 20, 제4호의 경우에는 100분의 30)에 해당하는 금액을 해당 과세기간의 종합소득산출세액에서 공제한다. <개정 2014.12.23, 2016.12.20, 2017.12.19, 2021.12.8, 2023.12.31>\n\n[문서 ID: 003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306\n2. 거주자의 공제대상부양가족이 다른 거주자의 공제대상부양가족에 해당하는 때에는 직전 과세기간에 부양가족으로 인적공제를 받은 거주자의 공제대상부양가족으로 한다. 다만, 직전 과세기간에 부양가족으로 인적공제를 받은 사실이 없는 때에는 해당 과세기간의 종합소득금액이 가장 많은 거주자의 공제대상부양가족으로 한다.\n\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\n3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.\n\n[문서 ID: 001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118\n3. 「조세특례제한법」 제100조의18제1항에 따라 배분받은 소득금액\n\n[문서 ID: 001565:59_4_⑨_1._NO_목번호:j40:p1:l712\n1. 근로소득이 있는 거주자로서 제6항, 제52조제8항 및 「조세특례제한법」 제95조의2제2항에 따른 소득공제나 세액공제 신청을 하지 아니한 경우: 연 13만원\n\n[문서 ID: 003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532\n① 법 제98조에 따라 원천징수를 하는 경우 배당소득의 지급시기에 관하여는 「소득세법」 제131조제2항 및 같은 법 시행령 제191조(제4호는 제외한다)를 준용하고, 기타소득의 지급시기에 관하여는 「소득세법」 제145조의2 및 같은 법 시행령 제202조제3항을 준용한다. <개정 2012.2.2>\n\n    [질문]\n    소득세 신고시 부양가족 공제 요건 중 연간 소득금액 100만원 이하란 구체적으로 무엇을 말하나요?\n\n    <출력 형식>\n    [답변]\n    1. 결론: ...\n    2. 근거 법령: ...\n    3. 결론 도출 과정: ...\n\n    [출처]\n    [\"문서 ID1\", \"문서 ID2\", ...]\n    - 답변 생성에 사용한 문서의 ID만 작성\n    - 1 ~ 10개의 문서 ID 작성"
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [4.24s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "[답변]\n1. 결론: 연간 소득금액 100만원 이하란, 부양가족이 해당 과세기간 동안 벌어들인 모든 소득의 합계가 1,000,000원 이하임을 의미합니다.\n2. 근거 법령: [문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960]\n3. 결론 도출 과정: 해당 문서에서는 부양가족의 소득이 기준 중위소득의 40% 이상인 경우를 규정하고 있으며, 연간 소득금액이 100만원 이하인 경우는 별도로 명시되어 있지 않으나, 일반적으로 부양가족 공제 요건 중 소득 기준이 100만원 이하임을 의미하는 것으로 해석됩니다.\n\n[출처]\n[\"문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\"]",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "[답변]\n1. 결론: 연간 소득금액 100만원 이하란, 부양가족이 해당 과세기간 동안 벌어들인 모든 소득의 합계가 1,000,000원 이하임을 의미합니다.\n2. 근거 법령: [문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960]\n3. 결론 도출 과정: 해당 문서에서는 부양가족의 소득이 기준 중위소득의 40% 이상인 경우를 규정하고 있으며, 연간 소득금액이 100만원 이하인 경우는 별도로 명시되어 있지 않으나, 일반적으로 부양가족 공제 요건 중 소득 기준이 100만원 이하임을 의미하는 것으로 해석됩니다.\n\n[출처]\n[\"문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\"]",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 219,
#                 "prompt_tokens": 1708,
#                 "total_tokens": 1927,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_de604bd877",
#               "id": "chatcmpl-D5uVUACIHqxMGahaZXSL9C5PGzYSF",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e2c-f1c7-7cf3-92e1-bbce056664fe-0",
#             "usage_metadata": {
#               "input_tokens": 1708,
#               "output_tokens": 219,
#               "total_tokens": 1927,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 219,
#       "prompt_tokens": 1708,
#       "total_tokens": 1927,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_de604bd877",
#     "id": "chatcmpl-D5uVUACIHqxMGahaZXSL9C5PGzYSF",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "[답변]\n1. 결론: 연간 소득금액 100만원 이하란, 부양가족이 해당 과세기간 동안 벌어들인 모든 소득의 합계가 1,000,000원 이하임을 의미합니다.\n2. 근거 법령: [문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960]\n3. 결론 도출 과정: 해당 문서에서는 부양가족의 소득이 기준 중위소득의 40% 이상인 경우를 규정하고 있으며, 연간 소득금액이 100만원 이하인 경우는 별도로 명시되어 있지 않으나, 일반적으로 부양가족 공제 요건 중 소득 기준이 100만원 이하임을 의미하는 것으로 해석됩니다.\n\n[출처]\n[\"문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\"]"
# }
# [chain/end] [chain:RunnableSequence] [4.25s] Exiting Chain run with output:
# {
#   "output": "[답변]\n1. 결론: 연간 소득금액 100만원 이하란, 부양가족이 해당 과세기간 동안 벌어들인 모든 소득의 합계가 1,000,000원 이하임을 의미합니다.\n2. 근거 법령: [문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960]\n3. 결론 도출 과정: 해당 문서에서는 부양가족의 소득이 기준 중위소득의 40% 이상인 경우를 규정하고 있으며, 연간 소득금액이 100만원 이하인 경우는 별도로 명시되어 있지 않으나, 일반적으로 부양가족 공제 요건 중 소득 기준이 100만원 이하임을 의미하는 것으로 해석됩니다.\n\n[출처]\n[\"문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\"]"
# }
# ids:  []
# docs_id ['001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519', '001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647', '001565:64_3_①_NO_호번호_NO_목번호:j2:p1:l766', '001565:107_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1328', '001565:59_4_②_NO_호번호_NO_목번호:j5:p1:l677', '003956:106_NO_조문가지번호_②_2._NO_목번호:j5:p1:l1306', '003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960', '001563:15_NO_조문가지번호_②_3._NO_목번호:j6:p1:l118', '001565:59_4_⑨_1._NO_목번호:j40:p1:l712', '003608:137_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2532']
# used_docs [Document(id='001565:50_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l519', metadata={'law_name': '소득세법', 'law_id': '001565', 'file_line_no': 519, '조문제목': '기본공제', '시행일자': '20251001', 'piece_count': 1, '항번호': '①', 'level': '항', 'source': '법령정보센터', '조문번호': '50', '공포일자': '20251001', 'piece_index': 1, '조문_index': 2}, page_content='① 종합소득이 있는 거주자(자연인만 해당한다)에 대해서는 다음 각 호의 어느 하나에 해당하는 사람의 수에 1명당 연 150만원을 곱하여 계산한 금액을 그 거주자의 해당 과세기간의 종합소득금액에서 공제한다. <개정 2015.12.15, 2024.12.31>'), Document(id='001565:59_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l647', metadata={'piece_count': 1, 'piece_index': 1, 'law_id': '001565', 'law_name': '소득세법', '시행일자': '20251001', '항번호': '①', '조문_index': 2, '공포일자': '20251001', 'source': '법령정보센터', '조문제목': '근로소득세액공제', 'file_line_no': 647, '조문번호': '59', 'level': '항'}, page_content='①근로소득이 있는 거주자에 대해서는 그 근로소득에 대한 종합소득산출세액에서 다음의 금액을 공제한다. <개정 2014.1.1, 2015.5.13> \n \n <img src="http://www.law.go.kr/flDownload.do?flSeq=22185317" alt="img22185317" >\n \n ┌─────────────────┬───────────────────────┐\n \n │근로소득에 대한 종합소득 산출세액 │공제액 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 이하 │산출세액의 100분의 55 │\n \n ├─────────────────┼───────────────────────┤\n \n │130만원 초과 │71만5천원＋(130만원을 초과하는 금액의 100분의 │\n \n │ │30) │\n \n └─────────────────┴───────────────────────┘\n \n </img>')]
# [답변]
# 1. 결론: 연간 소득금액 100만원 이하란, 부양가족이 해당 과세기간 동안 벌어들인 모든 소득의 합계가 1,000,000원 이하임을 의미합니다.
# 2. 근거 법령: [문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960]
# 3. 결론 도출 과정: 해당 문서에서는 부양가족의 소득이 기준 중위소득의 40% 이상인 경우를 규정하고 있으며, 연간 소득금액이 100만원 이하인 경우는 별도로 명시되어 있지 않으나, 일반적으로 부양가족 공제 요건 중 소득 기준이 100만원 이하임을 의미하는 것으로 해석됩니다.
#
# [근거 법령 및 본문]소득세법 50조 ①항: 종합소득이 있는 거주자(자연인만 해당한다)에 대해서는 다음 각 호의 어느 하나에 해당하는 사람의 수에 1명당 연 150만원을 곱하여 계산한 금액을 그 거주자의 해당 과세기간의 종합소득금액에서 공제한다. <개정 2015.12.15, 2024.12.31>
#
# 소득세법 59조 ①항: 근로소득이 있는 거주자에 대해서는 그 근로소득에 대한 종합소득산출세액에서 다음의 금액을 공제한다. <개정 2014.1.1, 2015.5.13>
#
#  <img src="http://www.law.go.kr/flDownload.do?flSeq=22185317" alt="img22185317" >
#
#  ┌─────────────────┬───────────────────────┐
#
#  │근로소득에 대한 종합소득 산출세액 │공제액 │
#
#  ├─────────────────┼───────────────────────┤
#
#  │130만원 이하 │산출세액의 100분의 55 │
#
#  ├─────────────────┼───────────────────────┤
#
#  │130만원 초과 │71만5천원＋(130만원을 초과하는...

# %%
query = "간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?"

pipeline = MultiQueryPipeline(prompt_multi_query, llm, 25, 10, vectorstore)
print(Reference().final_output(query, pipeline))
# Out:
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "question": "간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?"
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n질문을 세법 전문 용어를 사용해 3개의 서로 다른 query로 재작성해.\n각 쿼리는 반드시 줄바꿈으로 구분해.\n\n질문: 간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?"
#   ]
# }
# [llm/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] [2.50s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 간편장부를 미작성 또는 미기장할 경우, 법인세법상 어떤 불이익 또는 가산세 부과 사유가 발생하는지 구체적으로 설명해 주시기 바랍니다.\n\n2. 간편장부를 작성하지 아니하거나 기장하지 않은 경우, 세무조사 시 세무당국이 부과할 수 있는 가산세 또는 불이익 조치에 대해 상세히 설명해 주십시오.\n\n3. 간편장부 미기장 또는 미작성 시, 법인세법상 인정되지 않는 비용 또는 손금불산입 등의 세무상 불이익이 발생하는지 여부와 그 구체적인 내용에 대해 설명해 주시기 바랍니다.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 간편장부를 미작성 또는 미기장할 경우, 법인세법상 어떤 불이익 또는 가산세 부과 사유가 발생하는지 구체적으로 설명해 주시기 바랍니다.\n\n2. 간편장부를 작성하지 아니하거나 기장하지 않은 경우, 세무조사 시 세무당국이 부과할 수 있는 가산세 또는 불이익 조치에 대해 상세히 설명해 주십시오.\n\n3. 간편장부 미기장 또는 미작성 시, 법인세법상 인정되지 않는 비용 또는 손금불산입 등의 세무상 불이익이 발생하는지 여부와 그 구체적인 내용에 대해 설명해 주시기 바랍니다.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 153,
#                 "prompt_tokens": 68,
#                 "total_tokens": 221,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_70fc5e01a5",
#               "id": "chatcmpl-D5uZ4ZgNaOme79ZrmQwagsZYL6TTU",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e30-560e-79f0-b5f2-59af78e6f801-0",
#             "usage_metadata": {
#               "input_tokens": 68,
#               "output_tokens": 153,
#               "total_tokens": 221,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 153,
#       "prompt_tokens": 68,
#       "total_tokens": 221,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_70fc5e01a5",
#     "id": "chatcmpl-D5uZ4ZgNaOme79ZrmQwagsZYL6TTU",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] s] Exiting Parser run with output:
# {
#   "output": [
#     "1. 간편장부를 미작성 또는 미기장할 경우, 법인세법상 어떤 불이익 또는 가산세 부과 사유가 발생하는지 구체적으로 설명해 주시기 바랍니다.",
#     "2. 간편장부를 작성하지 아니하거나 기장하지 않은 경우, 세무조사 시 세무당국이 부과할 수 있는 가산세 또는 불이익 조치에 대해 상세히 설명해 주십시오.",
#     "3. 간편장부 미기장 또는 미작성 시, 법인세법상 인정되지 않는 비용 또는 손금불산입 등의 세무상 불이익이 발생하는지 여부와 그 구체적인 내용에 대해 설명해 주시기 바랍니다."
#   ]
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence] [2.51s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 간편장부를 미작성 또는 미기장할 경우, 법인세법상 어떤 불이익 또는 가산세 부과 사유가 발생하는지 구체적으로 설명해 주시기 바랍니다.",
#     "2. 간편장부를 작성하지 아니하거나 기장하지 않은 경우, 세무조사 시 세무당국이 부과할 수 있는 가산세 또는 불이익 조치에 대해 상세히 설명해 주십시오.",
#     "3. 간편장부 미기장 또는 미작성 시, 법인세법상 인정되지 않는 비용 또는 손금불산입 등의 세무상 불이익이 발생하는지 여부와 그 구체적인 내용에 대해 설명해 주시기 바랍니다."
#   ]
# }
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?",
#   "docs": "[문서 ID: 003956:63_2_①_1._NO_목번호:j3:p1:l898] 1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우...\n[문서 ID: 003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485] 1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우...\n[문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832] ① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다....\n[문서 ID: 003608:111_NO_조문가지번호_④_1._NO_목번호:j26:p1:l2084] 1. 법인세가 부과되지 아니하거나 면제되는 소득...\n[문서 ID: 003956:46_NO_조문가지번호_NO_항번호_6._NO_목번호:j12:p1:l631] 6. 「법인세법」에 의하여 처분된 배당\n \n 　당해 법인의 당해 사업연도의 결산확정일...\n[문서 ID: 001565:20_NO_조문가지번호_①_3._NO_목번호:j5:p1:l259] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 003956:179_NO_조문가지번호_⑧_3._NO_목번호:j34:p1:l2990] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 003608:30_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l506] ① 각 사업연도의 소득에 대하여 법과 다른 법률에 따라 법인세를 면제받거나 감면받은 경우에는 개별 자산에 대한 감가상각비가 법 제23조제1항에 따른 상각범위액이 되도록 감가상각비를 손금에 산입하여야 한다. 다만, 한국채택국제회계기준을 적용하는 법인은 법 제23조제2항에 따라 개별 자산에 대한 감가상각비를 추가로 손금에 산입할 수 있다. <개정 2018.2.13, 2019.2.12>...\n[문서 ID: 001563:76_22_①_NO_호번호_NO_목번호:j2:p1:l1061] ① 각 연결사업연도의 소득에 대한 법인세액을 계산할 때 연결집단을 하나의 내국법인으로 보아 그 연결집단이 이 법 및 「조세특례제한법」에 따른 중소기업 또는 중견기업에 해당하는 경우에는 다음 각 호의 구분에 따라 이 법 및 「조세특례제한법」에 따른 중소기업 또는 중견기업에 관한 규정을 적용한다....\n[문서 ID: 003666:11_NO_조문가지번호_③_NO_호번호_NO_목번호:j8:p2:l98] 다. <개정 2014.2.21, 2019.2.12, 2024.2.29, 2025.2.28, 2025.12.30> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=159791571\" alt=\"img159791571\" >\n \n ┌─────────────────────┬───────────────────────┐\n \n │구분 │첨부서류 │\n \n ├─────────────────────┼───────────────────────┤\n \n │ │ │\n \n │ │ │\n \n │1. 법령에 따라 허가를 받거나 등록 또는 신 │사업허가증 사본, 사업등록증 사본 또는 신고확 │\n \n │고를 하여야 하는 사업의 경우 │인증 사본 │\n \n │ │ │\n \n │ │ │\n \n ├─────────────────────┼───────────────────────┤\n \n │ │ │\n \n │ │ │\n \n │2. 사업장을 임차하거나 전차(轉借)한 경우 │가. 사업장을 임...\n[문서 ID: 001565:17_NO_조문가지번호_①_4._NO_목번호:j7:p1:l196] 4. 「법인세법」에 따라 배당으로 처분된 금액...\n[문서 ID: 003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720] ①법 제113조제1항부터 제5항까지의 규정에 해당하는 법인은 구분하여야 할 사업 또는 재산별로 자산ㆍ부채 및 손익을 법인의 장부상 각각 독립된 계정과목에 의하여 재정경제부령으로 정하는 바에 따라 구분경리하여야 한다. <개정 2008.2.29, 2009.2.4, 2025.12.30>...\n[문서 ID: 003956:26_NO_조문가지번호_⑤_2._NO_목번호:j11:p1:l318] 2. 다음 각 목의 요건을 모두 갖추어 장래의 특정 시점에 금융회사 등이 지급하는 파생상품(「자본시장과 금융투자업에 관한 법률」 제166조의2제1항제1호에 해당하는 경우에 한정한다)으로부터의 이익이 확정되는 경우...\n[문서 ID: 003956:26_3_⑤_2._NO_목번호:j14:p1:l371] 2. 다음 각 목의 요건을 모두 갖추어 장래의 특정 시점에 금융회사 등이 지급하는 파생상품(「자본시장과 금융투자업에 관한 법률」 제166조의2제1항제1호에 해당하는 경우에 한정한다)으로부터의 이익이 확정되는 경우...\n[문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364] ② 제1항에 따라 법인의 대주주가 양도하는 주식등에 대하여 거래명세 등을 기장하지 아니하였거나 누락하였을 때에는 기장을 하지 아니한 소득금액 또는 누락한 소득금액이 양도소득금액에서 차지하는 비율을 산출세액에 곱하여 계산한 금액의 100분의 10에 해당하는 금액(이하 이 조에서 \"기장 불성실가산세\"라 한다)을 산출세액에 더한다. 다만, 산출세액이 없을 때에는 그 거래금액의 1만분의 7에 해당하는 금액을 기장 불성실가산세로 한다....\n[문서 ID: 003666:99_NO_조문가지번호_NO_항번호_1._NO_목번호:j2:p1:l1158] 1. 부가가치세가 면제되는 사업자 중 소득세 또는 법인세의 납세의무가 있는 자(「조세특례제한법」에 따라 소득세 또는 법인세가 면제되는 자를 포함한다)...\n[문서 ID: 003608:27_NO_조문가지번호_①_1._NO_목번호:j3:p1:l458] 1. 상각방법이 서로 다른 법인이 합병(분할합병을 포함한다)한 경우...\n[문서 ID: 001565:160_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j6:p1:l1904] ⑤ 둘 이상의 사업장을 가진 사업자가 이 법 또는 「조세특례제한법」에 따라 사업장별로 감면을 달리 적용받는 경우에는 사업장별 거래 내용이 구분될 수 있도록 장부에 기록하여야 한다. <개정 2010.12.27>...\n[문서 ID: 003956:79_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1048] ②「법인세법」 제24조제2항제1호가목에 따른 기부금에는 개인이 법인 또는 다른 개인에게 자산을 기증하고 수증자가 이를 받은 후 지체없이 다시 국가 또는 지방자치단체에 기증한 금품의 가액을 포함한다. <개정 2010.12.30, 2019.2.12, 2021.2.17>...\n[문서 ID: 001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070] 2. 특별법에 따라 설립된 법인이 그 특별법의 개정이나 폐지로 인하여 「상법」에 따른 회사로 조직변경하는 경우...\n[문서 ID: 003956:41_NO_조문가지번호_⑩_1._NO_목번호:j15:p1:l553] 1. 「법인세법」에 따라 법인의 소득금액을 법인이 신고하거나 세무서장이 결정ㆍ경정할 때 처분되는 배당ㆍ상여 외에 법인의 자산 또는 개인의 사업용으로 제공되어 소득발생의 원천이 되는 자산(이하 \"사업용자산\"이라 한다)을 무상 또는 저가로 이용함으로 인하여 개인이 받는 이익으로서 그 자산의 이용으로 인하여 통상 지급하여야 할 사용료 또는 그 밖에 이용의 대가(통상 지급하여야 할 금액보다 저가로 그 대가를 지급한 금액이 있는 경우에는 이를 공제한 금액)...\n[문서 ID: 003666:95_NO_조문가지번호_④_1._NO_목번호:j12:p1:l1110] 1. 「소득세법」 제156조제1항 각 호 외의 부분 또는 「법인세법」 제98조제1항 각 호 외의 부분에 해당하는 경우...\n[문 ...
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "query": "간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?",
#   "docs": "[문서 ID: 003956:63_2_①_1._NO_목번호:j3:p1:l898] 1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우...\n[문서 ID: 003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485] 1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우...\n[문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832] ① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다....\n[문서 ID: 003608:111_NO_조문가지번호_④_1._NO_목번호:j26:p1:l2084] 1. 법인세가 부과되지 아니하거나 면제되는 소득...\n[문서 ID: 003956:46_NO_조문가지번호_NO_항번호_6._NO_목번호:j12:p1:l631] 6. 「법인세법」에 의하여 처분된 배당\n \n 　당해 법인의 당해 사업연도의 결산확정일...\n[문서 ID: 001565:20_NO_조문가지번호_①_3._NO_목번호:j5:p1:l259] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 003956:179_NO_조문가지번호_⑧_3._NO_목번호:j34:p1:l2990] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 003608:30_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l506] ① 각 사업연도의 소득에 대하여 법과 다른 법률에 따라 법인세를 면제받거나 감면받은 경우에는 개별 자산에 대한 감가상각비가 법 제23조제1항에 따른 상각범위액이 되도록 감가상각비를 손금에 산입하여야 한다. 다만, 한국채택국제회계기준을 적용하는 법인은 법 제23조제2항에 따라 개별 자산에 대한 감가상각비를 추가로 손금에 산입할 수 있다. <개정 2018.2.13, 2019.2.12>...\n[문서 ID: 001563:76_22_①_NO_호번호_NO_목번호:j2:p1:l1061] ① 각 연결사업연도의 소득에 대한 법인세액을 계산할 때 연결집단을 하나의 내국법인으로 보아 그 연결집단이 이 법 및 「조세특례제한법」에 따른 중소기업 또는 중견기업에 해당하는 경우에는 다음 각 호의 구분에 따라 이 법 및 「조세특례제한법」에 따른 중소기업 또는 중견기업에 관한 규정을 적용한다....\n[문서 ID: 003666:11_NO_조문가지번호_③_NO_호번호_NO_목번호:j8:p2:l98] 다. <개정 2014.2.21, 2019.2.12, 2024.2.29, 2025.2.28, 2025.12.30> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=159791571\" alt=\"img159791571\" >\n \n ┌─────────────────────┬───────────────────────┐\n \n │구분 │첨부서류 │\n \n ├─────────────────────┼───────────────────────┤\n \n │ │ │\n \n │ │ │\n \n │1. 법령에 따라 허가를 받거나 등록 또는 신 │사업허가증 사본, 사업등록증 사본 또는 신고확 │\n \n │고를 하여야 하는 사업의 경우 │인증 사본 │\n \n │ │ │\n \n │ │ │\n \n ├─────────────────────┼───────────────────────┤\n \n │ │ │\n \n │ │ │\n \n │2. 사업장을 임차하거나 전차(轉借)한 경우 │가. 사업장을 임...\n[문서 ID: 001565:17_NO_조문가지번호_①_4._NO_목번호:j7:p1:l196] 4. 「법인세법」에 따라 배당으로 처분된 금액...\n[문서 ID: 003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720] ①법 제113조제1항부터 제5항까지의 규정에 해당하는 법인은 구분하여야 할 사업 또는 재산별로 자산ㆍ부채 및 손익을 법인의 장부상 각각 독립된 계정과목에 의하여 재정경제부령으로 정하는 바에 따라 구분경리하여야 한다. <개정 2008.2.29, 2009.2.4, 2025.12.30>...\n[문서 ID: 003956:26_NO_조문가지번호_⑤_2._NO_목번호:j11:p1:l318] 2. 다음 각 목의 요건을 모두 갖추어 장래의 특정 시점에 금융회사 등이 지급하는 파생상품(「자본시장과 금융투자업에 관한 법률」 제166조의2제1항제1호에 해당하는 경우에 한정한다)으로부터의 이익이 확정되는 경우...\n[문서 ID: 003956:26_3_⑤_2._NO_목번호:j14:p1:l371] 2. 다음 각 목의 요건을 모두 갖추어 장래의 특정 시점에 금융회사 등이 지급하는 파생상품(「자본시장과 금융투자업에 관한 법률」 제166조의2제1항제1호에 해당하는 경우에 한정한다)으로부터의 이익이 확정되는 경우...\n[문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364] ② 제1항에 따라 법인의 대주주가 양도하는 주식등에 대하여 거래명세 등을 기장하지 아니하였거나 누락하였을 때에는 기장을 하지 아니한 소득금액 또는 누락한 소득금액이 양도소득금액에서 차지하는 비율을 산출세액에 곱하여 계산한 금액의 100분의 10에 해당하는 금액(이하 이 조에서 \"기장 불성실가산세\"라 한다)을 산출세액에 더한다. 다만, 산출세액이 없을 때에는 그 거래금액의 1만분의 7에 해당하는 금액을 기장 불성실가산세로 한다....\n[문서 ID: 003666:99_NO_조문가지번호_NO_항번호_1._NO_목번호:j2:p1:l1158] 1. 부가가치세가 면제되는 사업자 중 소득세 또는 법인세의 납세의무가 있는 자(「조세특례제한법」에 따라 소득세 또는 법인세가 면제되는 자를 포함한다)...\n[문서 ID: 003608:27_NO_조문가지번호_①_1._NO_목번호:j3:p1:l458] 1. 상각방법이 서로 다른 법인이 합병(분할합병을 포함한다)한 경우...\n[문서 ID: 001565:160_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j6:p1:l1904] ⑤ 둘 이상의 사업장을 가진 사업자가 이 법 또는 「조세특례제한법」에 따라 사업장별로 감면을 달리 적용받는 경우에는 사업장별 거래 내용이 구분될 수 있도록 장부에 기록하여야 한다. <개정 2010.12.27>...\n[문서 ID: 003956:79_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1048] ②「법인세법」 제24조제2항제1호가목에 따른 기부금에는 개인이 법인 또는 다른 개인에게 자산을 기증하고 수증자가 이를 받은 후 지체없이 다시 국가 또는 지방자치단체에 기증한 금품의 가액을 포함한다. <개정 2010.12.30, 2019.2.12, 2021.2.17>...\n[문서 ID: 001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070] 2. 특별법에 따라 설립된 법인이 그 특별법의 개정이나 폐지로 인하여 「상법」에 따른 회사로 조직변경하는 경우...\n[문서 ID: 003956:41_NO_조문가지번호_⑩_1._NO_목번호:j15:p1:l553] 1. 「법인세법」에 따라 법인의 소득금액을 법인이 신고하거나 세무서장이 결정ㆍ경정할 때 처분되는 배당ㆍ상여 외에 법인의 자산 또는 개인의 사업용으로 제공되어 소득발생의 원천이 되는 자산(이하 \"사업용자산\"이라 한다)을 무상 또는 저가로 이용함으로 인하여 개인이 받는 이익으로서 그 자산의 이용으로 인하여 통상 지급하여야 할 사용료 또는 그 밖에 이용의 대가(통상 지급하여야 할 금액보다 저가로 그 대가를 지급한 금액이 있는 경우에는 이를 공제한 금액)...\n[문서 ID: 003666:95_NO_조문가지번호_④_1._NO_목번호:j12:p1:l1110] 1. 「소득세법」 제156조제1항 각 호 외의 부분 또는 「법인세법」 제98조제1항 각 호 외의 부분에 해당하는 경우...\n[문 ...
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문 지식을 가진 reranking 모델이야.\n    아래 질문에 대해 각 문서들이 답변 근거로 얼마나 관련성 있고 적합한지 점수로 평가해.\n    점수 범위: 0 ~ 100\n\n    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수\n    - 미세하게라도 점수에 차등을 둘 것\n    - 문서 간 비교를 하여 상대적인 점수를 계산할 것\n    - 반드시 아래의 JSON 형식으로만 답변할 것\n    - id는 문서ID를 그대로 복사해서 사용\n    \n    [질문]\n    간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?\n\n    [문서들]\n    [문서 ID: 003956:63_2_①_1._NO_목번호:j3:p1:l898] 1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우...\n[문서 ID: 003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485] 1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우...\n[문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832] ① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다....\n[문서 ID: 003608:111_NO_조문가지번호_④_1._NO_목번호:j26:p1:l2084] 1. 법인세가 부과되지 아니하거나 면제되는 소득...\n[문서 ID: 003956:46_NO_조문가지번호_NO_항번호_6._NO_목번호:j12:p1:l631] 6. 「법인세법」에 의하여 처분된 배당\n \n 　당해 법인의 당해 사업연도의 결산확정일...\n[문서 ID: 001565:20_NO_조문가지번호_①_3._NO_목번호:j5:p1:l259] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 003956:179_NO_조문가지번호_⑧_3._NO_목번호:j34:p1:l2990] 3. 「법인세법」에 따라 상여로 처분된 금액...\n[문서 ID: 003608:30_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l506] ① 각 사업연도의 소득에 대하여 법과 다른 법률에 따라 법인세를 면제받거나 감면받은 경우에는 개별 자산에 대한 감가상각비가 법 제23조제1항에 따른 상각범위액이 되도록 감가상각비를 손금에 산입하여야 한다. 다만, 한국채택국제회계기준을 적용하는 법인은 법 제23조제2항에 따라 개별 자산에 대한 감가상각비를 추가로 손금에 산입할 수 있다. <개정 2018.2.13, 2019.2.12>...\n[문서 ID: 001563:76_22_①_NO_호번호_NO_목번호:j2:p1:l1061] ① 각 연결사업연도의 소득에 대한 법인세액을 계산할 때 연결집단을 하나의 내국법인으로 보아 그 연결집단이 이 법 및 「조세특례제한법」에 따른 중소기업 또는 중견기업에 해당하는 경우에는 다음 각 호의 구분에 따라 이 법 및 「조세특례제한법」에 따른 중소기업 또는 중견기업에 관한 규정을 적용한다....\n[문서 ID: 003666:11_NO_조문가지번호_③_NO_호번호_NO_목번호:j8:p2:l98] 다. <개정 2014.2.21, 2019.2.12, 2024.2.29, 2025.2.28, 2025.12.30> \n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=159791571\" alt=\"img159791571\" >\n \n ┌─────────────────────┬───────────────────────┐\n \n │구분 │첨부서류 │\n \n ├─────────────────────┼───────────────────────┤\n \n │ │ │\n \n │ │ │\n \n │1. 법령에 따라 허가를 받거나 등록 또는 신 │사업허가증 사본, 사업등록증 사본 또는 신고확 │\n \n │고를 하여야 하는 사업의 경우 │인증 사본 │\n \n │ │ │\n \n │ │ │\n \n ├─────────────────────┼───────────────────────┤\n \n │ │ │\n \n │ │ │\n \n │2. 사업장을 임차하거나 전차(轉借)한 경우 │가. 사업장을 임...\n[문서 ID: 001565:17_NO_조문가지번호_①_4._NO_목번호:j7:p1:l196] 4. 「법인세법」에 따라 배당으로 처분된 금액...\n[문서 ID: 003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720] ①법 제113조제1항부터 제5항까지의 규정에 해당하는 법인은 구분하여야 할 사업 또는 재산별로 자산ㆍ부채 및 손익을 법인의 장부상 각각 독립된 계정과목에 의하여 재정경제부령으로 정하는 바에 따라 구분경리하여야 한다. <개정 2008.2.29, 2009.2.4, 2025.12.30>...\n[문서 ID: 003956:26_NO_조문가지번호_⑤_2._NO_목번호:j11:p1:l318] 2. 다음 각 목의 요건을 모두 갖추어 장래의 특정 시점에 금융회사 등이 지급하는 파생상품(「자본시장과 금융투자업에 관한 법률」 제166조의2제1항제1호에 해당하는 경우에 한정한다)으로부터의 이익이 확정되는 경우...\n[문서 ID: 003956:26_3_⑤_2._NO_목번호:j14:p1:l371] 2. 다음 각 목의 요건을 모두 갖추어 장래의 특정 시점에 금융회사 등이 지급하는 파생상품(「자본시장과 금융투자업에 관한 법률」 제166조의2제1항제1호에 해당하는 경우에 한정한다)으로부터의 이익이 확정되는 경우...\n[문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364] ② 제1항에 따라 법인의 대주주가 양도하는 주식등에 대하여 거래명세 등을 기장하지 아니하였거나 누락하였을 때에는 기장을 하지 아니한 소득금액 또는 누락한 소득금액이 양도소득금액에서 차지하는 비율을 산출세액에 곱하여 계산한 금액의 100분의 10에 해당하는 금액(이하 이 조에서 \"기장 불성실가산세\"라 한다)을 산출세액에 더한다. 다만, 산출세액이 없을 때에는 그 거래금액의 1만분의 7에 해당하는 금액을 기장 불성실가산세로 한다....\n[문서 ID: 003666:99_NO_조문가지번호_NO_항번호_1._NO_목번호:j2:p1:l1158] 1. 부가가치세가 면제되는 사업자 중 소득세 또는 법인세의 납세의무가 있는 자(「조세특례제한법」에 따라 소득세 또는 법인세가 면제되는 자를 포함한다)...\n[문서 ID: 003608:27_NO_조문가지번호_①_1._NO_목번호:j3:p1:l458] 1. 상각방법이 서로 다른 법인이 합병(분할합병을 포함한다)한 경우...\n[문서 ID: 001565:160_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j6:p1:l1904] ⑤ 둘 이상의 사업장을 가진 사업자가 이 법 또는 「조세특례제한법」에 따라 사업장별로 감면을 달리 적용받는 경우에는 사업장별 거래 내용이 구분될 수 있도록 장부에 기록하여야 한다. <개정 2010.12.27>...\n[문서 ID: 003956:79_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1048] ②「법인세법」 제24조제2항제1호가목에 따른 기부금에는 개인이 법인 또는 다른 개인에게 자산을 기증하고 수증자가 이를 받은 후 지체없이 다시 국가 또는 지방자치단체에 기증한 금품의 가액을 포함한다. <개정 2010.12.30, 2019.2.12, 2021.2.17>...\n[문서 ID: 001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070] 2. 특별법에 따라 설립된 법인이 그 특별법의 개정이나 폐지로 인하여 「상법」에 따른 회사로 조직변경하는 경우...\n[문서 ID: 003956:41_NO_조문가지번호_⑩_1._NO_목번호:j15:p1:l553] 1. 「법인세법」에 따라 법인의 소득금액을 법인이 신고하거나 세무서장이  ...
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [5.46s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"scores\": [\n    {\"id\": \"001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\", \"score\": 95},\n    {\"id\": \"003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485\", \"score\": 80},\n    {\"id\": \"001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\", \"score\": 70},\n    {\"id\": \"003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720\", \"score\": 65},\n    {\"id\": \"001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070\", \"score\": 60},\n    {\"id\": \"003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398\", \"score\": 58},\n    {\"id\": \"003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\", \"score\": 55},\n    {\"id\": \"003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154\", \"score\": 50},\n    {\"id\": \"001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211\", \"score\": 48},\n    {\"id\": \"003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\", \"score\": 45}\n  ]\n}",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"scores\": [\n    {\"id\": \"001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\", \"score\": 95},\n    {\"id\": \"003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485\", \"score\": 80},\n    {\"id\": \"001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\", \"score\": 70},\n    {\"id\": \"003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720\", \"score\": 65},\n    {\"id\": \"001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070\", \"score\": 60},\n    {\"id\": \"003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398\", \"score\": 58},\n    {\"id\": \"003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\", \"score\": 55},\n    {\"id\": \"003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154\", \"score\": 50},\n    {\"id\": \"001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211\", \"score\": 48},\n    {\"id\": \"003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\", \"score\": 45}\n  ]\n}",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 387,
#                 "prompt_tokens": 7952,
#                 "total_tokens": 8339,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_b6501e8a2c",
#               "id": "chatcmpl-D5uZ9Fq91UrWTCSdfvAdIXDunfH3o",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e30-6abc-7f22-8c24-f744112c4037-0",
#             "usage_metadata": {
#               "input_tokens": 7952,
#               "output_tokens": 387,
#               "total_tokens": 8339,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 387,
#       "prompt_tokens": 7952,
#       "total_tokens": 8339,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_b6501e8a2c",
#     "id": "chatcmpl-D5uZ9Fq91UrWTCSdfvAdIXDunfH3o",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "scores": [
#     {
#       "id": "001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832",
#       "score": 95
#     },
#     {
#       "id": "003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485",
#       "score": 80
#     },
#     {
#       "id": "001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364",
#       "score": 70
#     },
#     {
#       "id": "003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720",
#       "score": 65
#     },
#     {
#       "id": "001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070",
#       "score": 60
#     },
#     {
#       "id": "003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398",
#       "score": 58
#     },
#     {
#       "id": "003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031",
#       "score": 55
#     },
#     {
#       "id": "003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154",
#       "score": 50
#     },
#     {
#       "id": "001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211",
#       "score": 48
#     },
#     {
#       "id": "003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031",
#       "score": 45
#     }
#   ]
# }
# [chain/end] [chain:RunnableSequence] [5.46s] Exiting Chain run with output:
# {
#   "scores": [
#     {
#       "id": "001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832",
#       "score": 95
#     },
#     {
#       "id": "003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485",
#       "score": 80
#     },
#     {
#       "id": "001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364",
#       "score": 70
#     },
#     {
#       "id": "003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720",
#       "score": 65
#     },
#     {
#       "id": "001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070",
#       "score": 60
#     },
#     {
#       "id": "003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398",
#       "score": 58
#     },
#     {
#       "id": "003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031",
#       "score": 55
#     },
#     {
#       "id": "003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154",
#       "score": 50
#     },
#     {
#       "id": "001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211",
#       "score": 48
#     },
#     {
#       "id": "003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031",
#       "score": 45
#     }
#   ]
# }
# [문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832
# ① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다.
#
# [문서 ID: 003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485
# 1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우
#
# [문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364
# ② 제1항에 따라 법인의 대주주가 양도하는 주식등에 대하여 거래명세 등을 기장하지 아니하였거나 누락하였을 때에는 기장을 하지 아니한 소득금액 또는 누락한 소득금액이 양도소득금액에서 차지하는 비율을 산출세액에 곱하여 계산한 금액의 100분의 10에 해당하는 금액(이하 이 조에서 "기장 불성실가산세"라 한다)을 산출세액에 더한다. 다만, 산출세액이 없을 때에는 그 거래금액의 1만분의 7에 해당하는 금액을 기장 불성실가산세로 한다.
#
# [문서 ID: 003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720
# ①법 제113조제1항부터 제5항까지의 규정에 해당하는 법인은 구분하여야 할 사업 또는 재산별로 자산ㆍ부채 및 손익을 법인의 장부상 각각 독립된 계정과목에 의하여 재정경제부령으로 정하는 바에 따라 구분경리하여야 한다. <개정 2008.2.29, 2009.2.4, 2025.12.30>
#
# [문서 ID: 001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070
# 2. 특별법에 따라 설립된 법인이 그 특별법의 개정이나 폐지로 인하여 「상법」에 따른 회사로 조직변경하는 경우
#
# [문서 ID: 003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398
# ④ 분할신설법인등이 법 제46조의3제2항에 따라 분할법인등으로부터 승계받은 감면 또는 세액공제를 적용하는 경우에는 제81조제3항을 준용한다. <신설 2010.12.30>
#
# [문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031
# 2. 세무조사가 착수된 것을 알게 된 경우
#
# [문서 ID: 003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154
# 7. 「조세특례제한법」 제74조제1항(제4호부터 제6호까지는 제외한다) 또는 제4항에 따라 법인의 수익사업에서 발생한 소득을 고유목적사업준비금으로 손금에 산입할 수 있는 비영리내국법인
#
# [문서 ID: 001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211
# 3. 해산한 법인(법인으로 보는 단체를 포함한다)의 주주ㆍ사원ㆍ출자자 또는 구성원이 그 법인의 해산으로 인한 잔여재산의 분배로 취득하는 금전이나 그 밖의 재산의 가액이 해당 주식ㆍ출자지분 또는 자본을 취득하기 위하여 사용된 금액을 초과하는 금액. 다만, 내국법인이 조직변경하는 경우로서 다음 각 목의 어느 하나에 해당하는 경우는 제외한다.
#
# [문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031
# 2. 세무조사가 착수된 것을 알게 된 경우
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "context": "[문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\n① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다.\n\n[문서 ID: 003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485\n1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우\n\n[문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\n② 제1항에 따라 법인의 대주주가 양도하는 주식등에 대하여 거래명세 등을 기장하지 아니하였거나 누락하였을 때에는 기장을 하지 아니한 소득금액 또는 누락한 소득금액이 양도소득금액에서 차지하는 비율을 산출세액에 곱하여 계산한 금액의 100분의 10에 해당하는 금액(이하 이 조에서 \"기장 불성실가산세\"라 한다)을 산출세액에 더한다. 다만, 산출세액이 없을 때에는 그 거래금액의 1만분의 7에 해당하는 금액을 기장 불성실가산세로 한다.\n\n[문서 ID: 003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720\n①법 제113조제1항부터 제5항까지의 규정에 해당하는 법인은 구분하여야 할 사업 또는 재산별로 자산ㆍ부채 및 손익을 법인의 장부상 각각 독립된 계정과목에 의하여 재정경제부령으로 정하는 바에 따라 구분경리하여야 한다. <개정 2008.2.29, 2009.2.4, 2025.12.30>\n\n[문서 ID: 001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070\n2. 특별법에 따라 설립된 법인이 그 특별법의 개정이나 폐지로 인하여 「상법」에 따른 회사로 조직변경하는 경우\n\n[문서 ID: 003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398\n④ 분할신설법인등이 법 제46조의3제2항에 따라 분할법인등으로부터 승계받은 감면 또는 세액공제를 적용하는 경우에는 제81조제3항을 준용한다. <신설 2010.12.30>\n\n[문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\n2. 세무조사가 착수된 것을 알게 된 경우\n\n[문서 ID: 003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154\n7. 「조세특례제한법」 제74조제1항(제4호부터 제6호까지는 제외한다) 또는 제4항에 따라 법인의 수익사업에서 발생한 소득을 고유목적사업준비금으로 손금에 산입할 수 있는 비영리내국법인\n\n[문서 ID: 001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211\n3. 해산한 법인(법인으로 보는 단체를 포함한다)의 주주ㆍ사원ㆍ출자자 또는 구성원이 그 법인의 해산으로 인한 잔여재산의 분배로 취득하는 금전이나 그 밖의 재산의 가액이 해당 주식ㆍ출자지분 또는 자본을 취득하기 위하여 사용된 금액을 초과하는 금액. 다만, 내국법인이 조직변경하는 경우로서 다음 각 목의 어느 하나에 해당하는 경우는 제외한다.\n\n[문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\n2. 세무조사가 착수된 것을 알게 된 경우",
#   "question": "간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?",
#   "final_k": 10
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "context": "[문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\n① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다.\n\n[문서 ID: 003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485\n1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우\n\n[문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\n② 제1항에 따라 법인의 대주주가 양도하는 주식등에 대하여 거래명세 등을 기장하지 아니하였거나 누락하였을 때에는 기장을 하지 아니한 소득금액 또는 누락한 소득금액이 양도소득금액에서 차지하는 비율을 산출세액에 곱하여 계산한 금액의 100분의 10에 해당하는 금액(이하 이 조에서 \"기장 불성실가산세\"라 한다)을 산출세액에 더한다. 다만, 산출세액이 없을 때에는 그 거래금액의 1만분의 7에 해당하는 금액을 기장 불성실가산세로 한다.\n\n[문서 ID: 003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720\n①법 제113조제1항부터 제5항까지의 규정에 해당하는 법인은 구분하여야 할 사업 또는 재산별로 자산ㆍ부채 및 손익을 법인의 장부상 각각 독립된 계정과목에 의하여 재정경제부령으로 정하는 바에 따라 구분경리하여야 한다. <개정 2008.2.29, 2009.2.4, 2025.12.30>\n\n[문서 ID: 001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070\n2. 특별법에 따라 설립된 법인이 그 특별법의 개정이나 폐지로 인하여 「상법」에 따른 회사로 조직변경하는 경우\n\n[문서 ID: 003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398\n④ 분할신설법인등이 법 제46조의3제2항에 따라 분할법인등으로부터 승계받은 감면 또는 세액공제를 적용하는 경우에는 제81조제3항을 준용한다. <신설 2010.12.30>\n\n[문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\n2. 세무조사가 착수된 것을 알게 된 경우\n\n[문서 ID: 003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154\n7. 「조세특례제한법」 제74조제1항(제4호부터 제6호까지는 제외한다) 또는 제4항에 따라 법인의 수익사업에서 발생한 소득을 고유목적사업준비금으로 손금에 산입할 수 있는 비영리내국법인\n\n[문서 ID: 001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211\n3. 해산한 법인(법인으로 보는 단체를 포함한다)의 주주ㆍ사원ㆍ출자자 또는 구성원이 그 법인의 해산으로 인한 잔여재산의 분배로 취득하는 금전이나 그 밖의 재산의 가액이 해당 주식ㆍ출자지분 또는 자본을 취득하기 위하여 사용된 금액을 초과하는 금액. 다만, 내국법인이 조직변경하는 경우로서 다음 각 목의 어느 하나에 해당하는 경우는 제외한다.\n\n[문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\n2. 세무조사가 착수된 것을 알게 된 경우",
#   "question": "간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?",
#   "final_k": 10
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 회계, 세법 전문가야. 아래의 context를 근거로 다음 규칙에 따라 질문에 답변해.\n\n    [규칙]\n    1. 결론: 질문에 대한 답은 한 문장으로 먼저 제시 (ex. \"납부할 세액은 1,000,000원입니다.\" \"해당 항목은 익금산입 대상입니다.\")\n    2. 출처는 context에등장하는 [문서 ID: ...]의 값만 그대로 복사해서 사용. (요약, 생략 불가)\n\n    [문맥]\n    [문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\n① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다.\n\n[문서 ID: 003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485\n1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우\n\n[문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\n② 제1항에 따라 법인의 대주주가 양도하는 주식등에 대하여 거래명세 등을 기장하지 아니하였거나 누락하였을 때에는 기장을 하지 아니한 소득금액 또는 누락한 소득금액이 양도소득금액에서 차지하는 비율을 산출세액에 곱하여 계산한 금액의 100분의 10에 해당하는 금액(이하 이 조에서 \"기장 불성실가산세\"라 한다)을 산출세액에 더한다. 다만, 산출세액이 없을 때에는 그 거래금액의 1만분의 7에 해당하는 금액을 기장 불성실가산세로 한다.\n\n[문서 ID: 003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720\n①법 제113조제1항부터 제5항까지의 규정에 해당하는 법인은 구분하여야 할 사업 또는 재산별로 자산ㆍ부채 및 손익을 법인의 장부상 각각 독립된 계정과목에 의하여 재정경제부령으로 정하는 바에 따라 구분경리하여야 한다. <개정 2008.2.29, 2009.2.4, 2025.12.30>\n\n[문서 ID: 001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070\n2. 특별법에 따라 설립된 법인이 그 특별법의 개정이나 폐지로 인하여 「상법」에 따른 회사로 조직변경하는 경우\n\n[문서 ID: 003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398\n④ 분할신설법인등이 법 제46조의3제2항에 따라 분할법인등으로부터 승계받은 감면 또는 세액공제를 적용하는 경우에는 제81조제3항을 준용한다. <신설 2010.12.30>\n\n[문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\n2. 세무조사가 착수된 것을 알게 된 경우\n\n[문서 ID: 003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154\n7. 「조세특례제한법」 제74조제1항(제4호부터 제6호까지는 제외한다) 또는 제4항에 따라 법인의 수익사업에서 발생한 소득을 고유목적사업준비금으로 손금에 산입할 수 있는 비영리내국법인\n\n[문서 ID: 001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211\n3. 해산한 법인(법인으로 보는 단체를 포함한다)의 주주ㆍ사원ㆍ출자자 또는 구성원이 그 법인의 해산으로 인한 잔여재산의 분배로 취득하는 금전이나 그 밖의 재산의 가액이 해당 주식ㆍ출자지분 또는 자본을 취득하기 위하여 사용된 금액을 초과하는 금액. 다만, 내국법인이 조직변경하는 경우로서 다음 각 목의 어느 하나에 해당하는 경우는 제외한다.\n\n[문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\n2. 세무조사가 착수된 것을 알게 된 경우\n\n    [질문]\n    간편장부를 기장하지 아니하였을 때 어떤 불이익이 있나요?\n\n    <출력 형식>\n    [답변]\n    1. 결론: ...\n    2. 결론 도출 과정: ...\n\n    [출처]\n    [\"문서 ID1\", \"문서 ID2\", ...]\n    - 답변 생성에 사용한 문서의 ID만 작성\n    - 1 ~ 10개의 문서 ID 작성"
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [3.11s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "[답변]\n1. 결론: 간편장부를 기장하지 않으면 내국법인은 장부 미비치에 따른 가산세 또는 기장 불성실가산세 등의 불이익이 발생할 수 있습니다.\n2. 결론 도출 과정: 내국법인이 장부의 비치ㆍ기장 의무를 이행하지 않거나 거래명세 등을 기장하지 않은 경우 가산세 또는 기장 불성실가산세 부과 대상이 되며, 이는 법인세 납부 시 추가 부담으로 작용할 수 있기 때문입니다.\n[출처]\n[\"문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\", \"문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\", \"문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\"]",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "[답변]\n1. 결론: 간편장부를 기장하지 않으면 내국법인은 장부 미비치에 따른 가산세 또는 기장 불성실가산세 등의 불이익이 발생할 수 있습니다.\n2. 결론 도출 과정: 내국법인이 장부의 비치ㆍ기장 의무를 이행하지 않거나 거래명세 등을 기장하지 않은 경우 가산세 또는 기장 불성실가산세 부과 대상이 되며, 이는 법인세 납부 시 추가 부담으로 작용할 수 있기 때문입니다.\n[출처]\n[\"문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\", \"문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\", \"문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\"]",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 227,
#                 "prompt_tokens": 1285,
#                 "total_tokens": 1512,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_de604bd877",
#               "id": "chatcmpl-D5uZEQ6ySqZAQE4zwHQuShRkQK8L4",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e30-8010-7050-8215-7569606b955e-0",
#             "usage_metadata": {
#               "input_tokens": 1285,
#               "output_tokens": 227,
#               "total_tokens": 1512,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 227,
#       "prompt_tokens": 1285,
#       "total_tokens": 1512,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_de604bd877",
#     "id": "chatcmpl-D5uZEQ6ySqZAQE4zwHQuShRkQK8L4",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "[답변]\n1. 결론: 간편장부를 기장하지 않으면 내국법인은 장부 미비치에 따른 가산세 또는 기장 불성실가산세 등의 불이익이 발생할 수 있습니다.\n2. 결론 도출 과정: 내국법인이 장부의 비치ㆍ기장 의무를 이행하지 않거나 거래명세 등을 기장하지 않은 경우 가산세 또는 기장 불성실가산세 부과 대상이 되며, 이는 법인세 납부 시 추가 부담으로 작용할 수 있기 때문입니다.\n[출처]\n[\"문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\", \"문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\", \"문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\"]"
# }
# [chain/end] [chain:RunnableSequence] [3.11s] Exiting Chain run with output:
# {
#   "output": "[답변]\n1. 결론: 간편장부를 기장하지 않으면 내국법인은 장부 미비치에 따른 가산세 또는 기장 불성실가산세 등의 불이익이 발생할 수 있습니다.\n2. 결론 도출 과정: 내국법인이 장부의 비치ㆍ기장 의무를 이행하지 않거나 거래명세 등을 기장하지 않은 경우 가산세 또는 기장 불성실가산세 부과 대상이 되며, 이는 법인세 납부 시 추가 부담으로 작용할 수 있기 때문입니다.\n[출처]\n[\"문서 ID: 001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832\", \"문서 ID: 001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364\", \"문서 ID: 003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031\"]"
# }
# ids:  []
# docs_id ['001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832', '003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485', '001565:115_NO_조문가지번호_②_NO_호번호_NO_목번호:j3:p1:l1364', '003608:156_NO_조문가지번호_①_NO_호번호_NO_목번호:j2:p1:l2720', '001563:78_NO_조문가지번호_NO_항번호_2._NO_목번호:j3:p1:l1070', '003608:83_NO_조문가지번호_④_NO_호번호_NO_목번호:j5:p1:l1398', '003608:106_NO_조문가지번호_④_2._NO_목번호:j24:p1:l2031', '003608:10_NO_조문가지번호_①_7._NO_목번호:j14:p1:l154', '001565:17_NO_조문가지번호_②_3._NO_목번호:j22:p1:l211']
# used_docs [Document(id='001563:75_3_①_NO_호번호_NO_목번호:j2:p1:l832', metadata={'조문_index': 2, 'piece_index': 1, '항번호': '①', '조문제목': '장부의 기록ㆍ보관 불성실 가산세', 'level': '항', '조문번호': '75', 'law_id': '001563', 'file_line_no': 832, 'piece_count': 1, '시행일자': '20251001', '공포일자': '20251001', '조문가지번호': '3', 'law_name': '법인세법', 'source': '법령정보센터'}, page_content='① 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다.'), Document(id='003608:29_NO_조문가지번호_①_1._NO_목번호:j3:p1:l485', metadata={'조문제목': '내용연수의 특례 및 변경', 'law_id': '003608', '공포일자': '20251230', '시행일자': '20260102', '조문번호': '29', 'piece_index': 1, 'piece_count': 1, 'source': '법령정보센터', 'law_name': '법인세법 시행령', '항번호': '①', 'level': '호', '조문_index': 3, 'file_line_no': 485, '호번호': '1.'}, page_content='1. 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우')]
# [답변]
# 1. 결론: 간편장부를 기장하지 않으면 내국법인은 장부 미비치에 따른 가산세 또는 기장 불성실가산세 등의 불이익이 발생할 수 있습니다.
# 2. 결론 도출 과정: 내국법인이 장부의 비치ㆍ기장 의무를 이행하지 않거나 거래명세 등을 기장하지 않은 경우 가산세 또는 기장 불성실가산세 부과 대상이 되며, 이는 법인세 납부 시 추가 부담으로 작용할 수 있기 때문입니다.
#
# [근거 법령 및 본문]법인세법 75조 ①항: 내국법인(비영리내국법인과 이 법 또는 다른 법률에 따라 법인세가 비과세되거나 전액 면제되는 소득만 있는 법인은 제외한다)이 제112조에 따른 장부의 비치ㆍ기장 의무를 이행하지 아니한 경우에는 다음 각 호의 금액 중 큰 금액을 가산세로 해당 사업연도의 법인세액에 더하여 납부하여야 한다.
#
# 법인세법 시행령 29조 ①항 1호: 사업장의 특성으로 자산의 부식ㆍ마모 및 훼손의 정도가 현저한 경우

# %%
query= "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"

pipeline = MultiQueryPipeline(prompt_multi_query, llm, 25, 10, vectorstore)
print(Reference().final_output(query, pipeline))
# Out:
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n질문을 세법 전문 용어를 사용해 3개의 서로 다른 query로 재작성해.\n각 쿼리는 반드시 줄바꿈으로 구분해.\n\n질문: 미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?"
#   ]
# }
# [llm/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > llm:ChatOpenAI] [1.75s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 미혼자가 본인 명의로 임대한 부동산에서 발생하는 임대소득이 소득세법상 과세 대상인지 여부를 판단하는 기준은 무엇인가?\n\n2. 부모님 소유의 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 종합소득세 과세 여부는 어떻게 되는가?\n\n3. 임대소득세법상 과세 대상에 해당하는 임대소득의 범위와, 미혼인 임대사업자가 본인 소유 임대주택을 임대하는 경우 적용되는 세법 규정은 무엇인가?",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 미혼자가 본인 명의로 임대한 부동산에서 발생하는 임대소득이 소득세법상 과세 대상인지 여부를 판단하는 기준은 무엇인가?\n\n2. 부모님 소유의 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 종합소득세 과세 여부는 어떻게 되는가?\n\n3. 임대소득세법상 과세 대상에 해당하는 임대소득의 범위와, 미혼인 임대사업자가 본인 소유 임대주택을 임대하는 경우 적용되는 세법 규정은 무엇인가?",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 146,
#                 "prompt_tokens": 87,
#                 "total_tokens": 233,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_70fc5e01a5",
#               "id": "chatcmpl-D5ub9kRlYiiOdAO2OPsqZAXgbcK9l",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e32-51cc-7061-bed8-00f82491ebfe-0",
#             "usage_metadata": {
#               "input_tokens": 87,
#               "output_tokens": 146,
#               "total_tokens": 233,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 146,
#       "prompt_tokens": 87,
#       "total_tokens": 233,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_70fc5e01a5",
#     "id": "chatcmpl-D5ub9kRlYiiOdAO2OPsqZAXgbcK9l",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence > parser:LineListOutputParser] s] Exiting Parser run with output:
# {
#   "output": [
#     "1. 미혼자가 본인 명의로 임대한 부동산에서 발생하는 임대소득이 소득세법상 과세 대상인지 여부를 판단하는 기준은 무엇인가?",
#     "2. 부모님 소유의 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 종합소득세 과세 여부는 어떻게 되는가?",
#     "3. 임대소득세법상 과세 대상에 해당하는 임대소득의 범위와, 미혼인 임대사업자가 본인 소유 임대주택을 임대하는 경우 적용되는 세법 규정은 무엇인가?"
#   ]
# }
# [chain/end] [retriever:MultiQueryRetriever > chain:RunnableSequence] [1.75s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 미혼자가 본인 명의로 임대한 부동산에서 발생하는 임대소득이 소득세법상 과세 대상인지 여부를 판단하는 기준은 무엇인가?",
#     "2. 부모님 소유의 주택에 거주하면서 본인 명의 임대주택에서 임대소득이 발생하는 경우, 해당 임대소득에 대한 종합소득세 과세 여부는 어떻게 되는가?",
#     "3. 임대소득세법상 과세 대상에 해당하는 임대소득의 범위와, 미혼인 임대사업자가 본인 소유 임대주택을 임대하는 경우 적용되는 세법 규정은 무엇인가?"
#   ]
# }
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?",
#   "docs": "[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620] 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>...\n[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93] 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다....\n[문서 ID: 001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120] 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득...\n[문서 ID: 001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381] 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득...\n[문서 ID: 001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32] ⑤ 공동으로 소유한 자산에 대한 양도소득금액을 계산하는 경우에는 해당 자산을 공동으로 소유하는 각 거주자가 납세의무를 진다. <신설 2017.12.19, 2020.12.29>...\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673] 5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득...\n[문서 ID: 007289:74_NO_조문가지번호_②_4._NO_목번호:j10:p1:l346] 4. 부동산을 취득하는 경우: 별지 제27호서식의 건물 등 감가상각자산 취득명세서...\n[문서 ID: 001565:19_NO_조문가지번호_①_12._NO_목번호:j14:p1:l243] 12. 부동산업에서 발생하는 소득. 다만, 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」 제4조에 따른 공익사업과 관련하여 지역권ㆍ지상권(지하 또는 공중에 설정된 권리를 포함한다)을 설정하거나 대여함으로써 발생하는 소득은 제외한다....\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567] ⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입...\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985] ① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다....\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991] 다. 부동산을 임대하는 법인의 수입이자가 사업외수익에 포함된 경우에는 부동산임대에 의한 전세금 또는 임대보증금에 대한 수입이자 상당액...\n[문서 ID: 003956:167_3_⑤_2._가.:j40:p1:l2526] 가. 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」에 따른 수용 등 재정경제부령으로 정하는 부득이한 사유로 해당 의무임대기간등의 요건을 충족하지 못하게 되거나 임대의무호수를 임대하지 아니하게 된 때에는 해당 임대주택등을 계속 임대ㆍ사용하거나 무상으로 사용하는 것으로 본다....\n[문서 ID: 003956:155_2_④_NO_호번호_NO_목번호:j8:p1:l2107] ④제2항의 규정을 적용받으려는 자는 재정경제부령이 정하는 장기저당담보주택에 대한 특례적용신고서를 「소득세법」 제105조 또는 동법 제110조에 따른 양도소득세 과세표준신고기한 내에 장기저당담보주택에 관한 제1항의 대출 계약서와 함께 제출하여야 한다. 이 경우 납세지 관할세무서장은 「전자정부법」 제36조제1항에 따른 행정정보의 공동이용을 통하여 다음 각 호의 서류를 확인하여야 한다. <개정 2006.6.12, 2008.2.29, 2008.12.31, 2010.5.4, 2025.12.30>...\n[문서 ID: 007229:26_NO_조문가지번호_⑤_13._나.:j32:p1:l263] 나. 부동산의 소유권에 관한 소송이 계속중인 부동산...\n[문서 ID: 007229:26_NO_조문가지번호_⑥_NO_호번호_NO_목번호:j59:p1:l290] ⑥영 제49조제1항제1호의 규정을 적용함에 있어서 부동산의 취득시기는 「소득세법 시행령」 제162조의 규정을 준용하되, 동조제1항제3호의 규정에 의한 장기할부조건에 의한 취득의 경우에는 당해 부동산을 사용 또는 수익할 수 있는 날로 한다. <개정 2005.2.28>...\n[문서 ID: 001563:93_NO_조문가지번호_NO_항번호_3._NO_목번호:j11:p1:l1148] 3. 국내원천 부동산소득: 국내에 있는 부동산 또는 부동산상의 권리와 국내에서 취득한 광업권, 조광권(租鑛權), 흙ㆍ모래ㆍ돌의 채취에 관한 권리 또는 지하수의 개발ㆍ이용권의 양도ㆍ임대 또는 그 밖의 운영으로 인하여 발생하는 소득. 다만, 제7호에 따른 양도소득은 제외한다....\n[문서 ID: 003956:167_3_①_3._NO_목번호:j14:p1:l2500] 3. 「조세특례제한법」 제97조ㆍ제97조의2 및 제98조에 따라 양도소득세가 감면되는 임대주택으로서 5년 이상 임대한 국민주택(이하 이 조에서 \"감면대상장기임대주택\"이라 한다)...\n[문서 ID: 007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111] 다. 법 제70조제2항에 따른 분리과세 주택임대소득 및 법 제127조제1항제6호나목의 소득만 있는 경 ...
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "query": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?",
#   "docs": "[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620] 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>...\n[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93] 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다....\n[문서 ID: 001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120] 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득...\n[문서 ID: 001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381] 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득...\n[문서 ID: 001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32] ⑤ 공동으로 소유한 자산에 대한 양도소득금액을 계산하는 경우에는 해당 자산을 공동으로 소유하는 각 거주자가 납세의무를 진다. <신설 2017.12.19, 2020.12.29>...\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673] 5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득...\n[문서 ID: 007289:74_NO_조문가지번호_②_4._NO_목번호:j10:p1:l346] 4. 부동산을 취득하는 경우: 별지 제27호서식의 건물 등 감가상각자산 취득명세서...\n[문서 ID: 001565:19_NO_조문가지번호_①_12._NO_목번호:j14:p1:l243] 12. 부동산업에서 발생하는 소득. 다만, 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」 제4조에 따른 공익사업과 관련하여 지역권ㆍ지상권(지하 또는 공중에 설정된 권리를 포함한다)을 설정하거나 대여함으로써 발생하는 소득은 제외한다....\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567] ⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입...\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985] ① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다....\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991] 다. 부동산을 임대하는 법인의 수입이자가 사업외수익에 포함된 경우에는 부동산임대에 의한 전세금 또는 임대보증금에 대한 수입이자 상당액...\n[문서 ID: 003956:167_3_⑤_2._가.:j40:p1:l2526] 가. 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」에 따른 수용 등 재정경제부령으로 정하는 부득이한 사유로 해당 의무임대기간등의 요건을 충족하지 못하게 되거나 임대의무호수를 임대하지 아니하게 된 때에는 해당 임대주택등을 계속 임대ㆍ사용하거나 무상으로 사용하는 것으로 본다....\n[문서 ID: 003956:155_2_④_NO_호번호_NO_목번호:j8:p1:l2107] ④제2항의 규정을 적용받으려는 자는 재정경제부령이 정하는 장기저당담보주택에 대한 특례적용신고서를 「소득세법」 제105조 또는 동법 제110조에 따른 양도소득세 과세표준신고기한 내에 장기저당담보주택에 관한 제1항의 대출 계약서와 함께 제출하여야 한다. 이 경우 납세지 관할세무서장은 「전자정부법」 제36조제1항에 따른 행정정보의 공동이용을 통하여 다음 각 호의 서류를 확인하여야 한다. <개정 2006.6.12, 2008.2.29, 2008.12.31, 2010.5.4, 2025.12.30>...\n[문서 ID: 007229:26_NO_조문가지번호_⑤_13._나.:j32:p1:l263] 나. 부동산의 소유권에 관한 소송이 계속중인 부동산...\n[문서 ID: 007229:26_NO_조문가지번호_⑥_NO_호번호_NO_목번호:j59:p1:l290] ⑥영 제49조제1항제1호의 규정을 적용함에 있어서 부동산의 취득시기는 「소득세법 시행령」 제162조의 규정을 준용하되, 동조제1항제3호의 규정에 의한 장기할부조건에 의한 취득의 경우에는 당해 부동산을 사용 또는 수익할 수 있는 날로 한다. <개정 2005.2.28>...\n[문서 ID: 001563:93_NO_조문가지번호_NO_항번호_3._NO_목번호:j11:p1:l1148] 3. 국내원천 부동산소득: 국내에 있는 부동산 또는 부동산상의 권리와 국내에서 취득한 광업권, 조광권(租鑛權), 흙ㆍ모래ㆍ돌의 채취에 관한 권리 또는 지하수의 개발ㆍ이용권의 양도ㆍ임대 또는 그 밖의 운영으로 인하여 발생하는 소득. 다만, 제7호에 따른 양도소득은 제외한다....\n[문서 ID: 003956:167_3_①_3._NO_목번호:j14:p1:l2500] 3. 「조세특례제한법」 제97조ㆍ제97조의2 및 제98조에 따라 양도소득세가 감면되는 임대주택으로서 5년 이상 임대한 국민주택(이하 이 조에서 \"감면대상장기임대주택\"이라 한다)...\n[문서 ID: 007507:101_NO_조문가지번호_NO_항번호_11._다.:j18:p1:l1111] 다. 법 제70조제2항에 따른 분리과세 주택임대소득 및 법 제127조제1항제6호나목의 소득만 있는 경 ...
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 세법 전문 지식을 가진 reranking 모델이야.\n    아래 질문에 대해 각 문서들이 답변 근거로 얼마나 관련성 있고 적합한지 점수로 평가해.\n    점수 범위: 0 ~ 100\n\n    - 질문과 직접 관련되고 법적 근거로 적합할수록 높은 점수\n    - 미세하게라도 점수에 차등을 둘 것\n    - 문서 간 비교를 하여 상대적인 점수를 계산할 것\n    - 반드시 아래의 JSON 형식으로만 답변할 것\n    - id는 문서ID를 그대로 복사해서 사용\n    \n    [질문]\n    미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?\n\n    [문서들]\n    [문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620] 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>...\n[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93] 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다....\n[문서 ID: 001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120] 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득...\n[문서 ID: 001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381] 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득...\n[문서 ID: 001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32] ⑤ 공동으로 소유한 자산에 대한 양도소득금액을 계산하는 경우에는 해당 자산을 공동으로 소유하는 각 거주자가 납세의무를 진다. <신설 2017.12.19, 2020.12.29>...\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673] 5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득...\n[문서 ID: 007289:74_NO_조문가지번호_②_4._NO_목번호:j10:p1:l346] 4. 부동산을 취득하는 경우: 별지 제27호서식의 건물 등 감가상각자산 취득명세서...\n[문서 ID: 001565:19_NO_조문가지번호_①_12._NO_목번호:j14:p1:l243] 12. 부동산업에서 발생하는 소득. 다만, 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」 제4조에 따른 공익사업과 관련하여 지역권ㆍ지상권(지하 또는 공중에 설정된 권리를 포함한다)을 설정하거나 대여함으로써 발생하는 소득은 제외한다....\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567] ⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입...\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985] ① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다....\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960] 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다....\n[문서 ID: 003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991] 다. 부동산을 임대하는 법인의 수입이자가 사업외수익에 포함된 경우에는 부동산임대에 의한 전세금 또는 임대보증금에 대한 수입이자 상당액...\n[문서 ID: 003956:167_3_⑤_2._가.:j40:p1:l2526] 가. 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」에 따른 수용 등 재정경제부령으로 정하는 부득이한 사유로 해당 의무임대기간등의 요건을 충족하지 못하게 되거나 임대의무호수를 임대하지 아니하게 된 때에는 해당 임대주택등을 계속 임대ㆍ사용하거나 무상으로 사용하는 것으로 본다....\n[문서 ID: 003956:155_2_④_NO_호번호_NO_목번호:j8:p1:l2107] ④제2항의 규정을 적용받으려는 자는 재정경제부령이 정하는 장기저당담보주택에 대한 특례적용신고서를 「소득세법」 제105조 또는 동법 제110조에 따른 양도소득세 과세표준신고기한 내에 장기저당담보주택에 관한 제1항의 대출 계약서와 함께 제출하여야 한다. 이 경우 납세지 관할세무서장은 「전자정부법」 제36조제1항에 따른 행정정보의 공동이용을 통하여 다음 각 호의 서류를 확인하여야 한다. <개정 2006.6.12, 2008.2.29, 2008.12.31, 2010.5.4, 2025.12.30>...\n[문서 ID: 007229:26_NO_조문가지번호_⑤_13._나.:j32:p1:l263] 나. 부동산의 소유권에 관한 소송이 계속중인 부동산...\n[문서 ID: 007229:26_NO_조문가지번호_⑥_NO_호번호_NO_목번호:j59:p1:l290] ⑥영 제49조제1항제1호의 규정을 적용함에 있어서 부동산의 취득시기는 「소득세법 시행령」 제162조의 규정을 준용하되, 동조제1항제3호의 규정에 의한 장기할부조건에 의한 취득의 경우에는 당해 부동산을 사용 또는 수익할 수 있는 날로 한다. <개정 2005.2.28>...\n[문서 ID: 001563:93_NO_조문가지번호_NO_항번호_3._NO_목번호:j11:p1:l1148] 3. 국내원천 부동산소득: 국내에 있는 부동산 또는 부동산상의 권리와 국내에서 취득한 광업권 ...
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [7.85s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"scores\": [\n    {\"id\": \"003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\", \"score\": 25},\n    {\"id\": \"001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\", \"score\": 80},\n    {\"id\": \"001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120\", \"score\": 20},\n    {\"id\": \"001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381\", \"score\": 15},\n    {\"id\": \"001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32\", \"score\": 10},\n    {\"id\": \"003608:92_2_④_5._NO_목번호:j72:p1:l1673\", \"score\": 30},\n    {\"id\": \"007289:74_NO_조문가지번호_②_4._NO_목번호:j10:p1:l346\", \"score\": 7},\n    {\"id\": \"001565:19_NO_조문가지번호_①_12._NO_목번호:j14:p1:l243\", \"score\": 12},\n    {\"id\": \"001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567\", \"score\": 35},\n    {\"id\": \"001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985\", \"score\": 50},\n    {\"id\": \"003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\", \"score\": 18},\n    {\"id\": \"003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991\", \"score\": 22},\n    {\"id\": \"003956:167_3_⑤_2._가.:j40:p1:l2526\", \"score\": 17},\n    {\"id\": \"003956:155_2_④_NO_호번호_NO_목번호:j8:p1:l2107\", \"",
#         "generation_info": {
#           "finish_reason": "length",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"scores\": [\n    {\"id\": \"003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\", \"score\": 25},\n    {\"id\": \"001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\", \"score\": 80},\n    {\"id\": \"001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120\", \"score\": 20},\n    {\"id\": \"001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381\", \"score\": 15},\n    {\"id\": \"001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32\", \"score\": 10},\n    {\"id\": \"003608:92_2_④_5._NO_목번호:j72:p1:l1673\", \"score\": 30},\n    {\"id\": \"007289:74_NO_조문가지번호_②_4._NO_목번호:j10:p1:l346\", \"score\": 7},\n    {\"id\": \"001565:19_NO_조문가지번호_①_12._NO_목번호:j14:p1:l243\", \"score\": 12},\n    {\"id\": \"001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567\", \"score\": 35},\n    {\"id\": \"001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985\", \"score\": 50},\n    {\"id\": \"003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\", \"score\": 18},\n    {\"id\": \"003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991\", \"score\": 22},\n    {\"id\": \"003956:167_3_⑤_2._가.:j40:p1:l2526\", \"score\": 17},\n    {\"id\": \"003956:155_2_④_NO_호번호_NO_목번호:j8:p1:l2107\", \"",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 500,
#                 "prompt_tokens": 13022,
#                 "total_tokens": 13522,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_b6501e8a2c",
#               "id": "chatcmpl-D5ubDSG3TsgHaD2HjdYHBo8rign0u",
#               "service_tier": "default",
#               "finish_reason": "length",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e32-5f25-7310-820e-f4592e498be1-0",
#             "usage_metadata": {
#               "input_tokens": 13022,
#               "output_tokens": 500,
#               "total_tokens": 13522,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 500,
#       "prompt_tokens": 13022,
#       "total_tokens": 13522,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_b6501e8a2c",
#     "id": "chatcmpl-D5ubDSG3TsgHaD2HjdYHBo8rign0u",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:JsonOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:JsonOutputParser] s] Exiting Parser run with output:
# {
#   "scores": [
#     {
#       "id": "003956:122_2_⑦_2._NO_목번호:j23:p1:l1620",
#       "score": 25
#     },
#     {
#       "id": "001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93",
#       "score": 80
#     },
#     {
#       "id": "001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120",
#       "score": 20
#     },
#     {
#       "id": "001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381",
#       "score": 15
#     },
#     {
#       "id": "001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32",
#       "score": 10
#     },
#     {
#       "id": "003608:92_2_④_5._NO_목번호:j72:p1:l1673",
#       "score": 30
#     },
#     {
#       "id": "007289:74_NO_조문가지번호_②_4._NO_목번호:j10:p1:l346",
#       "score": 7
#     },
#     {
#       "id": "001565:19_NO_조문가지번호_①_12._NO_목번호:j14:p1:l243",
#       "score": 12
#     },
#     {
#       "id": "001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567",
#       "score": 35
#     },
#     {
#       "id": "001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985",
#       "score": 50
#     },
#     {
#       "id": "003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960",
#       "score": 18
#     },
#     {
#       "id": "003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991",
#       "score": 22
#     },
#     {
#       "id": "003956:167_3_⑤_2._가.:j40:p1:l2526",
#       "score": 17
#     },
#     {
#       "id": "003956:155_2_④_NO_호번호_NO_목번호:j8:p1:l2107"
#     }
#   ]
# }
# [chain/end] [chain:RunnableSequence] [7.86s] Exiting Chain run with output:
# {
#   "scores": [
#     {
#       "id": "003956:122_2_⑦_2._NO_목번호:j23:p1:l1620",
#       "score": 25
#     },
#     {
#       "id": "001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93",
#       "score": 80
#     },
#     {
#       "id": "001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120",
#       "score": 20
#     },
#     {
#       "id": "001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381",
#       "score": 15
#     },
#     {
#       "id": "001565:2_2_⑤_NO_호번호_NO_목번호:j6:p1:l32",
#       "score": 10
#     },
#     {
#       "id": "003608:92_2_④_5._NO_목번호:j72:p1:l1673",
#       "score": 30
#     },
#     {
#       "id": "007289:74_NO_조문가지번호_②_4._NO_목번호:j10:p1:l346",
#       "score": 7
#     },
#     {
#       "id": "001565:19_NO_조문가지번호_①_12._NO_목번호:j14:p1:l243",
#       "score": 12
#     },
#     {
#       "id": "001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567",
#       "score": 35
#     },
#     {
#       "id": "001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985",
#       "score": 50
#     },
#     {
#       "id": "003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960",
#       "score": 18
#     },
#     {
#       "id": "003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991",
#       "score": 22
#     },
#     {
#       "id": "003956:167_3_⑤_2._가.:j40:p1:l2526",
#       "score": 17
#     },
#     {
#       "id": "003956:155_2_④_NO_호번호_NO_목번호:j8:p1:l2107"
#     }
#   ]
# }
# [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93
# 나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.
#
# [문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985
# ① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다.
#
# [문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567
# ⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 "장기주택저당차입금"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입금의 상환기간이 15년 이상인 장기주택저당차입금에 대하여 적용하며, 이하 이 항 및 제6항에서 "공제한도"라 한다)을 초과하는 경우 그 초과하는 금액은 없는 것으로 한다. <개정 2012.1.1, 2013.8.13, 2014.1.1, 2014.12.23, 2015.1.6, 2016.1.19, 2018.12.31, 2020.12.29, 2023.12.31>
#
# [문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673
# 5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득
#
# [문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620
# 2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.
#
#  <img src="http://www.law.go.kr/flDownload.do?flSeq=40489693" alt="img40489693" >
#
#  ┌──────────────────────────────────┐
#
#  │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│
#
#  │[ 발생한 수입금액 [ 기간에 발생한 │
#
#  │ 수입금액 │
#
#  └──────────────────────────────────┘
#
#  </img>
#
# [문서 ID: 003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991
# 다. 부동산을 임대하는 법인의 수입이자가 사업외수익에 포함된 경우에는 부동산임대에 의한 전세금 또는 임대보증금에 대한 수입이자 상당액
#
# [문서 ID: 001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120
# 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득
#
# [문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960
# 3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.
#
# [문서 ID: 003956:167_3_⑤_2._가.:j40:p1:l2526
# 가. 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」에 따른 수용 등 재정경제부령으로 정하는 부득이한 사유로 해당 의무임대기간등의 요건을 충족하지 못하게 되거나 임대의무호수를 임대하지 아니하게 된 때에는 해당 임대주택등을 계속 임대ㆍ사용하거나 무상으로 사용하는 것으로 본다.
#
# [문서 ID: 001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381
# 2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "context": "[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\n나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.\n\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985\n① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다.\n\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567\n⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입금의 상환기간이 15년 이상인 장기주택저당차입금에 대하여 적용하며, 이하 이 항 및 제6항에서 \"공제한도\"라 한다)을 초과하는 경우 그 초과하는 금액은 없는 것으로 한다. <개정 2012.1.1, 2013.8.13, 2014.1.1, 2014.12.23, 2015.1.6, 2016.1.19, 2018.12.31, 2020.12.29, 2023.12.31>\n\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673\n5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득\n\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\n2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>\n\n[문서 ID: 003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991\n다. 부동산을 임대하는 법인의 수입이자가 사업외수익에 포함된 경우에는 부동산임대에 의한 전세금 또는 임대보증금에 대한 수입이자 상당액\n\n[문서 ID: 001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120\n2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득\n\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\n3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.\n\n[문서 ID: 003956:167_3_⑤_2._가.:j40:p1:l2526\n가. 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」에 따른 수용 등 재정경제부령으로 정하는 부득이한 사유로 해당 의무임대기간등의 요건을 충족하지 못하게 되거나 임대의무호수를 임대하지 아니하게 된 때에는 해당 임대주택등을 계속 임대ㆍ사용하거나 무상으로 사용하는 것으로 본다.\n\n[문서 ID: 001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381\n2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득",
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?",
#   "final_k": 10
# }
# [chain/start] [chain:RunnableSequence > prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "context": "[문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\n나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.\n\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985\n① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다.\n\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567\n⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입금의 상환기간이 15년 이상인 장기주택저당차입금에 대하여 적용하며, 이하 이 항 및 제6항에서 \"공제한도\"라 한다)을 초과하는 경우 그 초과하는 금액은 없는 것으로 한다. <개정 2012.1.1, 2013.8.13, 2014.1.1, 2014.12.23, 2015.1.6, 2016.1.19, 2018.12.31, 2020.12.29, 2023.12.31>\n\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673\n5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득\n\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\n2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>\n\n[문서 ID: 003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991\n다. 부동산을 임대하는 법인의 수입이자가 사업외수익에 포함된 경우에는 부동산임대에 의한 전세금 또는 임대보증금에 대한 수입이자 상당액\n\n[문서 ID: 001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120\n2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득\n\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\n3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.\n\n[문서 ID: 003956:167_3_⑤_2._가.:j40:p1:l2526\n가. 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」에 따른 수용 등 재정경제부령으로 정하는 부득이한 사유로 해당 의무임대기간등의 요건을 충족하지 못하게 되거나 임대의무호수를 임대하지 아니하게 된 때에는 해당 임대주택등을 계속 임대ㆍ사용하거나 무상으로 사용하는 것으로 본다.\n\n[문서 ID: 001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381\n2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득",
#   "question": "미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?",
#   "final_k": 10
# }
# [chain/end] [chain:RunnableSequence > prompt:PromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    너는 회계, 세법 전문가야. 아래의 context를 근거로 다음 규칙에 따라 질문에 답변해.\n\n    [규칙]\n    1. 결론: 질문에 대한 답은 한 문장으로 먼저 제시 (ex. \"납부할 세액은 1,000,000원입니다.\" \"해당 항목은 익금산입 대상입니다.\")\n    2. 출처는 context에등장하는 [문서 ID: ...]의 값만 그대로 복사해서 사용. (요약, 생략 불가)\n\n    [문맥]\n    [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93\n나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.\n\n[문서 ID: 001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985\n① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다.\n\n[문서 ID: 001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567\n⑤ 근로소득이 있는 거주자로서 주택을 소유하지 아니하거나 1주택을 보유한 세대의 세대주(세대주가 이 항, 제4항 및 「조세특례제한법」 제87조제2항에 따른 공제를 받지 아니하는 경우에는 세대의 구성원 중 근로소득이 있는 자를 말하며, 대통령령으로 정하는 외국인을 포함한다)가 취득 당시 제99조제1항에 따른 주택의 기준시가가 6억원 이하인 주택을 취득하기 위하여 그 주택에 저당권을 설정하고 금융회사등 또는 「주택도시기금법」에 따른 주택도시기금으로부터 차입한 대통령령으로 정하는 장기주택저당차입금(주택을 취득함으로써 승계받은 장기주택저당차입금을 포함하며, 이하 이 항 및 제6항에서 \"장기주택저당차입금\"이라 한다)의 이자를 지급하였을 때에는 해당 과세기간에 지급한 이자 상환액을 다음 각 호의 기준에 따라 그 과세기간의 근로소득금액에서 공제한다. 다만, 그 공제하는 금액과 제4항 및 「조세특례제한법」 제87조제2항에 따른 주택청약종합저축 등에 대한 소득공제 금액의 합계액이 연 800만원(차입금의 상환기간이 15년 이상인 장기주택저당차입금에 대하여 적용하며, 이하 이 항 및 제6항에서 \"공제한도\"라 한다)을 초과하는 경우 그 초과하는 금액은 없는 것으로 한다. <개정 2012.1.1, 2013.8.13, 2014.1.1, 2014.12.23, 2015.1.6, 2016.1.19, 2018.12.31, 2020.12.29, 2023.12.31>\n\n[문서 ID: 003608:92_2_④_5._NO_목번호:j72:p1:l1673\n5. 「민간임대주택에 관한 특별법」 제2조제7호에 따른 임대사업자로서 장기일반민간임대주택등을 300호 또는 300세대 이상 취득하였거나 취득하려는 자에게 토지를 양도하여 발생하는 소득\n\n[문서 ID: 003956:122_2_⑦_2._NO_목번호:j23:p1:l1620\n2. 해당 과세기간 중에 임대주택을 등록한 경우 주택임대소득금액은 다음의 계산식에 따라 계산한다.\n \n <img src=\"http://www.law.go.kr/flDownload.do?flSeq=40489693\" alt=\"img40489693\" >\n \n ┌──────────────────────────────────┐\n \n │ 등록한 기간에 × (1-0.6)] + 등록하지 않은 × (1-0.5)]│\n \n │[ 발생한 수입금액 [ 기간에 발생한 │\n \n │ 수입금액 │\n \n └──────────────────────────────────┘\n \n </img>\n\n[문서 ID: 003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991\n다. 부동산을 임대하는 법인의 수입이자가 사업외수익에 포함된 경우에는 부동산임대에 의한 전세금 또는 임대보증금에 대한 수입이자 상당액\n\n[문서 ID: 001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120\n2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득\n\n[문서 ID: 003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960\n3. 법 제4조에 따른 소득 중 재정경제부령으로 정하는 소득이 「국민기초생활 보장법」 제2조제11호에 따른 기준 중위소득을 12개월로 환산한 금액의 100분의 40 수준 이상으로서 소유하고 있는 주택 또는 토지를 관리ㆍ유지하면서 독립된 생계를 유지할 수 있는 경우. 다만, 미성년자의 경우를 제외하되, 미성년자의 결혼, 가족의 사망 그 밖에 재정경제부령이 정하는 사유로 1세대의 구성이 불가피한 경우에는 그러하지 아니하다.\n\n[문서 ID: 003956:167_3_⑤_2._가.:j40:p1:l2526\n가. 「공익사업을 위한 토지 등의 취득 및 보상에 관한 법률」에 따른 수용 등 재정경제부령으로 정하는 부득이한 사유로 해당 의무임대기간등의 요건을 충족하지 못하게 되거나 임대의무호수를 임대하지 아니하게 된 때에는 해당 임대주택등을 계속 임대ㆍ사용하거나 무상으로 사용하는 것으로 본다.\n\n[문서 ID: 001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381\n2. 다음 각 목의 어느 하나에 해당하는 부동산에 관한 권리의 양도로 발생하는 소득\n\n    [질문]\n    미혼인 본인이 보유한 1채를 임대하고, 부모님이 보유한 주택에서 거주하는 경우 임대소득세 과세대상인지?\n\n    <출력 형식>\n    [답변]\n    1. 결론: ...\n    2. 결론 도출 과정: ...\n\n    [출처]\n    [\"문서 ID1\", \"문서 ID2\", ...]\n    - 답변 생성에 사용한 문서의 ID만 작성\n    - 1 ~ 10개의 문서 ID 작성"
#   ]
# }
# [llm/end] [chain:RunnableSequence > llm:ChatOpenAI] [3.17s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "[답변]\n1. 결론: 미혼인 본인이 보유한 1채를 임대하고 부모님이 보유한 주택에서 거주하는 경우, 해당 임대소득은 과세 대상입니다.\n2. 결론 도출 과정: 본인이 소유한 주택의 임대소득은 [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.]에 따라 과세 대상이며, 부모님이 보유한 주택에서 거주하는 것은 임대소득과 관련된 소득이 아니므로 과세 대상에 영향을 미치지 않습니다.\n\n[출처]\n[\"001565:12_NO_조문가지번호_NO_항번호_2._나.\"]",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "[답변]\n1. 결론: 미혼인 본인이 보유한 1채를 임대하고 부모님이 보유한 주택에서 거주하는 경우, 해당 임대소득은 과세 대상입니다.\n2. 결론 도출 과정: 본인이 소유한 주택의 임대소득은 [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.]에 따라 과세 대상이며, 부모님이 보유한 주택에서 거주하는 것은 임대소득과 관련된 소득이 아니므로 과세 대상에 영향을 미치지 않습니다.\n\n[출처]\n[\"001565:12_NO_조문가지번호_NO_항번호_2._나.\"]",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 162,
#                 "prompt_tokens": 1834,
#                 "total_tokens": 1996,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-4.1-nano-2025-04-14",
#               "system_fingerprint": "fp_de604bd877",
#               "id": "chatcmpl-D5ubLu3UBXqogCK8YMrpPIhAskc4W",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019c2e32-7dd8-7771-b170-7b1af9dd52dd-0",
#             "usage_metadata": {
#               "input_tokens": 1834,
#               "output_tokens": 162,
#               "total_tokens": 1996,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 162,
#       "prompt_tokens": 1834,
#       "total_tokens": 1996,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-nano-2025-04-14",
#     "system_fingerprint": "fp_de604bd877",
#     "id": "chatcmpl-D5ubLu3UBXqogCK8YMrpPIhAskc4W",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "[답변]\n1. 결론: 미혼인 본인이 보유한 1채를 임대하고 부모님이 보유한 주택에서 거주하는 경우, 해당 임대소득은 과세 대상입니다.\n2. 결론 도출 과정: 본인이 소유한 주택의 임대소득은 [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.]에 따라 과세 대상이며, 부모님이 보유한 주택에서 거주하는 것은 임대소득과 관련된 소득이 아니므로 과세 대상에 영향을 미치지 않습니다.\n\n[출처]\n[\"001565:12_NO_조문가지번호_NO_항번호_2._나.\"]"
# }
# [chain/end] [chain:RunnableSequence] [3.17s] Exiting Chain run with output:
# {
#   "output": "[답변]\n1. 결론: 미혼인 본인이 보유한 1채를 임대하고 부모님이 보유한 주택에서 거주하는 경우, 해당 임대소득은 과세 대상입니다.\n2. 결론 도출 과정: 본인이 소유한 주택의 임대소득은 [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.]에 따라 과세 대상이며, 부모님이 보유한 주택에서 거주하는 것은 임대소득과 관련된 소득이 아니므로 과세 대상에 영향을 미치지 않습니다.\n\n[출처]\n[\"001565:12_NO_조문가지번호_NO_항번호_2._나.\"]"
# }
# ids:  []
# docs_id ['001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93', '001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985', '001565:52_NO_조문가지번호_⑤_NO_호번호_NO_목번호:j10:p1:l567', '003608:92_2_④_5._NO_목번호:j72:p1:l1673', '003956:122_2_⑦_2._NO_목번호:j23:p1:l1620', '003608:104_NO_조문가지번호_③_1._다.:j20:p1:l1991', '001565:94_NO_조문가지번호_①_2._NO_목번호:j4:p1:l1120', '003956:152_3_NO_항번호_3._NO_목번호:j4:p1:l1960', '003956:167_3_⑤_2._가.:j40:p1:l2526', '001565:118_2_NO_항번호_2._NO_목번호:j3:p1:l1381']
# used_docs [Document(id='001565:12_NO_조문가지번호_NO_항번호_2._나.:j5:p1:l93', metadata={'file_line_no': 93, '조문번호': '12', 'source': '법령정보센터', '시행일자': '20251001', '조문_index': 5, '공포일자': '20251001', 'piece_count': 1, '조문제목': '비과세소득', 'law_id': '001565', 'law_name': '소득세법', 'level': '목', '호번호': '2.', '목번호': '나.', 'piece_index': 1}, page_content='나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.'), Document(id='001565:81_12_①_NO_호번호_NO_목번호:j2:p1:l985', metadata={'piece_index': 1, '항번호': '①', '조문번호': '81', 'law_id': '001565', 'piece_count': 1, 'file_line_no': 985, '조문제목': '주택임대사업자 미등록 가산세', '시행일자': '20251001', '조문_index': 2, 'level': '항', '공포일자': '20251001', '조문가지번호': '12', 'source': '법령정보센터', 'law_name': '소득세법'}, page_content='① 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다.')]
# [답변]
# 1. 결론: 미혼인 본인이 보유한 1채를 임대하고 부모님이 보유한 주택에서 거주하는 경우, 해당 임대소득은 과세 대상입니다.
# 2. 결론 도출 과정: 본인이 소유한 주택의 임대소득은 [문서 ID: 001565:12_NO_조문가지번호_NO_항번호_2._나.]에 따라 과세 대상이며, 부모님이 보유한 주택에서 거주하는 것은 임대소득과 관련된 소득이 아니므로 과세 대상에 영향을 미치지 않습니다.
#
# [근거 법령 및 본문]
# 소득세법 12조 2호 나목: 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.
#
# 소득세법 81조 ①항: 주택임대소득이 있는 사업자가 제168조제1항 및 제3항에 따라 「부가가치세법」 제8조제1항 본문에 따른 기한까지 등록을 신청하지 아니한 경우에는 사업 개시일부터 등록을 신청한 날의 직전일까지의 주택임대수입금액의 1천분의 2를 가산세로 해당 과세기간의 종합소득 결정세액에 더하여 납부하여야 한다.
